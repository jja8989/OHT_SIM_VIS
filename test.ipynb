# %%
float('inf')
# Out:
# inf

# %%
import json
import random
import csv

# %%
with open('./flask_backend/fab_oht_layout_2nd.json') as f:
    layout_data = json.load(f)
nodes = layout_data['nodes']

# %%
random.choice(nodes)
# Out:
# {'id': 'rn_InterBay3_10',
#  'x': 198623.622047244,
#  'y': 137500.0,
#  'zcu_name': 'ZCU_A14_6',
#  'zcu_type': 'RESET'}

# %%
# 테스트용 job_list 생성
def generate_random_job_list(nodes, num_ohts=600):
    oht_list = []
    available_nodes = nodes.copy()

    for _ in range(num_ohts):
        start_node = random.choice(nodes) 
        while start_node['id'] in oht_list:
            start_node = random.choice(nodes)        
    
        oht_list.append({
            'start_node': start_node['id'],
        })
    
    return oht_list

# job_list를 csv로 저장
def save_job_list_to_csv(job_list, filename='test_oht_list.csv'):
    with open(filename, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=['start_node'])
        writer.writeheader()
        writer.writerows(job_list)

# job_list 생성
oht_list = generate_random_job_list(nodes, num_ohts=700)

# csv로 저장
save_job_list_to_csv(oht_list)

# %%
ports
# Out:
# [{'name': 'A10_LSTB_100_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 9167,
#   'x': 144996.85043307,
#   'y': 115624.666693239},
#  {'name': 'A10_LSTB_101_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 9792,
#   'x': 146996.85043307,
#   'y': 114999.666693239},
#  {'name': 'A10_LSTB_102_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 1042,
#   'x': 144996.85043307,
#   'y': 111249.666693239},
#  {'name': 'A10_LSTB_103_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 1667,
#   'x': 146996.85043307,
#   'y': 110624.666693239},
#  {'name': 'A10_LSTB_104_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 2292,
#   'x': 144996.85043307,
#   'y': 109999.666693239},
#  {'name': 'A10_LSTB_105_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 2917,
#   'x': 146996.85043307,
#   'y': 109374.666693239},
#  {'name': 'A10_LSTB_106_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 3542,
#   'x': 144996.85043307,
#   'y': 108749.666693239},
#  {'name': 'A10_LSTB_107_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 4167,
#   'x': 146996.85043307,
#   'y': 108124.666693239},
#  {'name': 'A10_LSTB_108_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 4792,
#   'x': 144996.85043307,
#   'y': 107499.666693239},
#  {'name': 'A10_LSTB_109_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 5417,
#   'x': 146996.85043307,
#   'y': 106874.666693239},
#  {'name': 'A10_LSTB_10_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 6667,
#   'x': 140206.299173228,
#   'y': 81875.333330676},
#  {'name': 'A10_LSTB_110_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 6042,
#   'x': 146996.85043307,
#   'y': 106249.666693239},
#  {'name': 'A10_LSTB_111_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 6667,
#   'x': 144996.85043307,
#   'y': 105624.666693239},
#  {'name': 'A10_LSTB_112_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 7292,
#   'x': 146996.85043307,
#   'y': 104999.666693239},
#  {'name': 'A10_LSTB_113_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 7917,
#   'x': 144996.85043307,
#   'y': 104374.666693239},
#  {'name': 'A10_LSTB_114_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 8542,
#   'x': 146996.85043307,
#   'y': 103749.666693239},
#  {'name': 'A10_LSTB_115_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 9167,
#   'x': 144996.85043307,
#   'y': 103124.666693239},
#  {'name': 'A10_LSTB_116_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 9792,
#   'x': 146996.85043307,
#   'y': 102499.666693239},
#  {'name': 'A10_LSTB_117_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 10417,
#   'x': 144996.85043307,
#   'y': 101874.666693239},
#  {'name': 'A10_LSTB_118_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 11042,
#   'x': 146996.85043307,
#   'y': 101249.666693239},
#  {'name': 'A10_LSTB_119_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 11667,
#   'x': 144996.85043307,
#   'y': 100624.666693239},
#  {'name': 'A10_LSTB_11_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 7292,
#   'x': 138206.299173228,
#   'y': 82500.333330676},
#  {'name': 'A10_LSTB_120_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 12292,
#   'x': 144996.85043307,
#   'y': 99999.666693239},
#  {'name': 'A10_LSTB_121_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 12917,
#   'x': 146996.85043307,
#   'y': 99374.666693239},
#  {'name': 'A10_LSTB_122_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 1042,
#   'x': 144996.85043307,
#   'y': 95833.0},
#  {'name': 'A10_LSTB_123_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 1667,
#   'x': 146996.85043307,
#   'y': 95208.0},
#  {'name': 'A10_LSTB_124_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 2292,
#   'x': 144996.85043307,
#   'y': 94583.0},
#  {'name': 'A10_LSTB_125_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 2917,
#   'x': 146996.85043307,
#   'y': 93958.0},
#  {'name': 'A10_LSTB_126_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 3542,
#   'x': 144996.85043307,
#   'y': 93333.0},
#  {'name': 'A10_LSTB_127_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 4167,
#   'x': 146996.85043307,
#   'y': 92708.0},
#  {'name': 'A10_LSTB_128_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 4792,
#   'x': 144996.85043307,
#   'y': 92083.0},
#  {'name': 'A10_LSTB_129_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 5417,
#   'x': 146996.85043307,
#   'y': 91458.0},
#  {'name': 'A10_LSTB_12_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 7917,
#   'x': 140206.299173228,
#   'y': 83125.333330676},
#  {'name': 'A10_LSTB_130_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 6042,
#   'x': 146996.85043307,
#   'y': 90833.0},
#  {'name': 'A10_LSTB_131_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 6667,
#   'x': 144996.85043307,
#   'y': 90208.0},
#  {'name': 'A10_LSTB_132_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 7292,
#   'x': 146996.85043307,
#   'y': 89583.0},
#  {'name': 'A10_LSTB_133_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 7917,
#   'x': 144996.85043307,
#   'y': 88958.0},
#  {'name': 'A10_LSTB_134_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 8542,
#   'x': 146996.85043307,
#   'y': 88333.0},
#  {'name': 'A10_LSTB_135_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 9167,
#   'x': 144996.85043307,
#   'y': 87708.0},
#  {'name': 'A10_LSTB_136_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 9792,
#   'x': 146996.85043307,
#   'y': 87083.0},
#  {'name': 'A10_LSTB_137_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 1042,
#   'x': 144996.85043307,
#   'y': 83333.0},
#  {'name': 'A10_LSTB_138_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 1667,
#   'x': 146996.85043307,
#   'y': 82708.0},
#  {'name': 'A10_LSTB_139_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 2292,
#   'x': 144996.85043307,
#   'y': 82083.0},
#  {'name': 'A10_LSTB_13_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 1042,
#   'x': 138206.299173228,
#   'y': 86667.0},
#  {'name': 'A10_LSTB_140_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 2917,
#   'x': 144996.85043307,
#   'y': 81458.0},
#  {'name': 'A10_LSTB_141_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 3542,
#   'x': 146996.85043307,
#   'y': 80833.0},
#  {'name': 'A10_LSTB_142_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 4167,
#   'x': 144996.85043307,
#   'y': 80208.0},
#  {'name': 'A10_LSTB_143_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 4792,
#   'x': 146996.85043307,
#   'y': 79583.0},
#  {'name': 'A10_LSTB_144_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 5417,
#   'x': 144996.85043307,
#   'y': 78958.0},
#  {'name': 'A10_LSTB_145_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 6042,
#   'x': 146996.85043307,
#   'y': 78333.0},
#  {'name': 'A10_LSTB_146_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 6667,
#   'x': 144996.85043307,
#   'y': 77708.0},
#  {'name': 'A10_LSTB_147_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 7292,
#   'x': 146996.85043307,
#   'y': 77083.0},
#  {'name': 'A10_LSTB_148_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 7917,
#   'x': 144996.85043307,
#   'y': 76458.0},
#  {'name': 'A10_LSTB_14_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 1667,
#   'x': 138206.299173228,
#   'y': 87292.0},
#  {'name': 'A10_LSTB_15_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 2292,
#   'x': 140206.299173228,
#   'y': 87917.0},
#  {'name': 'A10_LSTB_16_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 2917,
#   'x': 138206.299173228,
#   'y': 88542.0},
#  {'name': 'A10_LSTB_17_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 3542,
#   'x': 140206.299173228,
#   'y': 89167.0},
#  {'name': 'A10_LSTB_18_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 4167,
#   'x': 138206.299173228,
#   'y': 89792.0},
#  {'name': 'A10_LSTB_19_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 4792,
#   'x': 140206.299173228,
#   'y': 90417.0},
#  {'name': 'A10_LSTB_1_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 1042,
#   'x': 138206.299173228,
#   'y': 76250.333330676},
#  {'name': 'A10_LSTB_20_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 5417,
#   'x': 140206.299173228,
#   'y': 91042.0},
#  {'name': 'A10_LSTB_21_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 6042,
#   'x': 138206.299173228,
#   'y': 91667.0},
#  {'name': 'A10_LSTB_22_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 6667,
#   'x': 140206.299173228,
#   'y': 92292.0},
#  {'name': 'A10_LSTB_23_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 7292,
#   'x': 138206.299173228,
#   'y': 92917.0},
#  {'name': 'A10_LSTB_24_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 7917,
#   'x': 140206.299173228,
#   'y': 93542.0},
#  {'name': 'A10_LSTB_25_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 8542,
#   'x': 138206.299173228,
#   'y': 94167.0},
#  {'name': 'A10_LSTB_26_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 9167,
#   'x': 140206.299173228,
#   'y': 94792.0},
#  {'name': 'A10_LSTB_27_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 9792,
#   'x': 138206.299173228,
#   'y': 95417.0},
#  {'name': 'A10_LSTB_28_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 1042,
#   'x': 140206.299173228,
#   'y': 99167.0},
#  {'name': 'A10_LSTB_29_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 1667,
#   'x': 138206.299173228,
#   'y': 99792.0},
#  {'name': 'A10_LSTB_2_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 1667,
#   'x': 140206.299173228,
#   'y': 76875.333330676},
#  {'name': 'A10_LSTB_30_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 2292,
#   'x': 138206.299173228,
#   'y': 100417.0},
#  {'name': 'A10_LSTB_31_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 2917,
#   'x': 140206.299173228,
#   'y': 101042.0},
#  {'name': 'A10_LSTB_32_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 3542,
#   'x': 138206.299173228,
#   'y': 101667.0},
#  {'name': 'A10_LSTB_33_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 4167,
#   'x': 140206.299173228,
#   'y': 102292.0},
#  {'name': 'A10_LSTB_34_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 4792,
#   'x': 138206.299173228,
#   'y': 102917.0},
#  {'name': 'A10_LSTB_35_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 5417,
#   'x': 140206.299173228,
#   'y': 103542.0},
#  {'name': 'A10_LSTB_36_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 6042,
#   'x': 138206.299173228,
#   'y': 104167.0},
#  {'name': 'A10_LSTB_37_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 6667,
#   'x': 140206.299173228,
#   'y': 104792.0},
#  {'name': 'A10_LSTB_38_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 7292,
#   'x': 138206.299173228,
#   'y': 105417.0},
#  {'name': 'A10_LSTB_39_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 7917,
#   'x': 140206.299173228,
#   'y': 106042.0},
#  {'name': 'A10_LSTB_3_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 2292,
#   'x': 138206.299173228,
#   'y': 77500.333330676},
#  {'name': 'A10_LSTB_40_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 8542,
#   'x': 140206.299173228,
#   'y': 106667.0},
#  {'name': 'A10_LSTB_41_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 9167,
#   'x': 138206.299173228,
#   'y': 107292.0},
#  {'name': 'A10_LSTB_42_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 9792,
#   'x': 140206.299173228,
#   'y': 107917.0},
#  {'name': 'A10_LSTB_43_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 10417,
#   'x': 138206.299173228,
#   'y': 108542.0},
#  {'name': 'A10_LSTB_44_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 11042,
#   'x': 140206.299173228,
#   'y': 109167.0},
#  {'name': 'A10_LSTB_45_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 11667,
#   'x': 138206.299173228,
#   'y': 109792.0},
#  {'name': 'A10_LSTB_46_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 12292,
#   'x': 140206.299173228,
#   'y': 110417.0},
#  {'name': 'A10_LSTB_47_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_6_7',
#   'from_node': 'rn_A10_6',
#   'to_node': 'rn_A10_7',
#   'distance': 12917,
#   'x': 138206.299173228,
#   'y': 111042.0},
#  {'name': 'A10_LSTB_48_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 1042,
#   'x': 140206.299173228,
#   'y': 114583.666693239},
#  {'name': 'A10_LSTB_49_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 1667,
#   'x': 138206.299173228,
#   'y': 115208.666693239},
#  {'name': 'A10_LSTB_4_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 2917,
#   'x': 140206.299173228,
#   'y': 78125.333330676},
#  {'name': 'A10_LSTB_50_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 2292,
#   'x': 138206.299173228,
#   'y': 115833.666693239},
#  {'name': 'A10_LSTB_51_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 2917,
#   'x': 140206.299173228,
#   'y': 116458.666693239},
#  {'name': 'A10_LSTB_52_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 3542,
#   'x': 138206.299173228,
#   'y': 117083.666693239},
#  {'name': 'A10_LSTB_53_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 4167,
#   'x': 140206.299173228,
#   'y': 117708.666693239},
#  {'name': 'A10_LSTB_54_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 4792,
#   'x': 138206.299173228,
#   'y': 118333.666693239},
#  {'name': 'A10_LSTB_55_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 5417,
#   'x': 140206.299173228,
#   'y': 118958.666693239},
#  {'name': 'A10_LSTB_56_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 6042,
#   'x': 138206.299173228,
#   'y': 119583.666693239},
#  {'name': 'A10_LSTB_57_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 6667,
#   'x': 140206.299173228,
#   'y': 120208.666693239},
#  {'name': 'A10_LSTB_58_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 7292,
#   'x': 138206.299173228,
#   'y': 120833.666693239},
#  {'name': 'A10_LSTB_59_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 7917,
#   'x': 140206.299173228,
#   'y': 121458.666693239},
#  {'name': 'A10_LSTB_5_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 3542,
#   'x': 138206.299173228,
#   'y': 78750.333330676},
#  {'name': 'A10_LSTB_60_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 8542,
#   'x': 140206.299173228,
#   'y': 122083.666693239},
#  {'name': 'A10_LSTB_61_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 9167,
#   'x': 138206.299173228,
#   'y': 122708.666693239},
#  {'name': 'A10_LSTB_62_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_8_9',
#   'from_node': 'rn_A10_8',
#   'to_node': 'rn_A10_9',
#   'distance': 9792,
#   'x': 140206.299173228,
#   'y': 123333.666693239},
#  {'name': 'A10_LSTB_63_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 1042,
#   'x': 138206.299173228,
#   'y': 127083.666693239},
#  {'name': 'A10_LSTB_64_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 1667,
#   'x': 140206.299173228,
#   'y': 127708.666693239},
#  {'name': 'A10_LSTB_65_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 2292,
#   'x': 138206.299173228,
#   'y': 128333.666693239},
#  {'name': 'A10_LSTB_66_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 2917,
#   'x': 140206.299173228,
#   'y': 128958.666693239},
#  {'name': 'A10_LSTB_67_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 3542,
#   'x': 138206.299173228,
#   'y': 129583.666693239},
#  {'name': 'A10_LSTB_68_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 4167,
#   'x': 140206.299173228,
#   'y': 130208.666693239},
#  {'name': 'A10_LSTB_69_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 4792,
#   'x': 138206.299173228,
#   'y': 130833.666693239},
#  {'name': 'A10_LSTB_6_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 4167,
#   'x': 140206.299173228,
#   'y': 79375.333330676},
#  {'name': 'A10_LSTB_70_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 5417,
#   'x': 138206.299173228,
#   'y': 131458.666693239},
#  {'name': 'A10_LSTB_71_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 6042,
#   'x': 140206.299173228,
#   'y': 132083.666693239},
#  {'name': 'A10_LSTB_72_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 6667,
#   'x': 138206.299173228,
#   'y': 132708.666693239},
#  {'name': 'A10_LSTB_73_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 7292,
#   'x': 140206.299173228,
#   'y': 133333.666693239},
#  {'name': 'A10_LSTB_74_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_10_11',
#   'from_node': 'rn_A10_10',
#   'to_node': 'rn_A10_11',
#   'distance': 7917,
#   'x': 138206.299173228,
#   'y': 133958.666693239},
#  {'name': 'A10_LSTB_75_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 1042,
#   'x': 144996.85043307,
#   'y': 134166.33330676},
#  {'name': 'A10_LSTB_76_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 1667,
#   'x': 146996.85043307,
#   'y': 133541.33330676},
#  {'name': 'A10_LSTB_77_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 2292,
#   'x': 144996.85043307,
#   'y': 132916.33330676},
#  {'name': 'A10_LSTB_78_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 2917,
#   'x': 146996.85043307,
#   'y': 132291.33330676},
#  {'name': 'A10_LSTB_79_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 3542,
#   'x': 144996.85043307,
#   'y': 131666.33330676},
#  {'name': 'A10_LSTB_7_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 4792,
#   'x': 138206.299173228,
#   'y': 80000.333330676},
#  {'name': 'A10_LSTB_80_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 4167,
#   'x': 144996.85043307,
#   'y': 131041.33330676},
#  {'name': 'A10_LSTB_81_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 4792,
#   'x': 146996.85043307,
#   'y': 130416.33330676},
#  {'name': 'A10_LSTB_82_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 5417,
#   'x': 144996.85043307,
#   'y': 129791.33330676},
#  {'name': 'A10_LSTB_83_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 6042,
#   'x': 146996.85043307,
#   'y': 129166.33330676},
#  {'name': 'A10_LSTB_84_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 6667,
#   'x': 144996.85043307,
#   'y': 128541.33330676},
#  {'name': 'A10_LSTB_85_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 7292,
#   'x': 146996.85043307,
#   'y': 127916.33330676},
#  {'name': 'A10_LSTB_86_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_16_17',
#   'from_node': 'rn_A10_16',
#   'to_node': 'rn_A10_17',
#   'distance': 7917,
#   'x': 144996.85043307,
#   'y': 127291.33330676},
#  {'name': 'A10_LSTB_87_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 1042,
#   'x': 146996.85043307,
#   'y': 123749.666693239},
#  {'name': 'A10_LSTB_88_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 1667,
#   'x': 144996.85043307,
#   'y': 123124.666693239},
#  {'name': 'A10_LSTB_89_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 2292,
#   'x': 146996.85043307,
#   'y': 122499.666693239},
#  {'name': 'A10_LSTB_8_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 5417,
#   'x': 140206.299173228,
#   'y': 80625.333330676},
#  {'name': 'A10_LSTB_90_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 2917,
#   'x': 146996.85043307,
#   'y': 121874.666693239},
#  {'name': 'A10_LSTB_91_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 3542,
#   'x': 144996.85043307,
#   'y': 121249.666693239},
#  {'name': 'A10_LSTB_92_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 4167,
#   'x': 146996.85043307,
#   'y': 120624.666693239},
#  {'name': 'A10_LSTB_93_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 4792,
#   'x': 144996.85043307,
#   'y': 119999.666693239},
#  {'name': 'A10_LSTB_94_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 5417,
#   'x': 146996.85043307,
#   'y': 119374.666693239},
#  {'name': 'A10_LSTB_95_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 6042,
#   'x': 144996.85043307,
#   'y': 118749.666693239},
#  {'name': 'A10_LSTB_96_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 6667,
#   'x': 146996.85043307,
#   'y': 118124.666693239},
#  {'name': 'A10_LSTB_97_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 7292,
#   'x': 144996.85043307,
#   'y': 117499.666693239},
#  {'name': 'A10_LSTB_98_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 7917,
#   'x': 146996.85043307,
#   'y': 116874.666693239},
#  {'name': 'A10_LSTB_99_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 8542,
#   'x': 144996.85043307,
#   'y': 116249.666693239},
#  {'name': 'A10_LSTB_9_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 6042,
#   'x': 138206.299173228,
#   'y': 81250.333330676},
#  {'name': 'A10_RSTB_100_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 9167,
#   'x': 144996.85043307,
#   'y': 115624.666693239},
#  {'name': 'A10_RSTB_101_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_18_19',
#   'from_node': 'rn_A10_18',
#   'to_node': 'rn_A10_19',
#   'distance': 9792,
#   'x': 146996.85043307,
#   'y': 114999.666693239},
#  {'name': 'A10_RSTB_102_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 1042,
#   'x': 144996.85043307,
#   'y': 111249.666693239},
#  {'name': 'A10_RSTB_103_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 1667,
#   'x': 146996.85043307,
#   'y': 110624.666693239},
#  {'name': 'A10_RSTB_104_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 2292,
#   'x': 144996.85043307,
#   'y': 109999.666693239},
#  {'name': 'A10_RSTB_105_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 2917,
#   'x': 146996.85043307,
#   'y': 109374.666693239},
#  {'name': 'A10_RSTB_106_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 3542,
#   'x': 144996.85043307,
#   'y': 108749.666693239},
#  {'name': 'A10_RSTB_107_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 4167,
#   'x': 146996.85043307,
#   'y': 108124.666693239},
#  {'name': 'A10_RSTB_108_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 4792,
#   'x': 144996.85043307,
#   'y': 107499.666693239},
#  {'name': 'A10_RSTB_109_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 5417,
#   'x': 146996.85043307,
#   'y': 106874.666693239},
#  {'name': 'A10_RSTB_10_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 6667,
#   'x': 140206.299173228,
#   'y': 81875.333330676},
#  {'name': 'A10_RSTB_110_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 6042,
#   'x': 146996.85043307,
#   'y': 106249.666693239},
#  {'name': 'A10_RSTB_111_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 6667,
#   'x': 144996.85043307,
#   'y': 105624.666693239},
#  {'name': 'A10_RSTB_112_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 7292,
#   'x': 146996.85043307,
#   'y': 104999.666693239},
#  {'name': 'A10_RSTB_113_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 7917,
#   'x': 144996.85043307,
#   'y': 104374.666693239},
#  {'name': 'A10_RSTB_114_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 8542,
#   'x': 146996.85043307,
#   'y': 103749.666693239},
#  {'name': 'A10_RSTB_115_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 9167,
#   'x': 144996.85043307,
#   'y': 103124.666693239},
#  {'name': 'A10_RSTB_116_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 9792,
#   'x': 146996.85043307,
#   'y': 102499.666693239},
#  {'name': 'A10_RSTB_117_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 10417,
#   'x': 144996.85043307,
#   'y': 101874.666693239},
#  {'name': 'A10_RSTB_118_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 11042,
#   'x': 146996.85043307,
#   'y': 101249.666693239},
#  {'name': 'A10_RSTB_119_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 11667,
#   'x': 144996.85043307,
#   'y': 100624.666693239},
#  {'name': 'A10_RSTB_11_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 7292,
#   'x': 138206.299173228,
#   'y': 82500.333330676},
#  {'name': 'A10_RSTB_120_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 12292,
#   'x': 144996.85043307,
#   'y': 99999.666693239},
#  {'name': 'A10_RSTB_121_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_20_21',
#   'from_node': 'rn_A10_20',
#   'to_node': 'rn_A10_21',
#   'distance': 12917,
#   'x': 146996.85043307,
#   'y': 99374.666693239},
#  {'name': 'A10_RSTB_122_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 1042,
#   'x': 144996.85043307,
#   'y': 95833.0},
#  {'name': 'A10_RSTB_123_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 1667,
#   'x': 146996.85043307,
#   'y': 95208.0},
#  {'name': 'A10_RSTB_124_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 2292,
#   'x': 144996.85043307,
#   'y': 94583.0},
#  {'name': 'A10_RSTB_125_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 2917,
#   'x': 146996.85043307,
#   'y': 93958.0},
#  {'name': 'A10_RSTB_126_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 3542,
#   'x': 144996.85043307,
#   'y': 93333.0},
#  {'name': 'A10_RSTB_127_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 4167,
#   'x': 146996.85043307,
#   'y': 92708.0},
#  {'name': 'A10_RSTB_128_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 4792,
#   'x': 144996.85043307,
#   'y': 92083.0},
#  {'name': 'A10_RSTB_129_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 5417,
#   'x': 146996.85043307,
#   'y': 91458.0},
#  {'name': 'A10_RSTB_12_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 7917,
#   'x': 140206.299173228,
#   'y': 83125.333330676},
#  {'name': 'A10_RSTB_130_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 6042,
#   'x': 146996.85043307,
#   'y': 90833.0},
#  {'name': 'A10_RSTB_131_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 6667,
#   'x': 144996.85043307,
#   'y': 90208.0},
#  {'name': 'A10_RSTB_132_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 7292,
#   'x': 146996.85043307,
#   'y': 89583.0},
#  {'name': 'A10_RSTB_133_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 7917,
#   'x': 144996.85043307,
#   'y': 88958.0},
#  {'name': 'A10_RSTB_134_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 8542,
#   'x': 146996.85043307,
#   'y': 88333.0},
#  {'name': 'A10_RSTB_135_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 9167,
#   'x': 144996.85043307,
#   'y': 87708.0},
#  {'name': 'A10_RSTB_136_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_22_23',
#   'from_node': 'rn_A10_22',
#   'to_node': 'rn_A10_23',
#   'distance': 9792,
#   'x': 146996.85043307,
#   'y': 87083.0},
#  {'name': 'A10_RSTB_137_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 1042,
#   'x': 144996.85043307,
#   'y': 83333.0},
#  {'name': 'A10_RSTB_138_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 1667,
#   'x': 146996.85043307,
#   'y': 82708.0},
#  {'name': 'A10_RSTB_139_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 2292,
#   'x': 144996.85043307,
#   'y': 82083.0},
#  {'name': 'A10_RSTB_13_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 1042,
#   'x': 138206.299173228,
#   'y': 86667.0},
#  {'name': 'A10_RSTB_140_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 2917,
#   'x': 144996.85043307,
#   'y': 81458.0},
#  {'name': 'A10_RSTB_141_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 3542,
#   'x': 146996.85043307,
#   'y': 80833.0},
#  {'name': 'A10_RSTB_142_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 4167,
#   'x': 144996.85043307,
#   'y': 80208.0},
#  {'name': 'A10_RSTB_143_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 4792,
#   'x': 146996.85043307,
#   'y': 79583.0},
#  {'name': 'A10_RSTB_144_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 5417,
#   'x': 144996.85043307,
#   'y': 78958.0},
#  {'name': 'A10_RSTB_145_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 6042,
#   'x': 146996.85043307,
#   'y': 78333.0},
#  {'name': 'A10_RSTB_146_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 6667,
#   'x': 144996.85043307,
#   'y': 77708.0},
#  {'name': 'A10_RSTB_147_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 7292,
#   'x': 146996.85043307,
#   'y': 77083.0},
#  {'name': 'A10_RSTB_148_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_24_25',
#   'from_node': 'rn_A10_24',
#   'to_node': 'rn_A10_25',
#   'distance': 7917,
#   'x': 144996.85043307,
#   'y': 76458.0},
#  {'name': 'A10_RSTB_14_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 1667,
#   'x': 138206.299173228,
#   'y': 87292.0},
#  {'name': 'A10_RSTB_15_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 2292,
#   'x': 140206.299173228,
#   'y': 87917.0},
#  {'name': 'A10_RSTB_16_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 2917,
#   'x': 138206.299173228,
#   'y': 88542.0},
#  {'name': 'A10_RSTB_17_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 3542,
#   'x': 140206.299173228,
#   'y': 89167.0},
#  {'name': 'A10_RSTB_18_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 4167,
#   'x': 138206.299173228,
#   'y': 89792.0},
#  {'name': 'A10_RSTB_19_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 4792,
#   'x': 140206.299173228,
#   'y': 90417.0},
#  {'name': 'A10_RSTB_1_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_2_3',
#   'from_node': 'rn_A10_2',
#   'to_node': 'rn_A10_3',
#   'distance': 1042,
#   'x': 138206.299173228,
#   'y': 76250.333330676},
#  {'name': 'A10_RSTB_20_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 5417,
#   'x': 140206.299173228,
#   'y': 91042.0},
#  {'name': 'A10_RSTB_21_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 6042,
#   'x': 138206.299173228,
#   'y': 91667.0},
#  {'name': 'A10_RSTB_22_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 6667,
#   'x': 140206.299173228,
#   'y': 92292.0},
#  {'name': 'A10_RSTB_23_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 7292,
#   'x': 138206.299173228,
#   'y': 92917.0},
#  {'name': 'A10_RSTB_24_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 7917,
#   'x': 140206.299173228,
#   'y': 93542.0},
#  {'name': 'A10_RSTB_25_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 8542,
#   'x': 138206.299173228,
#   'y': 94167.0},
#  {'name': 'A10_RSTB_26_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 9167,
#   'x': 140206.299173228,
#   'y': 94792.0},
#  {'name': 'A10_RSTB_27_Port',
#   'port_type': 'RSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A10_4_5',
#   'from_node': 'rn_A10_4',
#   'to_node': 'rn_A10_5',
#   'distance': 9792,
#   'x': 138206.299173228,
#   'y': 95417.0},
#  {'name': 'A10_RSTB_28_Port',
# ...
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_22_23',
#   'from_node': 'rn_A12_22',
#   'to_node': 'rn_A12_23',
#   'distance': 9792,
#   'x': 177245.669251968,
#   'y': 87083.0},
#  {'name': 'A12_LSTB_137_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 1042,
#   'x': 175245.669251968,
#   'y': 83333.0},
#  {'name': 'A12_LSTB_138_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 1667,
#   'x': 177245.669251968,
#   'y': 82708.0},
#  {'name': 'A12_LSTB_139_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 2292,
#   'x': 175245.669251968,
#   'y': 82083.0},
#  {'name': 'A12_LSTB_13_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 1042,
#   'x': 168455.118110236,
#   'y': 86667.0},
#  {'name': 'A12_LSTB_140_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 2917,
#   'x': 175245.669251968,
#   'y': 81458.0},
#  {'name': 'A12_LSTB_141_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 3542,
#   'x': 177245.669251968,
#   'y': 80833.0},
#  {'name': 'A12_LSTB_142_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 4167,
#   'x': 175245.669251968,
#   'y': 80208.0},
#  {'name': 'A12_LSTB_143_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 4792,
#   'x': 177245.669251968,
#   'y': 79583.0},
#  {'name': 'A12_LSTB_144_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 5417,
#   'x': 175245.669251968,
#   'y': 78958.0},
#  {'name': 'A12_LSTB_145_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 6042,
#   'x': 177245.669251968,
#   'y': 78333.0},
#  {'name': 'A12_LSTB_146_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 6667,
#   'x': 175245.669251968,
#   'y': 77708.0},
#  {'name': 'A12_LSTB_147_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 7292,
#   'x': 177245.669251968,
#   'y': 77083.0},
#  {'name': 'A12_LSTB_148_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_24_25',
#   'from_node': 'rn_A12_24',
#   'to_node': 'rn_A12_25',
#   'distance': 7917,
#   'x': 175245.669251968,
#   'y': 76458.0},
#  {'name': 'A12_LSTB_14_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 1667,
#   'x': 168455.118110236,
#   'y': 87292.0},
#  {'name': 'A12_LSTB_15_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 2292,
#   'x': 170455.118110236,
#   'y': 87917.0},
#  {'name': 'A12_LSTB_16_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 2917,
#   'x': 168455.118110236,
#   'y': 88542.0},
#  {'name': 'A12_LSTB_17_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 3542,
#   'x': 170455.118110236,
#   'y': 89167.0},
#  {'name': 'A12_LSTB_18_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 4167,
#   'x': 168455.118110236,
#   'y': 89792.0},
#  {'name': 'A12_LSTB_19_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 4792,
#   'x': 170455.118110236,
#   'y': 90417.0},
#  {'name': 'A12_LSTB_1_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_2_3',
#   'from_node': 'rn_A12_2',
#   'to_node': 'rn_A12_3',
#   'distance': 1042,
#   'x': 168455.118110236,
#   'y': 76250.333330676},
#  {'name': 'A12_LSTB_20_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 5417,
#   'x': 170455.118110236,
#   'y': 91042.0},
#  {'name': 'A12_LSTB_21_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 6042,
#   'x': 168455.118110236,
#   'y': 91667.0},
#  {'name': 'A12_LSTB_22_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 6667,
#   'x': 170455.118110236,
#   'y': 92292.0},
#  {'name': 'A12_LSTB_23_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 7292,
#   'x': 168455.118110236,
#   'y': 92917.0},
#  {'name': 'A12_LSTB_24_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 7917,
#   'x': 170455.118110236,
#   'y': 93542.0},
#  {'name': 'A12_LSTB_25_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 8542,
#   'x': 168455.118110236,
#   'y': 94167.0},
#  {'name': 'A12_LSTB_26_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 9167,
#   'x': 170455.118110236,
#   'y': 94792.0},
#  {'name': 'A12_LSTB_27_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_4_5',
#   'from_node': 'rn_A12_4',
#   'to_node': 'rn_A12_5',
#   'distance': 9792,
#   'x': 168455.118110236,
#   'y': 95417.0},
#  {'name': 'A12_LSTB_28_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 1042,
#   'x': 170455.118110236,
#   'y': 99167.0},
#  {'name': 'A12_LSTB_29_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 1667,
#   'x': 168455.118110236,
#   'y': 99792.0},
#  {'name': 'A12_LSTB_2_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_2_3',
#   'from_node': 'rn_A12_2',
#   'to_node': 'rn_A12_3',
#   'distance': 1667,
#   'x': 170455.118110236,
#   'y': 76875.333330676},
#  {'name': 'A12_LSTB_30_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 2292,
#   'x': 168455.118110236,
#   'y': 100417.0},
#  {'name': 'A12_LSTB_31_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 2917,
#   'x': 170455.118110236,
#   'y': 101042.0},
#  {'name': 'A12_LSTB_32_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 3542,
#   'x': 168455.118110236,
#   'y': 101667.0},
#  {'name': 'A12_LSTB_33_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 4167,
#   'x': 170455.118110236,
#   'y': 102292.0},
#  {'name': 'A12_LSTB_34_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 4792,
#   'x': 168455.118110236,
#   'y': 102917.0},
#  {'name': 'A12_LSTB_35_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 5417,
#   'x': 170455.118110236,
#   'y': 103542.0},
#  {'name': 'A12_LSTB_36_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 6042,
#   'x': 168455.118110236,
#   'y': 104167.0},
#  {'name': 'A12_LSTB_37_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 6667,
#   'x': 170455.118110236,
#   'y': 104792.0},
#  {'name': 'A12_LSTB_38_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 7292,
#   'x': 168455.118110236,
#   'y': 105417.0},
#  {'name': 'A12_LSTB_39_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 7917,
#   'x': 170455.118110236,
#   'y': 106042.0},
#  {'name': 'A12_LSTB_3_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_2_3',
#   'from_node': 'rn_A12_2',
#   'to_node': 'rn_A12_3',
#   'distance': 2292,
#   'x': 168455.118110236,
#   'y': 77500.333330676},
#  {'name': 'A12_LSTB_40_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 8542,
#   'x': 170455.118110236,
#   'y': 106667.0},
#  {'name': 'A12_LSTB_41_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 9167,
#   'x': 168455.118110236,
#   'y': 107292.0},
#  {'name': 'A12_LSTB_42_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 9792,
#   'x': 170455.118110236,
#   'y': 107917.0},
#  {'name': 'A12_LSTB_43_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 10417,
#   'x': 168455.118110236,
#   'y': 108542.0},
#  {'name': 'A12_LSTB_44_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 11042,
#   'x': 170455.118110236,
#   'y': 109167.0},
#  {'name': 'A12_LSTB_45_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 11667,
#   'x': 168455.118110236,
#   'y': 109792.0},
#  {'name': 'A12_LSTB_46_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 12292,
#   'x': 170455.118110236,
#   'y': 110417.0},
#  {'name': 'A12_LSTB_47_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_6_7',
#   'from_node': 'rn_A12_6',
#   'to_node': 'rn_A12_7',
#   'distance': 12917,
#   'x': 168455.118110236,
#   'y': 111042.0},
#  {'name': 'A12_LSTB_48_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 1042,
#   'x': 170455.118110236,
#   'y': 114583.666693239},
#  {'name': 'A12_LSTB_49_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 1667,
#   'x': 168455.118110236,
#   'y': 115208.666693239},
#  {'name': 'A12_LSTB_4_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_2_3',
#   'from_node': 'rn_A12_2',
#   'to_node': 'rn_A12_3',
#   'distance': 2917,
#   'x': 170455.118110236,
#   'y': 78125.333330676},
#  {'name': 'A12_LSTB_50_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 2292,
#   'x': 168455.118110236,
#   'y': 115833.666693239},
#  {'name': 'A12_LSTB_51_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 2917,
#   'x': 170455.118110236,
#   'y': 116458.666693239},
#  {'name': 'A12_LSTB_52_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 3542,
#   'x': 168455.118110236,
#   'y': 117083.666693239},
#  {'name': 'A12_LSTB_53_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 4167,
#   'x': 170455.118110236,
#   'y': 117708.666693239},
#  {'name': 'A12_LSTB_54_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 4792,
#   'x': 168455.118110236,
#   'y': 118333.666693239},
#  {'name': 'A12_LSTB_55_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 5417,
#   'x': 170455.118110236,
#   'y': 118958.666693239},
#  {'name': 'A12_LSTB_56_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 6042,
#   'x': 168455.118110236,
#   'y': 119583.666693239},
#  {'name': 'A12_LSTB_57_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 6667,
#   'x': 170455.118110236,
#   'y': 120208.666693239},
#  {'name': 'A12_LSTB_58_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 7292,
#   'x': 168455.118110236,
#   'y': 120833.666693239},
#  {'name': 'A12_LSTB_59_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 7917,
#   'x': 170455.118110236,
#   'y': 121458.666693239},
#  {'name': 'A12_LSTB_5_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_2_3',
#   'from_node': 'rn_A12_2',
#   'to_node': 'rn_A12_3',
#   'distance': 3542,
#   'x': 168455.118110236,
#   'y': 78750.333330676},
#  {'name': 'A12_LSTB_60_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 8542,
#   'x': 170455.118110236,
#   'y': 122083.666693239},
#  {'name': 'A12_LSTB_61_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 9167,
#   'x': 168455.118110236,
#   'y': 122708.666693239},
#  {'name': 'A12_LSTB_62_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_8_9',
#   'from_node': 'rn_A12_8',
#   'to_node': 'rn_A12_9',
#   'distance': 9792,
#   'x': 170455.118110236,
#   'y': 123333.666693239},
#  {'name': 'A12_LSTB_63_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_10_11',
#   'from_node': 'rn_A12_10',
#   'to_node': 'rn_A12_11',
#   'distance': 1042,
#   'x': 168455.118110236,
#   'y': 127083.666693239},
#  {'name': 'A12_LSTB_64_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_10_11',
#   'from_node': 'rn_A12_10',
#   'to_node': 'rn_A12_11',
#   'distance': 1667,
#   'x': 170455.118110236,
#   'y': 127708.666693239},
#  {'name': 'A12_LSTB_65_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_10_11',
#   'from_node': 'rn_A12_10',
#   'to_node': 'rn_A12_11',
#   'distance': 2292,
#   'x': 168455.118110236,
#   'y': 128333.666693239},
#  {'name': 'A12_LSTB_66_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_10_11',
#   'from_node': 'rn_A12_10',
#   'to_node': 'rn_A12_11',
#   'distance': 2917,
#   'x': 170455.118110236,
#   'y': 128958.666693239},
#  {'name': 'A12_LSTB_67_Port',
#   'port_type': 'LSTB',
#   'eqp_name': ',',
#   'rail_line': 'rl_A12_10_11',
#   'from_node': 'rn_A12_10',
#   'to_node': 'rn_A12_11',
#   'distance': 3542,
#   'x': 168455.118110236,
#   'y': 129583.666693239},
#  ...]

# %%
import multiprocessing
import random
import time

# OHT 객체 클래스
class OHT:
    def __init__(self, id, position):
        self.id = id
        self.position = position

    def update_position(self, increment):
        self.position += increment

    def move(self, time_step):
        # 위치를 임의로 업데이트 (단순히 위치 + 속도)
        self.update_position(time_step)

    def get_position(self):
        return self.position

# 작업을 실행할 프로세스 함수
def process_oht(oht, time_step, lock):
    with lock:  # Lock을 사용하여 동기화
        oht.move(time_step)
        print(f"OHT {oht.id} new position: {oht.get_position()}")

# 병렬화 처리 함수
def parallel_oht_processing(oht_objects, time_step, process_count=4):
    # Lock을 사용하여 동기화 처리
    lock = multiprocessing.Lock()

    # multiprocessing.Pool로 프로세스 생성
    with multiprocessing.Pool(processes=process_count) as pool:
        pool.starmap(process_oht, [(oht, time_step, lock) for oht in oht_objects])

    # 최종 결과 출력
    for oht in oht_objects:
        print(f"OHT {oht.id} final position: {oht.get_position()}")

if __name__ == "__main__":
    # OHT 객체 생성
    oht_objects = [OHT(i, random.randint(0, 100)) for i in range(10)]

    # 병렬 처리 실행
    time_step = 1.0
    parallel_oht_processing(oht_objects, time_step, process_count=4)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 46
#      44 # 병렬 처리 실행
#      45 time_step = 1.0
# ---> 46 parallel_oht_processing(oht_objects, time_step, process_count=4)
#
# Cell In[1], line 34, in parallel_oht_processing(oht_objects, time_step, process_count)
#      32 # multiprocessing.Pool로 프로세스 생성
#      33 with multiprocessing.Pool(processes=process_count) as pool:
# ---> 34     pool.starmap(process_oht, [(oht, time_step, lock) for oht in oht_objects])
#      36 # 최종 결과 출력
#      37 for oht in oht_objects:
#
# File ~/anaconda3/lib/python3.11/multiprocessing/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File ~/anaconda3/lib/python3.11/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File ~/anaconda3/lib/python3.11/multiprocessing/pool.py:540, in Pool._handle_tasks(taskqueue, put, outqueue, pool, cache)
#     538     break
#     539 try:
# --> 540     put(task)
#     541 except Exception as e:
#     542     job, idx = task[:2]
#
# File ~/anaconda3/lib/python3.11/multiprocessing/connection.py:205, in _ConnectionBase.send(self, obj)
#     203 self._check_closed()
#     204 self._check_writable()
# --> 205 self._send_bytes(_ForkingPickler.dumps(obj))
#
# File ~/anaconda3/lib/python3.11/multiprocessing/reduction.py:51, in ForkingPickler.dumps(cls, obj, protocol)
#      48 @classmethod
#      49 def dumps(cls, obj, protocol=None):
#      50     buf = io.BytesIO()
# ---> 51     cls(buf, protocol).dump(obj)
#      52     return buf.getbuffer()
#
# File ~/anaconda3/lib/python3.11/multiprocessing/synchronize.py:101, in SemLock.__getstate__(self)
#     100 def __getstate__(self):
# --> 101     context.assert_spawning(self)
#     102     sl = self._semlock
#     103     if sys.platform == 'win32':
#
# File ~/anaconda3/lib/python3.11/multiprocessing/context.py:373, in assert_spawning(obj)
#     371 def assert_spawning(obj):
#     372     if get_spawning_popen() is None:
# --> 373         raise RuntimeError(
#     374             '%s objects should only be shared between processes'
#     375             ' through inheritance' % type(obj).__name__
#     376             )
#
# RuntimeError: Lock objects should only be shared between processes through inheritance

# %%
import multiprocessing
import random

# OHT 객체 클래스
class OHT:
    def __init__(self, id, position):
        self.id = id
        self.position = position

    def update_position(self, increment):
        self.position += increment

    def get_position(self):
        return self.position

# 작업을 실행할 프로세스 함수
def process_oht(oht, time_step):
    oht.update_position(time_step)  # 객체의 값을 수정
    return oht  # 수정된 객체를 리턴

# 병렬화 처리 함수
def parallel_oht_processing(oht_objects, time_step, process_count=4):
    with multiprocessing.Manager() as manager:
        # 공유 객체 리스트
        shared_oht_objects = manager.list(oht_objects)
        
        # multiprocessing.Pool로 프로세스 생성
        with multiprocessing.Pool(processes=process_count) as pool:
            updated_ohts = pool.map(process_oht, [(oht, time_step) for oht in shared_oht_objects])

        # 결과 출력
        for oht in updated_ohts:
            print(f"OHT {oht.id} final position: {oht.get_position()}")

if __name__ == "__main__":
    # 멀티프로세싱 시작 방법 설정
    multiprocessing.set_start_method('spawn')  # spawn 방식으로 프로세스 시작

    # OHT 객체 생성
    oht_objects = [OHT(i, random.randint(0, 100)) for i in range(10)]

    # 병렬 처리 실행
    time_step = 1.0
    parallel_oht_processing(oht_objects, time_step, process_count=4)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 37
#      33             print(f"OHT {oht.id} final position: {oht.get_position()}")
#      35 if __name__ == "__main__":
#      36     # 멀티프로세싱 시작 방법 설정
# ---> 37     multiprocessing.set_start_method('spawn')  # spawn 방식으로 프로세스 시작
#      39     # OHT 객체 생성
#      40     oht_objects = [OHT(i, random.randint(0, 100)) for i in range(10)]
#
# File ~/anaconda3/lib/python3.11/multiprocessing/context.py:247, in DefaultContext.set_start_method(self, method, force)
#     245 def set_start_method(self, method, force=False):
#     246     if self._actual_context is not None and not force:
# --> 247         raise RuntimeError('context has already been set')
#     248     if method is None and force:
#     249         self._actual_context = None
#
# RuntimeError: context has already been set

# %%
import multiprocessing
import time

class OHT:
    def __init__(self, id, position):
        self.id = id
        self.position = position

    def move(self):
        self.position += 1  # 간단히 이동시키기

    def get_position(self):
        return self.position

def process_oht(oht, queue):
    oht.move()  # OHT 이동
    print(oht)
    queue.put(oht)  # 결과를 Queue에 넣기

def update_oht_positions(oht_objects):
    
    
    # Queue 객체 생성
    queue = multiprocessing.Queue()
        # Pool을 사용하여 병렬 처리
    with multiprocessing.Pool(processes=4) as pool:
        for oht in oht_objects:
            pool.apply_async(process_oht, args=(oht, queue))  # OHT 처리
        pool.close()
        pool.join()
    
    # Queue에서 결과를 가져와 리스트로 반환
    updated_ohts = []
    while not queue.empty():
        updated_ohts.append(queue.get())
    return updated_ohts

if __name__ == '__main__':
    # OHT 객체 리스트 생성
    oht_objects = [OHT(i, i * 10) for i in range(10)]

    # OHT 객체 이동 업데이트
    updated_ohts = update_oht_positions(oht_objects)
    
    # 결과 출력
    for oht in updated_ohts:
        print(f"OHT {oht.id} final position: {oht.get_position()}")

# %%
import ray

ray.init()

class MyClass:
    def __init__(self, name):
        self.name = name

    @ray.remote
    def say_hello(self):
        return f"Hello from {self.name}"

# 객체 생성
obj = MyClass("Ray")

# 병렬 실행
futures = [obj.say_hello.remote(obj) for _ in range(10)]
results = ray.get(futures)

print(results)

ray.shutdown()
# Out:
# 2025-01-22 08:27:02,942	INFO worker.py:1821 -- Started a local Ray instance.
# ['Hello from Ray', 'Hello from Ray', 'Hello from Ray', 'Hello from Ray', 'Hello from Ray', 'Hello from Ray', 'Hello from Ray', 'Hello from Ray', 'Hello from Ray', 'Hello from Ray']

# %%
import ray

ray.init()

class MyClass:
    def __init__(self, name):
        self.name = name

    @ray.remote
    def say_hello(self):
        return f"Hello from {self.name}"

# 객체 생성
obj = MyClass("Ray")

# 병렬 실행 시, 객체를 전달
futures = [obj.say_hello.remote() for _ in range(10)]
results = ray.get(futures)

print(results)

ray.shutdown()
# Out:
# 2025-01-22 08:29:35,041	INFO worker.py:1821 -- Started a local Ray instance.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 17
#      14 obj = MyClass("Ray")
#      16 # 병렬 실행 시, 객체를 전달
# ---> 17 futures = [obj.say_hello.remote() for _ in range(10)]
#      18 results = ray.get(futures)
#      20 print(results)
#
# Cell In[2], line 17, in <listcomp>(.0)
#      14 obj = MyClass("Ray")
#      16 # 병렬 실행 시, 객체를 전달
# ---> 17 futures = [obj.say_hello.remote() for _ in range(10)]
#      18 results = ray.get(futures)
#      20 print(results)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/remote_function.py:156, in RemoteFunction.__init__.<locals>._remote_proxy(*args, **kwargs)
#     154 @wraps(function)
#     155 def _remote_proxy(*args, **kwargs):
# --> 156     return self._remote(
#     157         serialized_runtime_env_info=self._serialized_base_runtime_env_info,
#     158         args=args,
#     159         kwargs=kwargs,
#     160         **self._default_options,
#     161     )
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/util/tracing/tracing_helper.py:310, in _tracing_task_invocation.<locals>._invocation_remote_span(self, args, kwargs, *_args, **_kwargs)
#     308     if kwargs is not None:
#     309         assert "_ray_trace_ctx" not in kwargs
# --> 310     return method(self, args, kwargs, *_args, **_kwargs)
#     312 assert "_ray_trace_ctx" not in kwargs
#     313 tracer = _opentelemetry.trace.get_tracer(__name__)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/remote_function.py:504, in RemoteFunction._remote(self, args, kwargs, serialized_runtime_env_info, **task_options)
#     501 if self._decorator is not None:
#     502     invocation = self._decorator(invocation)
# --> 504 return invocation(args, kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/remote_function.py:462, in RemoteFunction._remote.<locals>.invocation(args, kwargs)
#     460     list_args = []
#     461 else:
# --> 462     list_args = ray._private.signature.flatten_args(
#     463         self._function_signature, args, kwargs
#     464     )
#     466 if worker.mode == ray._private.worker.LOCAL_MODE:
#     467     assert (
#     468         not self._is_cross_language
#     469     ), "Cross language remote function cannot be executed locally."
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/signature.py:110, in flatten_args(signature_parameters, args, kwargs)
#     108     reconstructed_signature.bind(*args, **kwargs)
#     109 except TypeError as exc:  # capture a friendlier stacktrace
# --> 110     raise TypeError(str(exc)) from None
#     111 list_args = []
#     112 for arg in args:
#
# TypeError: missing a required argument: 'self'

# %%
import ray

# 1. 클래스를 ray.actor로 병렬화
@ray.remote
class MyClass:
    def __init__(self, value):
        self.value = value

    def increment(self, x):
        self.value += x
        return self.value

    def get_value(self):
        return self.value

# 2. `actor` 인스턴스 생성
ray.init(ignore_reinit_error=True)  # Ray 클러스터 초기화
my_class_instance = MyClass.remote(10)  # `MyClass` 인스턴스를 Ray에서 실행

# 3. 메서드를 병렬로 실행
future1 = my_class_instance.increment.remote(5)  # `increment` 메서드를 병렬로 실행
future2 = my_class_instance.increment.remote(10)  # `increment` 메서드를 병렬로 실행

# 4. 결과를 가져옴
result1 = ray.get(future1)  # 병렬 실행된 결과 가져오기
result2 = ray.get(future2)

print("Result 1:", result1)  # 15
print("Result 2:", result2)  # 20

# 5. 클래스 상태 확인
value = ray.get(my_class_instance.get_value.remote())  # 클래스의 값을 확인
print("Final value:", value)  # 20

# Ray 클러스터 종료
ray.shutdown()
# Out:
# 2025-01-23 01:45:00,856	INFO worker.py:1821 -- Started a local Ray instance.
# Result 1: 15
# Result 2: 25
# Final value: 25

# %%
@ray.remote
class Counter:
    def __init__(self, start=0):
        self.value = start

    def increment(self, x):
        self.value += x
        return self.value

    def get_value(self):
        return self.value

# `Counter` 클래스를 병렬로 실행하는 예시
counter = Counter.remote(0)  # 초기 값 0으로 `Counter` 인스턴스 생성

# 병렬로 실행된 메서드
futures = [counter.increment.remote(i) for i in range(5)]
results = ray.get(futures)

print("Increment results:", results)  # [0, 1, 3, 6, 10]

# 최종 값 확인
final_value = ray.get(counter.get_value.remote())
print("Final value:", final_value)  # 10

# Ray 클러스터 종료
ray.shutdown()
# Out:
# 2025-01-23 01:47:47,639	INFO worker.py:1821 -- Started a local Ray instance.
# Increment results: [0, 1, 3, 6, 10]
# Final value: 10

# %%
#import libraries
import numpy as np
import random
import networkit as nk
import json
import threading
import ray

def compress_data(data):
    json_data = json.dumps(data).encode('utf-8')
    compressed_data = gzip.compress(json_data)
    return base64.b64encode(compressed_data).decode('utf-8')

#node 클래스
class node():
    def __init__(self, id, coord):
        #node id
        self.id = id
        #node 좌표 (2차원)
        self.coord = np.array(coord)
        #노드로 들어오는 edge들 => intersection 쪽 충돌 감지 위해 필요
        self.incoming_edges = []
        self.outgoing_edges = []
        self.OHT = None
        
class edge():
    def __init__(self, source, dest, length, max_speed):
        self.id = None
        #Edge source
        self.source = source
        source.outgoing_edges.append(self)
        #edge target(destination)
        self.dest = dest
        dest.incoming_edges.append(self)
        #edge length
        self.length = length
        #edge의 방향 벡터
        self.unit_vec = (self.dest.coord - self.source.coord) / self.length
        #max speed -> 전부 1500
        self.max_speed = max_speed
        #edge 위에 존재하는 OHT 리스트
        self.OHTs = []  # Use a set to track OHTs
        
        self.count = 0  # OHT가 이 Edge에 진입한 횟수
        # self.speeds = []  # 최근 time_window 동안의 속도 저장
        self.avg_speed = max_speed  # time_window 내 평균 속도
        self.entry_exit_records = {} 
            
    def calculate_avg_speed(self, time_window, current_time):
        all_relevant_records = []
        total_time_covered = 0  # 기록된 총 시간
        total_distance_covered = 0  # 기록된 총 거리

        for oht_id, records in self.entry_exit_records.items():
            # time_window 내의 유효한 기록 필터링
            relevant_records = [
                (entry, exit) for entry, exit in records
                if exit is not None and entry >= current_time - time_window
            ]
            all_relevant_records.extend(relevant_records)

        # 기록된 각 구간의 속도와 이동 거리 계산
        for entry, exit in all_relevant_records:
            travel_time = exit - entry
            if travel_time > 0.01:  # 최소 이동 시간
                speed = self.length / travel_time
                total_time_covered += travel_time
                total_distance_covered += speed * travel_time

        # time_window에서 기록되지 않은 시간 간격 계산
        uncovered_time = time_window - total_time_covered
        if uncovered_time > 0:
            total_distance_covered += self.max_speed * uncovered_time

        # 전체 평균 속도 계산
        avg_speed = total_distance_covered / time_window
        return min(avg_speed, self.max_speed)
    
class port():
    def __init__(self, name, from_node, to_node, from_dist):
        #port name
        self.name = name
        #포트 위치 설정을 위한 from_node
        self.from_node = from_node
        #포트 to_node
        self.to_node = to_node
        #from_node로부터의 거리
        self.from_dist = from_dist
        #포트가 존재하는 edge
        self.edge = None

        
class OHT():
    def __init__(self, id, from_node, from_dist, speed, acc, rect, path):
        self.id = id #oht id
        self.from_node = from_node #oht 위치를 계산하기 위한 from_node
        self.from_dist = from_dist #from_node로부터의 거리
        
        self.path = path #oht가 움직일 경로, (Edge들의 List)
        self.path_to_start = [] #start port로 갈 때 경로
        self.path_to_end = [] #end port로 갈 때 경로
        self.edge = path.pop(0) if path else None #OHT가 위치한 edge
        
        self.pos = (
            self.from_node.coord + self.edge.unit_vec * self.from_dist
            if self.edge else self.from_node.coord
        ) #OHT의 위치 계산
        self.speed = speed #속도
        self.acc = acc #가속도
        self.rect = rect #충돌 감지 범위
        
        self.edge.OHTs.append(self) if self.edge else None #OHT가 위치한 edge의 OHT list에 self 추가 
        
        
        self.start_port = None #출발 포트
        self.end_port = None #도착 포트
        self.wait_time = 0 #loading / unloading시 기다리는 시간
        
        self.status = "IDLE" #STATUS, IDLE / TO_START / TO_END
    
    #위치 계산 method
    def cal_pos(self, time_step):
        self.from_dist = self.from_dist + self.speed * time_step + 1/2 * self.acc * time_step**2
        self.pos = self.from_node.coord + self.edge.unit_vec * self.from_dist if self.edge != None else self.from_node.coord

    #move, 매 time step 마다 실행            
    def move(self, time_step, current_time):
        #node 위에만 있을 떄?? 이거 사실 잘 모르겠구 에러 나는거 해결하려고 이거저거하다가 넣었습니다
        
        if self.status == 'ON_REMOVED':
            self.speed = 0
            self.acc = 0
            return
        
        if not self.edge:
            # print('no edge', self.edge)
            self.speed = 0
            self.acc = 0
            if len(self.path) != 0:
                self.from_node.OHT = None
            return

        #end port 도착하면 wait time 동안 기다리기
        if self.wait_time > 0:
            self.wait_time -= time_step
            if self.wait_time <= 0:  # 대기 시간이 끝나면
                self.wait_time = 0
                if self.status == 'STOP_AT_START':
                    self.status = 'TO_END'
                elif self.status == 'STOP_AT_END':
                    self.status = 'IDLE'
            return  # 대기 중이므로 이동하지 않음
        
        #충돌 감지
        self.col_check(time_step)
        
        # ori_dist_1 = copy.copy(self.from_dist)
        
        #다음 스텝에 움직인 거리 계산
        # self.from_dist = self.from_dist + self.speed * time_step + 1/2 * self.acc * time_step**2
        
        #만약 도착했다면 멈추기 
        if self.is_arrived():
            self.arrive()
            return
            
        #From_dist가 edge의 length보다 길어지면 다음 엣지로 업데이트    
        while (self.from_dist > self.edge.length):
            
            self.from_node = self.edge.dest #from_node를 Edge dest로 업데이트

            self.from_dist = self.from_dist - self.edge.length #from_dist도 업데이트
            
            if self.edge:
                try:
                     #원래 엣지에서 현재 OHT 제거
                    if len(self.path) > 0:
                # before_edge = copy.copy(self.edge)
                
                        exit_record = self.edge.entry_exit_records.get(self.id, [])
                        if exit_record and exit_record[-1][1] is None:
                            exit_record[-1] = (exit_record[-1][0], current_time)
                        self.edge.entry_exit_records[self.id] = exit_record
                                            
                        self.edge.OHTs.remove(self)
                        
                        self.edge = self.path.pop(0) #다음 엣지로 업데이트
                        
                        if self not in self.edge.OHTs:
                            self.edge.OHTs.append(self) #다음 엣지 안에 OHT 추가
                            self.edge.count += 1
                            if self.id not in self.edge.entry_exit_records:
                                self.edge.entry_exit_records[self.id] = []
                                self.edge.entry_exit_records[self.id].append((current_time, None))
                            
                    else:
                        self.speed = 0
                        self.acc = 0
                        self.from_dist = self.edge.length
                        self.from_node = self.edge.source
                        return
                except:
                    print('update error : ', self.edge.source.id)

  
            if self.is_arrived():
                self.arrive()
                return
            

        if self.is_arrived():
            self.arrive()
            return
            
        #가속도 고려해서 스피드 계산
        self.speed = min(max(self.speed + self.acc * time_step, 0), self.edge.max_speed)
        
    def is_arrived(self):

        #start_port 혹은 end port에 도착했는지 확인, OHT와 port가 같은 엣지, 같은 from_node에 있는지, OHT의 from_dist가 port의 From_dist보다 커지는지
        if self.status == "TO_START":
            return (self.start_port 
                    and self.start_port.from_node == self.from_node and self.start_port.to_node == self.edge.dest
                    and self.from_dist >= self.start_port.from_dist)
        elif self.status == "TO_END":
            return (self.end_port 
                    and self.end_port.from_node == self.from_node and self.end_port.to_node == self.edge.dest
                    and self.from_dist >= self.end_port.from_dist)
        
    def arrive(self):
        # print('arrived at', self.pos, self.from_node.id)
        # self.from_dist = self.end_port.from_dist
        # self.pos = self.from_node.coord + self.edge.unit_vec * self.end_port.from_dist
        # self.speed = 0
        # self.acc = 0
        # self.wait_time = 500
        # self.end_port = None
        # print('arrived rail : ', self.edge.OHTs, self in self.edge.OHTs)
        
        #도착하면 port위치로 OHT를 고정하고, 속도, 가속도 0으로 정지, wait_time 5초 주기
        if self.status == "TO_START":
            # print(f"OHT {self.id} arrived at start port: {self.start_port.name}")
            self.from_dist = self.start_port.from_dist
            self.pos = self.from_node.coord + self.edge.unit_vec * self.start_port.from_dist
            self.speed = 0
            self.acc = 0
            self.wait_time = 5
            
            self.status = "STOP_AT_START"
            self.path = self.path_to_end  # 경로를 end_port로 변경
            self.path_to_start = []  # start_port 경로 초기화
            self.start_port = None

        elif self.status == "TO_END":
            
            self.from_dist = self.end_port.from_dist
            self.pos = self.from_node.coord + self.edge.unit_vec * self.end_port.from_dist
            self.speed = 0
            self.acc = 0
            self.wait_time = 5
            self.end_port = None
            # print(f"OHT {self.id} arrived at end port: {self.end_port.name}")
            self.status = "STOP_AT_END"
            self.path = []
            self.path_to_end = []  # end_port 경로 초기화

        else:
            print(f"OHT {self.id} is idle.")

    
    #충돌 감지
    def col_check(self, time_step):
        OHTs = self.edge.OHTs
        
        #같은 edge상에 있는 OHT들과 거리 비교
        for oht in OHTs:
            if oht is not self:  # 자신과의 비교를 피함
                dist_diff = oht.from_dist - self.from_dist
                if 0 < dist_diff < self.rect:  # rect 길이보다 가까워지면
                    # 가속도를 줄여 충돌 방지
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
                
        if self.edge.dest.OHT is not None:
            dist_diff = self.edge.length - self.from_dist
            if 0 < dist_diff < self.rect:  # rect 길이보다 가까워지면
                # 가속도를 줄여 충돌 방지
                self.acc = -self.speed/time_step # 속도 감소 또는 정지
                return
         
         #다음 엣지에 있는 OHT들 중 제일 마지막에 있는 친구와 거리 비교       
        if len(self.path) > 0:
            next_edge = self.path[0]
            try:
                last_oht = next_edge.OHTs[-1]
                rem_diff = self.edge.length - self.from_dist
                dist_diff = last_oht.from_dist + rem_diff
                if 0 < dist_diff < self.rect:
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
            except:
                pass
        
        #다음 노드에서 들어오는 엣지들 상에 있는 OHT들과 충돌 비교 (intersection이 무조건 최대 2개임)    
        incoming_edges = [
            edge for edge in self.edge.dest.incoming_edges
            if edge != self.edge # Edges leading to the same destination node
        ]
        
        if len(incoming_edges) == 1: #만약 intersection이 있따면 (다른 edge가 있다면)
            rem_diff = self.edge.length - self.from_dist #현재 자기 자신의 엣지 상에서 남은 거리 계산
            try:
                other_oht = incoming_edges[0].OHTs[0]
                other_diff= other_oht.edge.length - other_oht.from_dist #다른 엣지 위 제일 앞에 있는 OHT의 남은 거리 계산
                dist_diff = rem_diff + other_diff #두 OHT간의 거리 계산
                if 0 < dist_diff < 3 * self.rect and rem_diff > other_diff: #더 가까운 OHT가 먼저 움직이도록, 나머지는 정지. 3*rect로 잡은 이유는 그래야 좀 더 미리 멈춰서
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
                elif rem_diff == other_diff and self.id > other_oht.id: #혹시나 거리가 같다면 OHT id가 더 빠른 아이가 움직이도록
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
            except:
                pass
        if len(self.path) > 0:
            outgoing_edges = [
                edge for edge in self.edge.dest.outgoing_edges
                if edge != self.path[0] # Edges leading to the same destination node
            ]
        
            if len(outgoing_edges) == 1: #만약 intersection이 있따면 (다른 edge가 있다면)
                rem_diff = self.edge.length - self.from_dist #현재 자기 자신의 엣지 상에서 남은 거리 계산
                try:
                    other_oht = outgoing_edges[0].OHTs[0]
                    other_diff= other_oht.from_dist #다른 엣지 위 제일 앞에 있는 OHT의 남은 거리 계산
                    dist_diff = rem_diff + other_diff #두 OHT간의 거리 계산
                    if 0 < dist_diff <  self.rect: #더 가까운 OHT가 먼저 움직이도록, 나머지는 정지. 3*rect로 잡은 이유는 그래야 좀 더 미리 멈춰서
                        self.acc = -self.speed/time_step # 속도 감소 또는 정지
                        return
                except:
                    pass
        
        #충돌 위험이 없다면 다시 원래 max speed로 가속
        self.acc = (self.edge.max_speed - self.speed) / time_step
        

class AMHS:
    def __init__(self, nodes, edges, ports, num_OHTs, max_jobs, job_list = [], oht_list = []):
        """
        AMHS 초기화.
        - nodes: node 클래스 객체 리스트
        - edges: edge 클래스 객체 리스트
        - num_OHTs: 초기 OHT 수
        - max_jobs: 작업 큐의 최대 크기
        """
        # self.graph = nx.DiGraph()
        # self.original_graph=nx.DiGraph()
        
        self.graph = nk.Graph(directed=True, weighted=True)  # Directed weighted graph
        
        self.nodes = nodes  # node 객체 리스트
        for node in nodes:
            node.OHT = None
        self.edges = edges  # edge 객체 리스트
        for edge in edges:
            edge.OHTs = []
            edge.count = 0
            edge.avg_speed = edge.max_speed
        self.ports = ports #port list
        for p in ports:
            p.edge = self.get_edge(p.from_node, p.to_node)
        
        self.OHTs = []
        
        if job_list != []:
            self.job_queue = [[self.get_port(q[0]), self.get_port(q[1])] for q in job_list]
        else:
            self.job_queue = []
        self.max_jobs = max_jobs
        
        self.node_id_map = {}
        
        self.time_step=0.01
        
                
        self.simulation_running = False  # 시뮬레이션 상태 관리
        self.stop_simulation_event = threading.Event()  # 스레드 이벤트 처리

        # 그래프 생성
        self._create_graph()
        
        self.original_graph = nk.Graph(self.graph)

        # 초기 OHT 배치
        if oht_list != []:
            self.set_initial_OHTs(oht_list)
        else:
            self.initialize_OHTs(num_OHTs)
        
        self.apsp = nk.distance.APSP(self.graph)
        self.apsp.run()
        
        self.original_apsp = nk.distance.APSP(self.original_graph)
        self.original_apsp.run()
        


    def _create_graph(self):
        """NetworkX 그래프를 nodes와 edges로 생성."""
        for i, node in enumerate(self.nodes):
            self.graph.addNode()  # Add node to the graph
            self.node_id_map[node.id] = i
        
        for edge in self.edges:
            u = self.node_id_map[edge.source.id]  # Get index for source node
            v = self.node_id_map[edge.dest.id]    # Get index for destination node
            self.graph.addEdge(u, v, edge.length)
            # edge.dest.incoming_edges.append(edge) #각 node마다 incoming edge 추가
            # edge.source.outgoing_edges.append(edge)

    def initialize_OHTs(self, num_OHTs):
        available_nodes = self.nodes.copy()
        
        for i in range(num_OHTs):
            # 노드 중에서 랜덤 선택 (노드 소진 시 다시 전체에서 랜덤)
            if not available_nodes:
                available_nodes = self.nodes.copy()  # 노드 리스트 재생성
            
            start_node = random.choice(available_nodes)
            available_nodes.remove(start_node)  # 선택한 노드는 제거
            
            oht = OHT(
                id=i,
                from_node=start_node,
                from_dist=0,
                speed=0,
                acc=0,
                rect=1000,  # 충돌 판정 거리
                path=[],
            )
            start_node.OHT = oht
            self.OHTs.append(oht)
            
    def set_initial_OHTs(self, oht_list):
        i = 0
        for start_node in oht_list:  
            start_node = self.get_node(start_node)
            oht = OHT(
                id=i,
                from_node=start_node,
                from_dist=0,
                speed=0,
                acc=0,
                rect=1000,  # 충돌 판정 거리
                path=[],
            )
            start_node.OHT = oht
            self.OHTs.append(oht)
            i = i+1
    
    def set_oht(self, oht_origin, oht_new):
        oht_origin.from_node = self.get_node(oht_new['from_node'])
        oht_origin.from_dist = oht_new['from_dist']
        oht_origin.edge = self.get_edge(oht_new['source'], oht_new['dest'])
        if oht_origin.edge:
            if oht_origin not in oht_origin.edge.OHTs:
                oht_origin.edge.OHTs.append(oht_origin)
        try:
            if not self.graph.hasEdge(self.node_id_map[oht_new['source']], self.node_id_map[oht_new['dest']]):
                oht_origin.speed = 0
                oht_origin.acc = 0
                oht_origin.status = 'ON_REMOVED'
                oht_origin.cal_pos(self.time_step)
                return
        except:
            print('is here?', oht_new['source'])
  
            
        oht_origin.speed = oht_new['speed']
        oht_origin.status = oht_new['status']
        
        if oht_origin.status == 'ON_REMOVED':
            if oht_origin.start_port:
                oht_origin.status = "TO_START"
            elif oht_origin.end_port:
                oht_origin.status = "TO_END"
            else:
                oht_origin.status = "IDLE"
                
        oht_origin.cal_pos(self.time_step)
             
        
        oht_origin.start_port = self.get_port(oht_new['startPort']) if oht_new['startPort'] else None
        oht_origin.end_port = self.get_port(oht_new['endPort']) if oht_new['endPort'] else None
        oht_origin.wait_time = oht_new['wait_time']
                
        if oht_origin.start_port != None:
            if oht_origin.edge:
                path_edges_to_start = self.get_path_edges(oht_origin.edge.dest.id, oht_origin.start_port.to_node.id)
                path_edges_to_start = self._validate_path(path_edges_to_start)

            else:
                path_edges_to_start = self.get_path_edges(oht_origin.from_node.id, oht_origin.start_port.to_node.id)
                path_edges_to_start = self._validate_path(path_edges_to_start)
            oht_origin.path_to_start = path_edges_to_start[:]
        
        # elif oht_origin.status == "TO_END":
        if oht_origin.end_port != None:
            if oht_origin.status == "TO_END" or oht_origin.status == 'STOP_AT_START':
                if oht_origin.edge:
                    path_edges_to_end = self.get_path_edges(oht_origin.edge.dest.id, oht_origin.end_port.to_node.id)
                    path_edges_to_end = self._validate_path(path_edges_to_end)
                else:
                    path_edges_to_end = self.get_path_edges(oht_origin.from_node.id, oht_origin.end_port.to_node.id)
                    path_edges_to_end = self._validate_path(path_edges_to_end)
            else:
                path_edges_to_end = self.get_path_edges(oht_origin.start_port.to_node.id, oht_origin.end_port.to_node.id)

            oht_origin.path_to_end = path_edges_to_end
        
        if oht_origin.status == "TO_START":
            oht_origin.path = path_edges_to_start[:]
        elif oht_origin.status == "TO_END" or oht_origin.status == "STOP_AT_START":
            oht_origin.path = path_edges_to_end[:]
        else:
            oht_origin.path = []

    def modi_edge(self, source, dest, oht_positions, is_removed):
        if is_removed:
            removed_edge = self.get_edge(source, dest)
            try:       
                self.graph.removeEdge(self.node_id_map[source], self.node_id_map[dest])
                self.apsp = nk.distance.APSP(self.graph)
                self.apsp.run()
            except:
                print(source, dest)
        else:
            edge_to_restore = next((e for e in self.edges if e.source.id == source and e.dest.id == dest), None)
            if edge_to_restore:
                self.graph.addEdge(self.node_id_map[source], self.node_id_map[dest], edge_to_restore.length)
                self.apsp = nk.distance.APSP(self.graph)
                self.apsp.run()
            else:
                print(f"Rail {source} -> {dest} not found in original edges.")
        
    
    def reinitialize_simul(self, oht_positions, edge_data):
        for edge in self.edges:
            edge.OHTs.clear()
            edge.entry_exit_records.clear()
        
        for oht in oht_positions:
            oht_in_amhs = self.get_oht(oht['id'])
            self.set_oht(oht_in_amhs, oht)
            
        edge_map = {f"{edge.source.id}-{edge.dest.id}": edge for edge in self.edges}
    
        for edge_info in edge_data:
            edge_key = f"{edge_info['from']}-{edge_info['to']}"
            if edge_key in edge_map:
                edge = edge_map[edge_key]
                edge.count = edge_info.get('count', 0)
                edge.avg_speed = edge_info.get('avg_speed', 0)
            
        for edge in self.edges:
            edge.OHTs.sort(key = lambda oht : -oht.from_dist)
    
    def generate_job(self):
        """모든 OHT가 Job을 갖도록 작업 생성."""
        for _ in range(50):
            start_port = random.choice(self.ports)
            end_port = random.choice(self.ports)
            while start_port == end_port:  # 시작/목적 포트가 같지 않도록 보장
                end_port = random.choice(self.ports)
            self.job_queue.append((start_port, end_port))
            

    def assign_jobs(self):
        """모든 OHT가 Job을 갖도록 작업 할당."""
        closest_oht = None
        closest_dist = 1e100
        for oht in self.OHTs:
            if not oht.path and self.job_queue and oht.status == 'IDLE':  # OHT가 Idle 상태이고 Job Queue가 비어있지 않은 경우
                start_port, end_port = self.job_queue.pop(0)
                dist = self.get_path_distance(oht.from_node.id, start_port.from_node.id)
                if dist < closest_dist:
                    closest_dist = dist
                    closest_oht = oht
        
        if closest_oht:
            oht = closest_oht
            oht.start_port = start_port
            # oht.start_port = next((port for port in self.ports if port.name == 'DIE0137_Port3'), None)
            oht.end_port = end_port
            oht.status = "TO_START"

            # # Start로 이동하는 경로
            if oht.edge:
                path_edges_to_start = self.get_path_edges(oht.edge.dest.id, start_port.to_node.id)
            else:
                path_edges_to_start = self.get_path_edges(oht.from_node.id, start_port.to_node.id)
            oht.path_to_start = path_edges_to_start[:]
            
            # # End로 이동하는 경로
            # start_edge = [self.get_edge(start_port.from_node.id, start_port.to_node.id)]
            path_edges_to_end = self.get_path_edges(start_port.to_node.id, end_port.to_node.id)
            oht.path_to_end = path_edges_to_end

            # # 전체 경로를 OHT에 설정
            oht.path = path_edges_to_start[:]
            
            # print(oht.path)

            # Assign the first edge in the path to the OHT's edge
            if oht.path:
                if not oht.edge:
                    oht.edge = oht.path.pop(0)
                    oht.from_node.OHT = None
                    if oht not in oht.edge.OHTs:
                        oht.edge.OHTs.append(oht)
                        
    # def update_edge_metrics(self, current_time, time_window):
    #     for edge in self.edges:
    #         edge.avg_speed = edge.calculate_avg_speed(time_window, current_time)


    def get_node(self, node_id):
        """node id로 node 객체 반환."""
        return next((node for node in self.nodes if node.id == node_id), None)

    def get_edge(self, source_id, dest_id):
        """source와 dest ID로 edge 객체 반환."""
        return next(
            (e for e in self.edges if e.source.id == source_id and e.dest.id == dest_id), 
            None
        )
        
    def get_path_distance(self, source_id, dest_id):
        try:
            source_idx = self.node_id_map[source_id]
            dest_idx = self.node_id_map[dest_id]

            
            dist = self.apsp.getDistance(source_idx, dest_idx)      
            return dist
        except:
            try:
                source_idx = self.node_id_map[source_id]
                dest_idx = self.node_id_map[dest_id]            

                dist = self.original_apsp.getDistance(source_idx, dest_idx)                
                return dist
            except:
                print(f"No path found even in original_graph for {source_id} -> {dest_id}.")
                return float('inf')
        

    def get_path_edges(self, source_id, dest_id):
        """source와 dest ID로 최단 경로 에지 리스트 반환."""
        try:
            source_idx = self.node_id_map[source_id]
            dest_idx = self.node_id_map[dest_id]
            
            dijkstra = nk.distance.Dijkstra(self.graph, source_idx, storePaths=True, storeNodesSortedByDistance=False, target=dest_idx)
            dijkstra.run()

            path = dijkstra.getPath(dest_idx)
            
            return [
                self.get_edge(self.nodes[path[i]].id, self.nodes[path[i+1]].id)
                for i in range(len(path) - 1)
            ]
        except:
            try:
                source_idx = self.node_id_map[source_id]
                dest_idx = self.node_id_map[dest_id]
                
                dijkstra = nk.distance.Dijkstra(self.original_graph, source_idx, storePaths=True, storeNodesSortedByDistance=False, target=dest_idx)
                dijkstra.run()

                path = dijkstra.getPath(dest_idx)
                
                return [
                    self.get_edge(self.nodes[path[i]].id, self.nodes[path[i+1]].id)
                    for i in range(len(path) - 1)
                ]
            except:
                print(f"No path found even in original_graph for {source_id} -> {dest_id}.")
                return []
    
    def get_oht(self, oht_id):
        return next((oht for oht in self.OHTs if oht.id == oht_id), None)
    
    def get_port(self, port_name):
        return next((port for port in self.ports if port.name == port_name), None)

    def _validate_path(self, path):
        """
        현재 경로에 지워진 edge가 포함된 경우, 해당 edge 직전까지만 반환합니다.

        Parameters:
            path (list): 현재 경로 (edge 객체 리스트)

        Returns:
            list: 수정된 경로 (지워진 edge 직전까지만 포함)
        """
        valid_path = []
        for edge in path:
            if self.graph.hasEdge(self.node_id_map[edge.source.id], self.node_id_map[edge.dest.id]):  # edge가 그래프에 존재하는 경우
                valid_path.append(edge)
            else:
                break  # 지워진 edge를 발견하면 직전까지만 반환
        return valid_path    
        
    def start_simulation(self, current_time, max_time = 4000, time_step = 0.01):
        
        
        count = 0
        edge_metrics_cache = {}  # Cache for edge metrics to track changes
        

        while current_time < max_time:
            if count % 5 == 0:
                self.generate_job()
                self.assign_jobs()

            # Move all OHTs
            oht_positions = []
            
            # self.OHTs = self.update_oht_positions(self.OHTs, current_time, time_step)
            for oht in self.OHTs:
                oht.move(time_step, current_time)
                
            ray.put(self.edges)

            self.edges = self.update_edge_metrics(current_time, time_window=500)
            
            for oht in self.OHTs:
                oht.cal_pos(time_step)
                

            if count % 5 == 0:
                for oht in self.OHTs:
                    oht_positions.append({
                        'id': oht.id,
                        'x': oht.pos[0],
                        'y': oht.pos[1],
                        'source': oht.edge.source.id if oht.edge else None,
                        'dest': oht.edge.dest.id if oht.edge else None,
                        'speed': oht.speed,
                        'status': oht.status,
                        'startPort': oht.start_port.name if oht.start_port else None,
                        'endPort': oht.end_port.name if oht.end_port else None,
                        'from_node': oht.from_node.id if oht.from_node else None,
                        'from_dist': oht.from_dist,
                        'wait_time': oht.wait_time
                    })

                updated_edges = []
                for edge in self.edges:
                    key = f"{edge.source.id}-{edge.dest.id}"
                    new_metrics = {"count": edge.count, "avg_speed": edge.avg_speed}
                    if edge_metrics_cache.get(key) != new_metrics:
                        edge_metrics_cache[key] = new_metrics
                        updated_edges.append({
                            "from": edge.source.id,
                            "to": edge.dest.id,
                            **new_metrics
                        })

                payload = {
                    'time': current_time,
                    'oht_positions': oht_positions,
                    'edges': updated_edges
                }
                
                compressed_payload = compress_data(payload)

            # Increment time
            current_time += time_step
            count += 1

        self.simulation_running = False
        print('Simulation ended')
        


import random
import json
import time
import threading
import math
import pandas as pd
import io



# Load the layout data
with open('./flask_backend/fab_oht_layout_2nd.json') as f:
    layout_data = json.load(f)



nodes = [node(n['id'], [n['x'], n['y']]) for n in layout_data['nodes']]
edges = [
    edge(
        source=next(node for node in nodes if node.id == rail['from']),
        dest=next(node for node in nodes if node.id == rail['to']),
        length=math.sqrt(
            (next(node for node in nodes if node.id == rail['to']).coord[0] -
             next(node for node in nodes if node.id == rail['from']).coord[0])**2 +
            (next(node for node in nodes if node.id == rail['to']).coord[1] -
             next(node for node in nodes if node.id == rail['from']).coord[1])**2
        ),
        max_speed=1500  # Default speed = 0.01
    )
    for rail in layout_data['rails']
]

ports = [
    port(
        name = p['name'], 
        from_node = next((node for node in nodes if node.id == p['from_node'])),
        to_node = next((node for node in nodes if node.id == p['to_node'])),
        from_dist = p['distance']
    )
    for p in layout_data['ports']
]


ray.init(num_cpus=4,ignore_reinit_error=True)  # Ray 클러스터 초기화
max_time = 4000
    
amhs = AMHS(nodes=nodes, edges=edges, ports=ports, num_OHTs=500, max_jobs=1000)

ray.put(amhs.nodes)
# ray.put(amhs)
# ray.get(amhs.start_simulation.remote(current_time=0, max_time=4000))
ray.shutdown()  # Ray 클러스터 종료
# Out:
# 2025-01-23 04:03:56,090	INFO worker.py:1821 -- Started a local Ray instance.

# %%
import numpy as np
import random
import networkit as nk
import json
import threading
import ray

class node():
    def __init__(self, id, coord):
        self.id = id
        self.coord = np.array(coord)
        self.incoming_edges = []
        self.outgoing_edges = []
        self.OHT = None        
    
    def add_incoming_edge(self, edge):
        self.incoming_edges.append(edge)

    def add_outgoing_edge(self, edge):
        self.outgoing_edges.append(edge)
        
class edge():
    def __init__(self, source, dest, length, max_speed):
        self.id = None
        self.source = source
        self.dest = dest
        self.length = length
        self.unit_vec = (self.dest.coord - self.source.coord) / self.length
        self.max_speed = max_speed
        self.OHTs = []  # Use a set to track OHTs        
        self.count = 0  # OHT가 이 Edge에 진입한 횟수
        self.avg_speed = max_speed  # time_window 내 평균 속도
        self.entry_exit_records = {}        
        source.add_incoming_edge(self)
        dest.add_outgoing_edge(self)
        
class port():
    def __init__(self, name, from_node, to_node, from_dist):
        #port name
        self.name = name
        self.from_node = from_node
        self.to_node = to_node
        self.from_dist = from_dist
        self.edge = None


class AMHS:
    def __init__(self, nodes, edges, ports, num_OHTs, max_jobs, job_list = [], oht_list = []):        
        self.graph = nk.Graph(directed=True, weighted=True)  # Directed weighted graph
        
        self.nodes = nodes  # node 객체 리스트
        for node in nodes:
            node.OHT = None
        self.edges = edges  # edge 객체 리스트
        for edge in edges:
            edge.OHTs = []
            edge.count = 0
            edge.avg_speed = edge.max_speed
        self.ports = ports #port list
        for p in ports:
            p.edge = self.get_edge(p.from_node, p.to_node)
        self.OHTs = []
        if job_list != []:
            self.job_queue = [[self.get_port(q[0]), self.get_port(q[1])] for q in job_list]
        else:
            self.job_queue = []
        self.max_jobs = max_jobs
        
        self.node_id_map = {}
        
        self.edge_id_map = {}
        
        self.time_step=0.01
        
                
        # self.simulation_running = False  # 시뮬레이션 상태 관리
        # self.stop_simulation_event = threading.Event()  # 스레드 이벤트 처리

        # 그래프 생성
        # self.create_graph()
        
        # self.original_graph = nk.Graph(self.graph)

        # self.apsp = nk.distance.APSP(self.graph)
        # self.apsp.run()
        
        # self.original_apsp = nk.distance.APSP(self.original_graph)
        # self.original_apsp.run()


    def create_graph(self):
        """NetworkX 그래프를 nodes와 edges로 생성."""
        for i, node in enumerate(self.nodes):
            self.graph.addNode()  # Add node to the graph
            self.node_id_map[node.id] = i
        
        for i, edge in enumerate(self.edges):
            self.edge_id_map[i] = edge
            edge.id = i
        
        for edge in self.edges:
            u = self.node_id_map[edge.source.id]  # Get index for source node
            v = self.node_id_map[edge.dest.id]    # Get index for destination node
            self.graph.addEdge(u, v, edge.length)
            

    def get_node(self, node_id):
        """node id로 node 객체 반환."""
        return next((node for node in self.nodes if node.id == node_id), None)

    def get_edge(self, source_id, dest_id):
        """source와 dest ID로 edge 객체 반환."""
        return next(
            (e for e in self.edges if e.source.id == source_id and e.dest.id == dest_id), 
            None
        )
        
    def get_path_distance(self, source_id, dest_id):
        try:
            source_idx = self.node_id_map[source_id]
            dest_idx = self.node_id_map[dest_id]
            
            dist = self.apsp.getDistance(source_idx, dest_idx)      
            return dist
        except:
            try:
                source_idx = self.node_id_map[source_id]
                dest_idx = self.node_id_map[dest_id]            

                dist = self.original_apsp.getDistance(source_idx, dest_idx)                
                return dist
            except:
                print(f"No path found even in original_graph for {source_id} -> {dest_id}.")
                return float('inf')
        

    def get_path_edges(self, source_id, dest_id):
        """source와 dest ID로 최단 경로 에지 리스트 반환."""
        try:
            source_idx = self.node_id_map[source_id]
            dest_idx = self.node_id_map[dest_id]
            
            dijkstra = nk.distance.Dijkstra(self.graph, source_idx, storePaths=True, storeNodesSortedByDistance=False, target=dest_idx)
            dijkstra.run()

            path = dijkstra.getPath(dest_idx)
            
            return [
                self.get_edge(self.nodes[path[i]].id, self.nodes[path[i+1]].id)
                for i in range(len(path) - 1)
            ]
        except:
            try:
                source_idx = self.node_id_map[source_id]
                dest_idx = self.node_id_map[dest_id]
                
                dijkstra = nk.distance.Dijkstra(self.original_graph, source_idx, storePaths=True, storeNodesSortedByDistance=False, target=dest_idx)
                dijkstra.run()

                path = dijkstra.getPath(dest_idx)
                
                return [
                    self.get_edge(self.nodes[path[i]].id, self.nodes[path[i+1]].id)
                    for i in range(len(path) - 1)
                ]
            except:
                print(f"No path found even in original_graph for {source_id} -> {dest_id}.")
                return []
    
    def get_oht(self, oht_id):
        return next((oht for oht in self.OHTs if oht.id == oht_id), None)
    
    def get_port(self, port_name):
        return next((port for port in self.ports if port.name == port_name), None)

    def _validate_path(self, path):
        """
        현재 경로에 지워진 edge가 포함된 경우, 해당 edge 직전까지만 반환합니다.

        Parameters:
            path (list): 현재 경로 (edge 객체 리스트)

        Returns:
            list: 수정된 경로 (지워진 edge 직전까지만 포함)
        """
        valid_path = []
        for edge in path:
            if self.graph.hasEdge(self.node_id_map[edge.source.id], self.node_id_map[edge.dest.id]):  # edge가 그래프에 존재하는 경우
                valid_path.append(edge)
            else:
                break  # 지워진 edge를 발견하면 직전까지만 반환
        return valid_path

        
import random
import json
import time
import threading
import math
import pandas as pd
import io



# Load the layout data
with open('./flask_backend/fab_oht_layout_2nd.json') as f:
    layout_data = json.load(f)


nodes = [node(n['id'], [n['x'], n['y']]) for n in layout_data['nodes']]
edges = [
    edge(
        source=next(node for node in nodes if node.id == rail['from']),
        dest=next(node for node in nodes if node.id == rail['to']),
        length=math.sqrt(
            (next(node for node in nodes if node.id == rail['to']).coord[0] -
             next(node for node in nodes if node.id == rail['from']).coord[0])**2 +
            (next(node for node in nodes if node.id == rail['to']).coord[1] -
             next(node for node in nodes if node.id == rail['from']).coord[1])**2
        ),
        max_speed=1500  # Default speed = 0.01
    )
    for rail in layout_data['rails']
]

ports = [
    port(
        name = p['name'], 
        from_node = next((node for node in nodes if node.id == p['from_node'])),
        to_node = next((node for node in nodes if node.id == p['to_node'])),
        from_dist = p['distance']
    )
    for p in layout_data['ports']
]

if __name__ == "__main__":
    ray.init(num_cpus=4,ignore_reinit_error=True)  # Ray 클러스터 초기화
    max_time = 4000
        
    amhs = AMHS(nodes=nodes, edges=edges, ports=ports, num_OHTs=500, max_jobs=1000)
    
    ray.put(amhs.nodes)
    
    ray.shutdown()  # Ray 클러스터 종료
# Out:
# 2025-01-23 07:51:02,241	INFO worker.py:1654 -- Calling ray.init() again after it has already been called.
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/ray/cloudpickle/cloudpickle.py:1245, in Pickler.dump(self, obj)
#    1244 try:
# -> 1245     return super().dump(obj)
#    1246 except RuntimeError as e:
#
# File ~/anaconda3/lib/python3.11/collections/__init__.py:1006, in ChainMap.__getitem__(self, key)
#    1005         pass
# -> 1006 return self.__missing__(key)
#
# RecursionError: maximum recursion depth exceeded
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# Cell In[6], line 242
#     238 max_time = 4000
#     240 amhs = AMHS(nodes=nodes, edges=edges, ports=ports, num_OHTs=500, max_jobs=1000)
# --> 242 ray.put(amhs.nodes)
#     244 ray.shutdown()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py:2836, in put(value, _owner)
#    2834 with profiling.profile("ray.put"):
#    2835     try:
# -> 2836         object_ref = worker.put_object(value, owner_address=serialize_owner_address)
#    2837     except ObjectStoreFullError:
#    2838         logger.info(
#    2839             "Put failed since the value was either too large or the "
#    2840             "store was full of pinned objects."
#    2841         )
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py:794, in Worker.put_object(self, value, object_ref, owner_address, _is_experimental_channel)
#     789     assert (
#     790         object_ref is None
#     791     ), "Local Mode does not support inserting with an ObjectRef"
#     793 try:
# --> 794     serialized_value = self.get_serialization_context().serialize(value)
#     795 except TypeError as e:
#     796     sio = io.StringIO()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:556, in SerializationContext.serialize(self, value)
#     554     return RawSerializedObject(value)
#     555 else:
# --> 556     return self._serialize_to_msgpack(value)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:534, in SerializationContext._serialize_to_msgpack(self, value)
#     532 if python_objects:
#     533     metadata = ray_constants.OBJECT_METADATA_TYPE_PYTHON
# --> 534     pickle5_serialized_object = self._serialize_to_pickle5(
#     535         metadata, python_objects
#     536     )
#     537 else:
#     538     pickle5_serialized_object = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:481, in SerializationContext._serialize_to_pickle5(self, metadata, value)
#     479 except Exception as e:
#     480     self.get_and_clear_contained_object_refs()
# --> 481     raise e
#     482 finally:
#     483     self.set_out_of_band_serialization()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:476, in SerializationContext._serialize_to_pickle5(self, metadata, value)
#     474 try:
#     475     self.set_in_band_serialization()
# --> 476     inband = pickle.dumps(
#     477         value, protocol=5, buffer_callback=writer.buffer_callback
#     478     )
#     479 except Exception as e:
#     480     self.get_and_clear_contained_object_refs()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/cloudpickle/cloudpickle.py:1479, in dumps(obj, protocol, buffer_callback)
#    1477 with io.BytesIO() as file:
#    1478     cp = Pickler(file, protocol=protocol, buffer_callback=buffer_callback)
# -> 1479     cp.dump(obj)
#    1480     return file.getvalue()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/cloudpickle/cloudpickle.py:1249, in Pickler.dump(self, obj)
#    1247 if len(e.args) > 0 and "recursion" in e.args[0]:
#    1248     msg = "Could not pickle object as excessively deep recursion required."
# -> 1249     raise pickle.PicklingError(msg) from e
#    1250 else:
#    1251     raise
#
# PicklingError: Could not pickle object as excessively deep recursion required.

# %%
import ray
import random
import json
import math
import numpy as np

# 클래스 정의 (node, edge, OHT 등 포함)
class node():
    def __init__(self, id, coord):
        self.id = id
        self.coord = np.array(coord)
        self.incoming_edges = []
        self.outgoing_edges = []
        self.OHT = None

    def add_incoming_edge(self, edge):
        self.incoming_edges.append(edge)

    def add_outgoing_edge(self, edge):
        self.outgoing_edges.append(edge)

class edge():
    def __init__(self, source, dest, length, max_speed):
        self.source = source
        self.dest = dest
        self.length = length
        self.max_speed = max_speed
        self.OHTs = []
        
        self.update_edge_references()

    def update_edge_references(self):
        self.source.add_incoming_edge(self)
        self.dest.add_outgoing_edge(self)

class OHT():
    def __init__(self, id, from_node, from_dist, speed, acc, rect, path):
        self.id = id
        self.from_node = from_node
        self.from_dist = from_dist
        self.speed = speed
        self.acc = acc
        self.rect = rect
        self.path = path
        self.pos = self.from_node.coord
        self.status = "IDLE"

# AMHS 클래스 정의 (간단화)
class AMHS:
    def __init__(self, nodes, edges, num_OHTs):
        self.nodes = nodes
        self.edges = edges
        self.OHTs = []
        self.initialize_OHTs(num_OHTs)
    
    def initialize_OHTs(self, num_OHTs):
        available_nodes = self.nodes.copy()
        for i in range(num_OHTs):
            start_node = random.choice(available_nodes)
            available_nodes.remove(start_node)
            oht = OHT(id=i, from_node=start_node, from_dist=0, speed=0, acc=0, rect=1000, path=[])
            start_node.OHT = oht
            self.OHTs.append(oht)


# def test_ray_put():
#     nodes = [node(i, [i, i]) for i in range(500)]  # 5개의 노드
#     edges = [edge(nodes[i], nodes[(i+1) % 5], 10, 1500) for i in range(500)]  # 5개의 엣지 (순환 구조)
#     amhs = AMHS(nodes, edges, num_OHTs=500)

#     # Ray에 데이터를 직렬화하여 전달
#     ray.put(amhs.nodes)
#     ray.put(amhs.edges)
#     ray.put(amhs.OHTs)

#     print("Node Data, Edge Data, OHT Data put into Ray!")

# Ray 클러스터 초기화
ray.init(ignore_reinit_error=True)

# nodes = [node(i, [i, i]) for i in range(500)]  # 5개의 노드
edges = [edge(nodes[i], nodes[(i+1) % 5], 1023923.1241, 1500) for i in range(500)]  # 5개의 엣지 (순환 구조)

# Load the layout data
with open('./flask_backend/fab_oht_layout_2nd.json') as f:
    layout_data = json.load(f)


nodes = [node(n['id'], [n['x'], n['y']]) for n in layout_data['nodes']]
edges = [edge(random.choice(nodes), random.choice(nodes), 1023923.1241, 1500) for i in range(3000)]
# edges = [
#     edge(
#         source=next(node for node in nodes if node.id == rail['from']),
#         dest=next(node for node in nodes if node.id == rail['to']),
#         length=math.sqrt(
#             (next(node for node in nodes if node.id == rail['to']).coord[0] -
#              next(node for node in nodes if node.id == rail['from']).coord[0])**2 +
#             (next(node for node in nodes if node.id == rail['to']).coord[1] -
#              next(node for node in nodes if node.id == rail['from']).coord[1])**2
#         ),
#         max_speed=1500  # Default speed = 0.01
#     )
#     for rail in layout_data['rails']
# ]

amhs = AMHS(nodes, edges, num_OHTs=500)

# Ray에 데이터를 직렬화하여 전달
ray.put(amhs.nodes)
ray.put(amhs.edges)
# ray.put(amhs.OHTs)

# Ray 테스트
# test_ray_put()

# Ray 클러스터 종료
ray.shutdown()





# ray.init(num_cpus=4,ignore_reinit_error=True)  # Ray 클러스터 초기화
# max_time = 4000
    
# amhs = AMHS(nodes=nodes, edges=edges, num_OHTs=500)

# ray.put(amhs.nodes)

# ray.shutdown()  # Ray 클러스터 종료
# Out:
# 2025-01-23 08:11:33,126	INFO worker.py:1821 -- Started a local Ray instance.
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/ray/cloudpickle/cloudpickle.py:1245, in Pickler.dump(self, obj)
#    1244 try:
# -> 1245     return super().dump(obj)
#    1246 except RuntimeError as e:
#
# File ~/anaconda3/lib/python3.11/collections/__init__.py:1006, in ChainMap.__getitem__(self, key)
#    1005         pass
# -> 1006 return self.__missing__(key)
#
# RecursionError: maximum recursion depth exceeded
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# Cell In[28], line 109
#     106 amhs = AMHS(nodes, edges, num_OHTs=500)
#     108 # Ray에 데이터를 직렬화하여 전달
# --> 109 ray.put(amhs.nodes)
#     110 ray.put(amhs.edges)
#     111 # ray.put(amhs.OHTs)
#     112
#     113 # Ray 테스트
#     114 # test_ray_put()
#     115
#     116 # Ray 클러스터 종료
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py:2836, in put(value, _owner)
#    2834 with profiling.profile("ray.put"):
#    2835     try:
# -> 2836         object_ref = worker.put_object(value, owner_address=serialize_owner_address)
#    2837     except ObjectStoreFullError:
#    2838         logger.info(
#    2839             "Put failed since the value was either too large or the "
#    2840             "store was full of pinned objects."
#    2841         )
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py:794, in Worker.put_object(self, value, object_ref, owner_address, _is_experimental_channel)
#     789     assert (
#     790         object_ref is None
#     791     ), "Local Mode does not support inserting with an ObjectRef"
#     793 try:
# --> 794     serialized_value = self.get_serialization_context().serialize(value)
#     795 except TypeError as e:
#     796     sio = io.StringIO()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:556, in SerializationContext.serialize(self, value)
#     554     return RawSerializedObject(value)
#     555 else:
# --> 556     return self._serialize_to_msgpack(value)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:534, in SerializationContext._serialize_to_msgpack(self, value)
#     532 if python_objects:
#     533     metadata = ray_constants.OBJECT_METADATA_TYPE_PYTHON
# --> 534     pickle5_serialized_object = self._serialize_to_pickle5(
#     535         metadata, python_objects
#     536     )
#     537 else:
#     538     pickle5_serialized_object = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:481, in SerializationContext._serialize_to_pickle5(self, metadata, value)
#     479 except Exception as e:
#     480     self.get_and_clear_contained_object_refs()
# --> 481     raise e
#     482 finally:
#     483     self.set_out_of_band_serialization()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:476, in SerializationContext._serialize_to_pickle5(self, metadata, value)
#     474 try:
#     475     self.set_in_band_serialization()
# --> 476     inband = pickle.dumps(
#     477         value, protocol=5, buffer_callback=writer.buffer_callback
#     478     )
#     479 except Exception as e:
#     480     self.get_and_clear_contained_object_refs()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/cloudpickle/cloudpickle.py:1479, in dumps(obj, protocol, buffer_callback)
#    1477 with io.BytesIO() as file:
#    1478     cp = Pickler(file, protocol=protocol, buffer_callback=buffer_callback)
# -> 1479     cp.dump(obj)
#    1480     return file.getvalue()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/cloudpickle/cloudpickle.py:1249, in Pickler.dump(self, obj)
#    1247 if len(e.args) > 0 and "recursion" in e.args[0]:
#    1248     msg = "Could not pickle object as excessively deep recursion required."
# -> 1249     raise pickle.PicklingError(msg) from e
#    1250 else:
#    1251     raise
#
# PicklingError: Could not pickle object as excessively deep recursion required.

# %%
nodes = [node(i, [i, i]) for i in range(500)]  # 5개의 노드
edges = [edge(nodes[i], nodes[(i+1) % 5], 10, 1500) for i in range(500)]  # 5개의 엣지 (순환 구조)

# %%
edges[0].source

# %%
nodes
# Out:
# [<__main__.node at 0x7fe5b855c150>,
#  <__main__.node at 0x7fb6a3f5db50>,
#  <__main__.node at 0x7fe65c436110>,
#  <__main__.node at 0x7fe65c4362d0>,
#  <__main__.node at 0x7fe65c436710>,
#  <__main__.node at 0x7fe65c436390>,
#  <__main__.node at 0x7fe65c435990>,
#  <__main__.node at 0x7fe65c435450>,
#  <__main__.node at 0x7fe65c435250>,
#  <__main__.node at 0x7fe65c436810>,
#  <__main__.node at 0x7fe65c4355d0>,
#  <__main__.node at 0x7fe65c435810>,
#  <__main__.node at 0x7fe65c435a90>,
#  <__main__.node at 0x7fe65c435f10>,
#  <__main__.node at 0x7fe65c435d50>,
#  <__main__.node at 0x7fe65c435e50>,
#  <__main__.node at 0x7fe65c435fd0>,
#  <__main__.node at 0x7fe65c434290>,
#  <__main__.node at 0x7fe65c434c10>,
#  <__main__.node at 0x7fe65c434750>,
#  <__main__.node at 0x7fe65c434e90>,
#  <__main__.node at 0x7fe65c434cd0>,
#  <__main__.node at 0x7fe65c434ad0>,
#  <__main__.node at 0x7fe65c434dd0>,
#  <__main__.node at 0x7fe65c434810>,
#  <__main__.node at 0x7fe65c434590>,
#  <__main__.node at 0x7fe65c434650>,
#  <__main__.node at 0x7fe65c434710>,
#  <__main__.node at 0x7fe65c434350>,
#  <__main__.node at 0x7fe65c436c10>,
#  <__main__.node at 0x7fe65c436d50>,
#  <__main__.node at 0x7fe65c437910>,
#  <__main__.node at 0x7fe65c437390>,
#  <__main__.node at 0x7fe65c437a90>,
#  <__main__.node at 0x7fe65c437fd0>,
#  <__main__.node at 0x7fe65c436b50>,
#  <__main__.node at 0x7fe65c436950>,
#  <__main__.node at 0x7fe65c434790>,
#  <__main__.node at 0x7fe65c4349d0>,
#  <__main__.node at 0x7fe65c449150>,
#  <__main__.node at 0x7fe65c449d50>,
#  <__main__.node at 0x7fe65c448210>,
#  <__main__.node at 0x7fe65c4480d0>,
#  <__main__.node at 0x7fe65c449b10>,
#  <__main__.node at 0x7fe65c44ad50>,
#  <__main__.node at 0x7fe65c449fd0>,
#  <__main__.node at 0x7fe65c449850>,
#  <__main__.node at 0x7fe65c449290>,
#  <__main__.node at 0x7fe65c44b8d0>,
#  <__main__.node at 0x7fe65c44bbd0>,
#  <__main__.node at 0x7fe65c44bf50>,
#  <__main__.node at 0x7fe65c425790>,
#  <__main__.node at 0x7fe65c426810>,
#  <__main__.node at 0x7fe65c425ad0>,
#  <__main__.node at 0x7fe65c425f10>,
#  <__main__.node at 0x7fe65c425910>,
#  <__main__.node at 0x7fe65c4275d0>,
#  <__main__.node at 0x7fe65c426450>,
#  <__main__.node at 0x7fe65c4269d0>,
#  <__main__.node at 0x7fe65c425890>,
#  <__main__.node at 0x7fe65c424d50>,
#  <__main__.node at 0x7fe65c426a10>,
#  <__main__.node at 0x7fe65c424810>,
#  <__main__.node at 0x7fe65c426510>,
#  <__main__.node at 0x7fe65c426150>,
#  <__main__.node at 0x7fe65c427990>,
#  <__main__.node at 0x7fe65c427a50>,
#  <__main__.node at 0x7fe65c427190>,
#  <__main__.node at 0x7fe65c4270d0>,
#  <__main__.node at 0x7fe65c426f50>,
#  <__main__.node at 0x7fe65c427010>,
#  <__main__.node at 0x7fe65c427790>,
#  <__main__.node at 0x7fe65c426c90>,
#  <__main__.node at 0x7fe65c427450>,
#  <__main__.node at 0x7fe65c425950>,
#  <__main__.node at 0x7fe65c424d90>,
#  <__main__.node at 0x7fe65c427210>,
#  <__main__.node at 0x7fe65c426210>,
#  <__main__.node at 0x7fe65c426ed0>,
#  <__main__.node at 0x7fe65c427350>,
#  <__main__.node at 0x7fe65c425c50>,
#  <__main__.node at 0x7fe65c425cd0>,
#  <__main__.node at 0x7fe65c457690>,
#  <__main__.node at 0x7fe65c457f50>,
#  <__main__.node at 0x7fe65c456790>,
#  <__main__.node at 0x7fe65c4571d0>,
#  <__main__.node at 0x7fe65c455850>,
#  <__main__.node at 0x7fe65c454790>,
#  <__main__.node at 0x7fe65c454310>,
#  <__main__.node at 0x7fe65c454a90>,
#  <__main__.node at 0x7fe65c455d10>,
#  <__main__.node at 0x7fe65c457390>,
#  <__main__.node at 0x7fe65c4564d0>,
#  <__main__.node at 0x7fe65c454c10>,
#  <__main__.node at 0x7fe65c450910>,
#  <__main__.node at 0x7fe65c4509d0>,
#  <__main__.node at 0x7fe65c4500d0>,
#  <__main__.node at 0x7fe65c451750>,
#  <__main__.node at 0x7fe65c451a50>,
#  <__main__.node at 0x7fe65c452210>,
#  <__main__.node at 0x7fe65c452b10>,
#  <__main__.node at 0x7fe65c452550>,
#  <__main__.node at 0x7fe65c4518d0>,
#  <__main__.node at 0x7fe65c4536d0>,
#  <__main__.node at 0x7fe65c453dd0>,
#  <__main__.node at 0x7fe65c453bd0>,
#  <__main__.node at 0x7fe65c452dd0>,
#  <__main__.node at 0x7fe65c45f290>,
#  <__main__.node at 0x7fe65c45ee90>,
#  <__main__.node at 0x7fe65c45cf10>,
#  <__main__.node at 0x7fe65c45d110>,
#  <__main__.node at 0x7fe65c45c990>,
#  <__main__.node at 0x7fe65c45cbd0>,
#  <__main__.node at 0x7fe65c45c210>,
#  <__main__.node at 0x7fe65c45d5d0>,
#  <__main__.node at 0x7fe65c45c5d0>,
#  <__main__.node at 0x7fe65c45ec10>,
#  <__main__.node at 0x7fe65c45ed50>,
#  <__main__.node at 0x7fe65c45eb50>,
#  <__main__.node at 0x7fe65c45e510>,
#  <__main__.node at 0x7fe65c45e590>,
#  <__main__.node at 0x7fe65c45e690>,
#  <__main__.node at 0x7fe65c45e8d0>,
#  <__main__.node at 0x7fe65c45e890>,
#  <__main__.node at 0x7fe65c45e6d0>,
#  <__main__.node at 0x7fe65c45e4d0>,
#  <__main__.node at 0x7fe65c45e010>,
#  <__main__.node at 0x7fe65c45e1d0>,
#  <__main__.node at 0x7fe65c45e3d0>,
#  <__main__.node at 0x7fe65c45e210>,
#  <__main__.node at 0x7fe65c45df90>,
#  <__main__.node at 0x7fe65c45de50>,
#  <__main__.node at 0x7fe65c45ddd0>,
#  <__main__.node at 0x7fe65c45db10>,
#  <__main__.node at 0x7fe65c45dd50>,
#  <__main__.node at 0x7fe65c45dc10>,
#  <__main__.node at 0x7fe65c45da10>,
#  <__main__.node at 0x7fe65c45d850>,
#  <__main__.node at 0x7fe65c45d7d0>,
#  <__main__.node at 0x7fe65c45f010>,
#  <__main__.node at 0x7fe65c45f190>,
#  <__main__.node at 0x7fe65c45f590>,
#  <__main__.node at 0x7fb6b1449910>,
#  <__main__.node at 0x7fb6b14c0dd0>,
#  <__main__.node at 0x7fe65c4fcbd0>,
#  <__main__.node at 0x7fb6b0783690>,
#  <__main__.node at 0x7fe58c6edb50>,
#  <__main__.node at 0x7fe58c6ee310>,
#  <__main__.node at 0x7fe58c6e7fd0>,
#  <__main__.node at 0x7fe65c517590>,
#  <__main__.node at 0x7fe65c502dd0>,
#  <__main__.node at 0x7fe65c5015d0>,
#  <__main__.node at 0x7fb6b1422090>,
#  <__main__.node at 0x7fe5b853f210>,
#  <__main__.node at 0x7fb6b0add910>,
#  <__main__.node at 0x7fe58c63ec10>,
#  <__main__.node at 0x7fe548880410>,
#  <__main__.node at 0x7fe548882690>,
#  <__main__.node at 0x7fe548882990>,
#  <__main__.node at 0x7fe548880610>,
#  <__main__.node at 0x7fb6b243c350>,
#  <__main__.node at 0x7fb6b243c390>,
#  <__main__.node at 0x7fb6b03f4710>,
#  <__main__.node at 0x7fb6b2435950>,
#  <__main__.node at 0x7fb6b24359d0>,
#  <__main__.node at 0x7fe5488a54d0>,
#  <__main__.node at 0x7fe5488a6d50>,
#  <__main__.node at 0x7fe5488a4b10>,
#  <__main__.node at 0x7fe54889a350>,
#  <__main__.node at 0x7fe548898510>,
#  <__main__.node at 0x7fe548899d10>,
#  <__main__.node at 0x7fe548899a10>,
#  <__main__.node at 0x7fe54889bd50>,
#  <__main__.node at 0x7fb6b0551dd0>,
#  <__main__.node at 0x7fb6b0552110>,
#  <__main__.node at 0x7fb6b0553690>,
#  <__main__.node at 0x7fb6b24393d0>,
#  <__main__.node at 0x7fb6b2438d90>,
#  <__main__.node at 0x7fb6b2438e10>,
#  <__main__.node at 0x7fb6b2439490>,
#  <__main__.node at 0x7fb6b243b550>,
#  <__main__.node at 0x7fb6b02b7810>,
#  <__main__.node at 0x7fb6a3b16190>,
#  <__main__.node at 0x7fb6a3b162d0>,
#  <__main__.node at 0x7fb6a3b16b90>,
#  <__main__.node at 0x7fb6a3b15c50>,
#  <__main__.node at 0x7fb6a3b16410>,
#  <__main__.node at 0x7fb6a3b15f10>,
#  <__main__.node at 0x7fb6a3b3fb10>,
#  <__main__.node at 0x7fb6a3b3eb10>,
#  <__main__.node at 0x7fb6a3b3fd90>,
#  <__main__.node at 0x7fb6a3b3de10>,
#  <__main__.node at 0x7fb6a3b3de50>,
#  <__main__.node at 0x7fb6a3b3ded0>,
#  <__main__.node at 0x7fb6a3b3e150>,
#  <__main__.node at 0x7fb6a3b3e250>,
#  <__main__.node at 0x7fb6a3b3ff50>,
#  <__main__.node at 0x7fb6a3b3ff10>,
#  <__main__.node at 0x7fb6a3b3fe90>,
#  <__main__.node at 0x7fb6a3b3da10>,
#  <__main__.node at 0x7fb6a3b3dd10>,
#  <__main__.node at 0x7fb6a3b3e290>,
#  <__main__.node at 0x7fb6a3b3e790>,
#  <__main__.node at 0x7fb6a3b3ec90>,
#  <__main__.node at 0x7fb6a3b3e990>,
#  <__main__.node at 0x7fb6a3b3ee90>,
#  <__main__.node at 0x7fb6a3b3e490>,
#  <__main__.node at 0x7fb6a3b3ef10>,
#  <__main__.node at 0x7fb6a3b3eed0>,
#  <__main__.node at 0x7fb6a3b3f710>,
#  <__main__.node at 0x7fb6a3b3f550>,
#  <__main__.node at 0x7fb6a3b3f310>,
#  <__main__.node at 0x7fb6a3b3f6d0>,
#  <__main__.node at 0x7fb6a3b3fad0>,
#  <__main__.node at 0x7fb6a3b3f7d0>,
#  <__main__.node at 0x7fb6a3b519d0>,
#  <__main__.node at 0x7fb6a3b53090>,
#  <__main__.node at 0x7fb6a3b50550>,
#  <__main__.node at 0x7fb6a3b500d0>,
#  <__main__.node at 0x7fb6a3b514d0>,
#  <__main__.node at 0x7fb6a3b53f50>,
#  <__main__.node at 0x7fb6a3b51c10>,
#  <__main__.node at 0x7fb6a3b50b10>,
#  <__main__.node at 0x7fb6a3b515d0>,
#  <__main__.node at 0x7fb6a3b50c10>,
#  <__main__.node at 0x7fb6a3b516d0>,
#  <__main__.node at 0x7fb6a3b51bd0>,
#  <__main__.node at 0x7fb6a3b51150>,
#  <__main__.node at 0x7fb6a3b51dd0>,
#  <__main__.node at 0x7fb6a3b52150>,
#  <__main__.node at 0x7fb6a3b51d10>,
#  <__main__.node at 0x7fb6a3b52a50>,
#  <__main__.node at 0x7fb6a3b52d10>,
#  <__main__.node at 0x7fb6a3b52a90>,
#  <__main__.node at 0x7fb6a3b52ad0>,
#  <__main__.node at 0x7fb6a3b529d0>,
#  <__main__.node at 0x7fb6a3b52dd0>,
#  <__main__.node at 0x7fb6a3b53310>,
#  <__main__.node at 0x7fb6a3b532d0>,
#  <__main__.node at 0x7fb6a3b52d50>,
#  <__main__.node at 0x7fb6a3b53cd0>,
#  <__main__.node at 0x7fb6a3b52e10>,
#  <__main__.node at 0x7fb6a3b51a10>,
#  <__main__.node at 0x7fb6a3b51b50>,
#  <__main__.node at 0x7fb6a3b53c10>,
#  <__main__.node at 0x7fb6a3b53910>,
#  <__main__.node at 0x7fb6a3b53b10>,
#  <__main__.node at 0x7fb6a3b53e10>,
#  <__main__.node at 0x7fb6a3b340d0>,
#  <__main__.node at 0x7fb6a3b342d0>,
#  <__main__.node at 0x7fb6a3b34590>,
#  <__main__.node at 0x7fb6a3b34690>,
#  <__main__.node at 0x7fb6a3b34790>,
#  <__main__.node at 0x7fb6a3b34890>,
#  <__main__.node at 0x7fb6a3b34990>,
#  <__main__.node at 0x7fb6a3b34a90>,
#  <__main__.node at 0x7fb6a3b34b90>,
#  <__main__.node at 0x7fb6a3b34c90>,
#  <__main__.node at 0x7fb6a3b34d90>,
#  <__main__.node at 0x7fb6a3b34e90>,
#  <__main__.node at 0x7fb6a3b34f90>,
#  <__main__.node at 0x7fb6a3b35090>,
#  <__main__.node at 0x7fb6a3b351d0>,
#  <__main__.node at 0x7fb6a3b35350>,
#  <__main__.node at 0x7fb6a3b353d0>,
#  <__main__.node at 0x7fb6a3b35690>,
#  <__main__.node at 0x7fb6a3b35790>,
#  <__main__.node at 0x7fb6a3b35890>,
#  <__main__.node at 0x7fb6a3b35990>,
#  <__main__.node at 0x7fb6a3b35a90>,
#  <__main__.node at 0x7fb6a3b35b90>,
#  <__main__.node at 0x7fb6a3b35c90>,
#  <__main__.node at 0x7fb6a3b35d90>,
#  <__main__.node at 0x7fb6a3b35e90>,
#  <__main__.node at 0x7fb6a3b35f90>,
#  <__main__.node at 0x7fb6a3b36090>,
#  <__main__.node at 0x7fb6a3b36190>,
#  <__main__.node at 0x7fb6a3b36290>,
#  <__main__.node at 0x7fb6a3b36390>,
#  <__main__.node at 0x7fb6a3b35050>,
#  <__main__.node at 0x7fb6a3b36510>,
#  <__main__.node at 0x7fb6a3b366d0>,
#  <__main__.node at 0x7fb6a3b36790>,
#  <__main__.node at 0x7fb6a3b36bd0>,
#  <__main__.node at 0x7fb6a3b36950>,
#  <__main__.node at 0x7fb6a3b36c10>,
#  <__main__.node at 0x7fb6a3b36d10>,
#  <__main__.node at 0x7fb6a3b36e10>,
#  <__main__.node at 0x7fb6a3b36f10>,
#  <__main__.node at 0x7fb6a3b37010>,
#  <__main__.node at 0x7fb6a3b37110>,
#  <__main__.node at 0x7fb6a3b37210>,
#  <__main__.node at 0x7fb6a3b37310>,
#  <__main__.node at 0x7fb6a3b37410>,
#  <__main__.node at 0x7fb6a3b37510>,
#  <__main__.node at 0x7fb6a3b37610>,
#  <__main__.node at 0x7fb6a3b37710>,
#  <__main__.node at 0x7fb6a3b37810>,
#  <__main__.node at 0x7fb6a3b378d0>,
#  <__main__.node at 0x7fb6a3b379d0>,
#  <__main__.node at 0x7fb6a3b37b10>,
#  <__main__.node at 0x7fb6a3b37c10>,
#  <__main__.node at 0x7fb6a3b37dd0>,
#  <__main__.node at 0x7fb6a3b37f10>,
#  <__main__.node at 0x7fb6a3b37890>,
#  <__main__.node at 0x7fb6a3b35550>,
#  <__main__.node at 0x7fb6a3b34450>,
#  <__main__.node at 0x7fb6a3b48390>,
#  <__main__.node at 0x7fb6a3b48190>,
#  <__main__.node at 0x7fb6a3b483d0>,
#  <__main__.node at 0x7fb6a3b48950>,
#  <__main__.node at 0x7fb6a3b48ad0>,
#  <__main__.node at 0x7fb6a3b48d50>,
#  <__main__.node at 0x7fb6a3b48e90>,
#  <__main__.node at 0x7fb6a3b49090>,
#  <__main__.node at 0x7fb6a3b49190>,
#  <__main__.node at 0x7fb6a3b49350>,
#  <__main__.node at 0x7fb6a3b49450>,
#  <__main__.node at 0x7fb6a3b49590>,
#  <__main__.node at 0x7fb6a3b48290>,
#  <__main__.node at 0x7fb6a3b4b9d0>,
#  <__main__.node at 0x7fb6a3b498d0>,
#  <__main__.node at 0x7fb6a3b4ba90>,
#  <__main__.node at 0x7fb6a3b4bf90>,
#  <__main__.node at 0x7fb6a3b4bc90>,
#  <__main__.node at 0x7fb6a3b4bf10>,
#  <__main__.node at 0x7fb6a3b4ab90>,
#  <__main__.node at 0x7fb6a3b4ad50>,
#  <__main__.node at 0x7fb6a3b4af90>,
#  <__main__.node at 0x7fb6a3b4a710>,
#  <__main__.node at 0x7fb6a3b49790>,
#  <__main__.node at 0x7fb6a3b49610>,
#  <__main__.node at 0x7fb6a3b49710>,
#  <__main__.node at 0x7fb6a3b49a10>,
#  <__main__.node at 0x7fb6a3b49ad0>,
#  <__main__.node at 0x7fb6a3b49cd0>,
#  <__main__.node at 0x7fb6a3b48690>,
#  <__main__.node at 0x7fb6a3b49ed0>,
#  <__main__.node at 0x7fb6a3b49e50>,
#  <__main__.node at 0x7fb6a3b49fd0>,
#  <__main__.node at 0x7fb6a3b4a3d0>,
#  <__main__.node at 0x7fb6a3b4a590>,
#  <__main__.node at 0x7fb6a3b49550>,
#  <__main__.node at 0x7fb6a3b4a990>,
#  <__main__.node at 0x7fb6a3b4a810>,
#  <__main__.node at 0x7fb6a3b4a2d0>,
#  <__main__.node at 0x7fb6a3b4ac10>,
#  <__main__.node at 0x7fb6a3b4ac50>,
#  <__main__.node at 0x7fb6a3b4ad10>,
#  <__main__.node at 0x7fb6a3b4b310>,
#  <__main__.node at 0x7fb6a3b4b290>,
#  <__main__.node at 0x7fb6a3b4b590>,
#  <__main__.node at 0x7fb6a3b4b6d0>,
#  <__main__.node at 0x7fb6a3b4b7d0>,
#  <__main__.node at 0x7fb6a3b441d0>,
#  <__main__.node at 0x7fb6a3b443d0>,
#  <__main__.node at 0x7fb6a3b444d0>,
#  <__main__.node at 0x7fb6a3b44290>,
#  <__main__.node at 0x7fb6a3b44590>,
#  <__main__.node at 0x7fb6a3b446d0>,
#  <__main__.node at 0x7fb6a3b44810>,
#  <__main__.node at 0x7fb6a3b44990>,
#  <__main__.node at 0x7fb6a3b44b90>,
#  <__main__.node at 0x7fb6a3b44cd0>,
#  <__main__.node at 0x7fb6a3b45050>,
#  <__main__.node at 0x7fb6a3b45090>,
#  <__main__.node at 0x7fb6a3b45dd0>,
#  <__main__.node at 0x7fb6a3b455d0>,
#  <__main__.node at 0x7fb6a3b45790>,
#  <__main__.node at 0x7fb6a3b45510>,
#  <__main__.node at 0x7fb6a3b45490>,
#  <__main__.node at 0x7fb6a3b45550>,
#  <__main__.node at 0x7fb6a3b45ad0>,
#  <__main__.node at 0x7fb6a3b45a10>,
#  <__main__.node at 0x7fb6a3b45890>,
#  <__main__.node at 0x7fb6a3b44ad0>,
#  <__main__.node at 0x7fb6a3b46010>,
#  <__main__.node at 0x7fb6a3b45e10>,
#  <__main__.node at 0x7fb6a3b46650>,
#  <__main__.node at 0x7fb6a3b46750>,
#  <__main__.node at 0x7fb6a3b468d0>,
#  <__main__.node at 0x7fb6a3b46c90>,
#  <__main__.node at 0x7fb6a3b46e90>,
#  <__main__.node at 0x7fb6a3b46f10>,
#  <__main__.node at 0x7fb6a3b47210>,
#  <__main__.node at 0x7fb6a3b47590>,
#  <__main__.node at 0x7fb6a3b474d0>,
#  <__main__.node at 0x7fb6a3b475d0>,
#  <__main__.node at 0x7fb6a3b47890>,
#  <__main__.node at 0x7fb6a3b47110>,
#  <__main__.node at 0x7fb6a3b47d10>,
#  <__main__.node at 0x7fb6a3b479d0>,
#  <__main__.node at 0x7fb6a3b47d90>,
#  <__main__.node at 0x7fb6a3b47ed0>,
#  <__main__.node at 0x7fb6a3b47e50>,
#  <__main__.node at 0x7fb6a3b45d10>,
#  <__main__.node at 0x7fb6a3b47410>,
#  <__main__.node at 0x7fb6a3b44110>,
#  <__main__.node at 0x7fb6a3b45850>,
#  <__main__.node at 0x7fb6a3b440d0>,
#  <__main__.node at 0x7fb6a3b46790>,
#  <__main__.node at 0x7fb6a3b60110>,
#  <__main__.node at 0x7fb6a3b60210>,
#  <__main__.node at 0x7fb6a3b60310>,
#  <__main__.node at 0x7fb6a3b60410>,
#  <__main__.node at 0x7fb6a3b60510>,
#  <__main__.node at 0x7fb6a3b60610>,
#  <__main__.node at 0x7fb6a3b60710>,
#  <__main__.node at 0x7fb6a3b60810>,
#  <__main__.node at 0x7fb6a3b60910>,
#  <__main__.node at 0x7fb6a3b60a10>,
#  <__main__.node at 0x7fb6a3b60b50>,
#  <__main__.node at 0x7fb6a3b60c90>,
#  <__main__.node at 0x7fb6a3b60c50>,
#  <__main__.node at 0x7fb6a3b60e50>,
#  <__main__.node at 0x7fb6a3b60f50>,
#  <__main__.node at 0x7fb6a3b61050>,
#  <__main__.node at 0x7fb6a3b61150>,
#  <__main__.node at 0x7fb6a3b61250>,
#  <__main__.node at 0x7fb6a3b61350>,
#  <__main__.node at 0x7fb6a3b61450>,
#  <__main__.node at 0x7fb6a3b61550>,
#  <__main__.node at 0x7fb6a3b61650>,
#  <__main__.node at 0x7fb6a3b61750>,
#  <__main__.node at 0x7fb6a3b61850>,
#  <__main__.node at 0x7fb6a3b61950>,
#  <__main__.node at 0x7fb6a3b61a50>,
#  <__main__.node at 0x7fb6a3b61b10>,
#  <__main__.node at 0x7fb6a3b62090>,
#  <__main__.node at 0x7fb6a3b621d0>,
#  <__main__.node at 0x7fb6a3b62290>,
#  <__main__.node at 0x7fb6a3b62390>,
#  <__main__.node at 0x7fb6a3b61b50>,
#  <__main__.node at 0x7fb6a3b61c90>,
#  <__main__.node at 0x7fb6a3b61c50>,
#  <__main__.node at 0x7fb6a3b61e50>,
#  <__main__.node at 0x7fb6a3b61f50>,
#  <__main__.node at 0x7fb6a3b624d0>,
#  <__main__.node at 0x7fb6a3b62790>,
#  <__main__.node at 0x7fb6a3b62910>,
#  <__main__.node at 0x7fb6a3b62a50>,
#  <__main__.node at 0x7fb6a3b62ad0>,
#  <__main__.node at 0x7fb6a3b62c50>,
#  <__main__.node at 0x7fb6a3b62d90>,
#  <__main__.node at 0x7fb6a3b62e50>,
#  <__main__.node at 0x7fb6a3b62f50>,
#  <__main__.node at 0x7fb6a3b63350>,
#  <__main__.node at 0x7fb6a3b63190>,
#  <__main__.node at 0x7fb6a3b63110>,
#  <__main__.node at 0x7fb6a3b63310>,
#  <__main__.node at 0x7fb6a3b63050>,
#  <__main__.node at 0x7fb6a3b63650>,
#  <__main__.node at 0x7fb6a3b63590>,
#  <__main__.node at 0x7fb6a3b63d90>,
#  <__main__.node at 0x7fb6a3b63d50>,
#  <__main__.node at 0x7fb6a3b63a90>,
#  <__main__.node at 0x7fb6a3b63f90>,
#  <__main__.node at 0x7fb6a3b63e50>,
#  <__main__.node at 0x7fb6a3b63e90>,
#  <__main__.node at 0x7fb6a3b63690>,
#  <__main__.node at 0x7fb6a3b62810>,
#  <__main__.node at 0x7fb6a3b5f150>,
#  <__main__.node at 0x7fb6a3b5c110>,
#  <__main__.node at 0x7fb6a3b5c050>,
#  <__main__.node at 0x7fb6a3b5c210>,
#  <__main__.node at 0x7fb6a3b5c450>,
#  <__main__.node at 0x7fb6a3b5c2d0>,
#  <__main__.node at 0x7fb6a3b5c6d0>,
#  <__main__.node at 0x7fb6a3b5c690>,
#  <__main__.node at 0x7fb6a3b5c950>,
#  <__main__.node at 0x7fb6a3b5cb50>,
#  <__main__.node at 0x7fb6a3b5cc50>,
#  <__main__.node at 0x7fb6a3b5cdd0>,
#  <__main__.node at 0x7fb6a3b5cf10>,
#  <__main__.node at 0x7fb6a3b5d010>,
#  <__main__.node at 0x7fb6a3b5d110>,
#  <__main__.node at 0x7fb6a3b5d250>,
#  <__main__.node at 0x7fb6a3b5d290>,
#  <__main__.node at 0x7fb6a3b5d5d0>,
#  <__main__.node at 0x7fb6a3b5d690>,
#  <__main__.node at 0x7fb6a3b5d790>,
#  <__main__.node at 0x7fb6a3b5d890>,
#  <__main__.node at 0x7fb6a3b5d990>,
#  <__main__.node at 0x7fb6a3b5c310>,
#  <__main__.node at 0x7fb6a3b5df10>,
#  <__main__.node at 0x7fb6a3b5e090>,
#  <__main__.node at 0x7fb6a3b5db50>,
#  <__main__.node at 0x7fb6a3b5dad0>,
#  <__main__.node at 0x7fb6a3b5e1d0>,
#  <__main__.node at 0x7fb6a3b5dc50>,
#  <__main__.node at 0x7fb6a3b5dbd0>,
#  <__main__.node at 0x7fb6a3b5e4d0>,
#  <__main__.node at 0x7fb6a3b5e750>,
#  <__main__.node at 0x7fb6a3b5e810>,
#  <__main__.node at 0x7fb6a3b5e910>,
#  <__main__.node at 0x7fb6a3b5e990>,
#  <__main__.node at 0x7fb6a3b5eb10>,
#  <__main__.node at 0x7fb6a3b5ec50>,
#  <__main__.node at 0x7fb6a3b5ed10>,
#  <__main__.node at 0x7fb6a3b5ea10>]

# %%
with open('./flask_backend/fab_oht_layout_2nd.json') as f:
    layout_data = json.load(f)


nodes = [node(n['id'], [n['x'], n['y']]) for n in layout_data['nodes']]
edges = [
    edge(
        source=next(node for node in nodes if node.id == rail['from']),
        dest=next(node for node in nodes if node.id == rail['to']),
        length=math.sqrt(
            (next(node for node in nodes if node.id == rail['to']).coord[0] -
             next(node for node in nodes if node.id == rail['from']).coord[0])**2 +
            (next(node for node in nodes if node.id == rail['to']).coord[1] -
             next(node for node in nodes if node.id == rail['from']).coord[1])**2
        ),
        max_speed=1500  # Default speed = 0.01
    )
    for rail in layout_data['rails']
]

# %%
nodes
# Out:
# [<__main__.node at 0x7fe65c501690>,
#  <__main__.node at 0x7fe58c7b8150>,
#  <__main__.node at 0x7fe58c7b80d0>,
#  <__main__.node at 0x7fe58c7b8050>,
#  <__main__.node at 0x7fe58c7b8310>,
#  <__main__.node at 0x7fe58c7b8250>,
#  <__main__.node at 0x7fe58c7b81d0>,
#  <__main__.node at 0x7fe58c7b84d0>,
#  <__main__.node at 0x7fe58c7b8450>,
#  <__main__.node at 0x7fe58c7b8290>,
#  <__main__.node at 0x7fe58c7b8390>,
#  <__main__.node at 0x7fe58c7b8690>,
#  <__main__.node at 0x7fe58c7b8610>,
#  <__main__.node at 0x7fe58c7b8590>,
#  <__main__.node at 0x7fe58c7b86d0>,
#  <__main__.node at 0x7fe58c7b8810>,
#  <__main__.node at 0x7fe58c7b8790>,
#  <__main__.node at 0x7fe58c7b8710>,
#  <__main__.node at 0x7fe58c7b8a10>,
#  <__main__.node at 0x7fe58c7b8990>,
#  <__main__.node at 0x7fe58c7b8910>,
#  <__main__.node at 0x7fe58c7b8a50>,
#  <__main__.node at 0x7fe58c7b8b90>,
#  <__main__.node at 0x7fe58c7b8b10>,
#  <__main__.node at 0x7fe58c7b8a90>,
#  <__main__.node at 0x7fe58c7b8d90>,
#  <__main__.node at 0x7fe58c7b8d10>,
#  <__main__.node at 0x7fe58c7b8c90>,
#  <__main__.node at 0x7fe58c7b8dd0>,
#  <__main__.node at 0x7fe58c7b8f10>,
#  <__main__.node at 0x7fe58c7b8e90>,
#  <__main__.node at 0x7fe58c7b8e10>,
#  <__main__.node at 0x7fe58c7b9110>,
#  <__main__.node at 0x7fe58c7b9090>,
#  <__main__.node at 0x7fe58c7b9010>,
#  <__main__.node at 0x7fe64c14b710>,
#  <__main__.node at 0x7fe63a5dd150>,
#  <__main__.node at 0x7fe628157f50>,
#  <__main__.node at 0x7fe618573fd0>,
#  <__main__.node at 0x7fe65c308550>,
#  <__main__.node at 0x7fe61841c050>,
#  <__main__.node at 0x7fe61841c150>,
#  <__main__.node at 0x7fe61841c2d0>,
#  <__main__.node at 0x7fe61841c490>,
#  <__main__.node at 0x7fe61841c550>,
#  <__main__.node at 0x7fe61841c6d0>,
#  <__main__.node at 0x7fe61841c890>,
#  <__main__.node at 0x7fe61841c950>,
#  <__main__.node at 0x7fe61841cad0>,
#  <__main__.node at 0x7fe61841cc90>,
#  <__main__.node at 0x7fe61841cd50>,
#  <__main__.node at 0x7fe61841ced0>,
#  <__main__.node at 0x7fe61841d090>,
#  <__main__.node at 0x7fe61841d150>,
#  <__main__.node at 0x7fe61841d2d0>,
#  <__main__.node at 0x7fe61841d490>,
#  <__main__.node at 0x7fe61841d550>,
#  <__main__.node at 0x7fe61841d6d0>,
#  <__main__.node at 0x7fe61841d890>,
#  <__main__.node at 0x7fe61841d950>,
#  <__main__.node at 0x7fe61841dad0>,
#  <__main__.node at 0x7fe61841dc90>,
#  <__main__.node at 0x7fe61841dd50>,
#  <__main__.node at 0x7fe61841ded0>,
#  <__main__.node at 0x7fe61841e090>,
#  <__main__.node at 0x7fe61841e150>,
#  <__main__.node at 0x7fe61841e2d0>,
#  <__main__.node at 0x7fe61841e490>,
#  <__main__.node at 0x7fe61841e550>,
#  <__main__.node at 0x7fe61841e6d0>,
#  <__main__.node at 0x7fe61841e890>,
#  <__main__.node at 0x7fe61841e950>,
#  <__main__.node at 0x7fe61841ead0>,
#  <__main__.node at 0x7fe61841ec90>,
#  <__main__.node at 0x7fe61841ed50>,
#  <__main__.node at 0x7fe61841eed0>,
#  <__main__.node at 0x7fe61841f090>,
#  <__main__.node at 0x7fe61841f150>,
#  <__main__.node at 0x7fe61841f2d0>,
#  <__main__.node at 0x7fe61841f490>,
#  <__main__.node at 0x7fe61841f550>,
#  <__main__.node at 0x7fe61841f6d0>,
#  <__main__.node at 0x7fe61841f890>,
#  <__main__.node at 0x7fe61841f950>,
#  <__main__.node at 0x7fe61841fad0>,
#  <__main__.node at 0x7fe61841fc90>,
#  <__main__.node at 0x7fe61841fd50>,
#  <__main__.node at 0x7fe61841fed0>,
#  <__main__.node at 0x7fe6184200d0>,
#  <__main__.node at 0x7fe618420190>,
#  <__main__.node at 0x7fe618420310>,
#  <__main__.node at 0x7fe6184204d0>,
#  <__main__.node at 0x7fe618420590>,
#  <__main__.node at 0x7fe618420710>,
#  <__main__.node at 0x7fe6184208d0>,
#  <__main__.node at 0x7fe618420990>,
#  <__main__.node at 0x7fe618420b10>,
#  <__main__.node at 0x7fe618420cd0>,
#  <__main__.node at 0x7fe618420d90>,
#  <__main__.node at 0x7fe618420f10>,
#  <__main__.node at 0x7fe6184210d0>,
#  <__main__.node at 0x7fe618421190>,
#  <__main__.node at 0x7fe618421310>,
#  <__main__.node at 0x7fe6184214d0>,
#  <__main__.node at 0x7fe618421590>,
#  <__main__.node at 0x7fe618421710>,
#  <__main__.node at 0x7fe6184218d0>,
#  <__main__.node at 0x7fe618421990>,
#  <__main__.node at 0x7fe618421b10>,
#  <__main__.node at 0x7fe618421cd0>,
#  <__main__.node at 0x7fe618421d90>,
#  <__main__.node at 0x7fe618421f10>,
#  <__main__.node at 0x7fe6184220d0>,
#  <__main__.node at 0x7fe618422190>,
#  <__main__.node at 0x7fe618422310>,
#  <__main__.node at 0x7fe6184224d0>,
#  <__main__.node at 0x7fe618422590>,
#  <__main__.node at 0x7fe618422710>,
#  <__main__.node at 0x7fe6184228d0>,
#  <__main__.node at 0x7fe618422990>,
#  <__main__.node at 0x7fe618422b10>,
#  <__main__.node at 0x7fe618422cd0>,
#  <__main__.node at 0x7fe618422d90>,
#  <__main__.node at 0x7fe618422f10>,
#  <__main__.node at 0x7fe6184230d0>,
#  <__main__.node at 0x7fe618423190>,
#  <__main__.node at 0x7fe618423310>,
#  <__main__.node at 0x7fe6184234d0>,
#  <__main__.node at 0x7fe618423590>,
#  <__main__.node at 0x7fe618423710>,
#  <__main__.node at 0x7fe6184238d0>,
#  <__main__.node at 0x7fe618423990>,
#  <__main__.node at 0x7fe618423b10>,
#  <__main__.node at 0x7fe618423cd0>,
#  <__main__.node at 0x7fe618423d90>,
#  <__main__.node at 0x7fe618423f10>,
#  <__main__.node at 0x7fe618424110>,
#  <__main__.node at 0x7fe6184241d0>,
#  <__main__.node at 0x7fe618424350>,
#  <__main__.node at 0x7fe618424510>,
#  <__main__.node at 0x7fe6184245d0>,
#  <__main__.node at 0x7fe618424750>,
#  <__main__.node at 0x7fe618424910>,
#  <__main__.node at 0x7fe6184249d0>,
#  <__main__.node at 0x7fe618424b50>,
#  <__main__.node at 0x7fe618424d10>,
#  <__main__.node at 0x7fe618424dd0>,
#  <__main__.node at 0x7fe618424f50>,
#  <__main__.node at 0x7fe618425110>,
#  <__main__.node at 0x7fe6184251d0>,
#  <__main__.node at 0x7fe618425350>,
#  <__main__.node at 0x7fe618425510>,
#  <__main__.node at 0x7fe6184255d0>,
#  <__main__.node at 0x7fe618425750>,
#  <__main__.node at 0x7fe618425910>,
#  <__main__.node at 0x7fe6184259d0>,
#  <__main__.node at 0x7fe618425b50>,
#  <__main__.node at 0x7fe618425d10>,
#  <__main__.node at 0x7fe618425dd0>,
#  <__main__.node at 0x7fe618425f50>,
#  <__main__.node at 0x7fe618426110>,
#  <__main__.node at 0x7fe6184261d0>,
#  <__main__.node at 0x7fe618426350>,
#  <__main__.node at 0x7fe618426510>,
#  <__main__.node at 0x7fe6184265d0>,
#  <__main__.node at 0x7fe618426750>,
#  <__main__.node at 0x7fe618426910>,
#  <__main__.node at 0x7fe6184269d0>,
#  <__main__.node at 0x7fe618426b50>,
#  <__main__.node at 0x7fe618426d10>,
#  <__main__.node at 0x7fe618426dd0>,
#  <__main__.node at 0x7fe618426f50>,
#  <__main__.node at 0x7fe618427110>,
#  <__main__.node at 0x7fe6184271d0>,
#  <__main__.node at 0x7fe618427350>,
#  <__main__.node at 0x7fe618427510>,
#  <__main__.node at 0x7fe6184275d0>,
#  <__main__.node at 0x7fe618427750>,
#  <__main__.node at 0x7fe618427910>,
#  <__main__.node at 0x7fe6184279d0>,
#  <__main__.node at 0x7fe618427b50>,
#  <__main__.node at 0x7fe618427d10>,
#  <__main__.node at 0x7fe618427dd0>,
#  <__main__.node at 0x7fe618427f50>,
#  <__main__.node at 0x7fe61842c150>,
#  <__main__.node at 0x7fe61842c210>,
#  <__main__.node at 0x7fe61842c390>,
#  <__main__.node at 0x7fe61842c550>,
#  <__main__.node at 0x7fe61842c610>,
#  <__main__.node at 0x7fe61842c790>,
#  <__main__.node at 0x7fe61842c950>,
#  <__main__.node at 0x7fe61842ca10>,
#  <__main__.node at 0x7fe61842cb90>,
#  <__main__.node at 0x7fe61842cd50>,
#  <__main__.node at 0x7fe61842ce10>,
#  <__main__.node at 0x7fe61842cf90>,
#  <__main__.node at 0x7fe61842d150>,
#  <__main__.node at 0x7fe61842d210>,
#  <__main__.node at 0x7fe61842d390>,
#  <__main__.node at 0x7fe61842d550>,
#  <__main__.node at 0x7fe61842d610>,
#  <__main__.node at 0x7fe61842d790>,
#  <__main__.node at 0x7fe61842d950>,
#  <__main__.node at 0x7fe61842da10>,
#  <__main__.node at 0x7fe61842db90>,
#  <__main__.node at 0x7fe61842dd50>,
#  <__main__.node at 0x7fe61842de10>,
#  <__main__.node at 0x7fe61842df90>,
#  <__main__.node at 0x7fe61842e150>,
#  <__main__.node at 0x7fe61842e210>,
#  <__main__.node at 0x7fe61842e390>,
#  <__main__.node at 0x7fe61842e550>,
#  <__main__.node at 0x7fe61842e610>,
#  <__main__.node at 0x7fe61842e790>,
#  <__main__.node at 0x7fe61842e950>,
#  <__main__.node at 0x7fe61842ea10>,
#  <__main__.node at 0x7fe61842eb90>,
#  <__main__.node at 0x7fe61842ed50>,
#  <__main__.node at 0x7fe61842ee10>,
#  <__main__.node at 0x7fe61842ef90>,
#  <__main__.node at 0x7fe61842f150>,
#  <__main__.node at 0x7fe61842f210>,
#  <__main__.node at 0x7fe61842f390>,
#  <__main__.node at 0x7fe61842f550>,
#  <__main__.node at 0x7fe61842f610>,
#  <__main__.node at 0x7fe61842f790>,
#  <__main__.node at 0x7fe61842f950>,
#  <__main__.node at 0x7fe61842fa10>,
#  <__main__.node at 0x7fe61842fb90>,
#  <__main__.node at 0x7fe61842fd50>,
#  <__main__.node at 0x7fe61842fe10>,
#  <__main__.node at 0x7fe61842ff90>,
#  <__main__.node at 0x7fe618434190>,
#  <__main__.node at 0x7fe618434250>,
#  <__main__.node at 0x7fe6184343d0>,
#  <__main__.node at 0x7fe618434590>,
#  <__main__.node at 0x7fe618434650>,
#  <__main__.node at 0x7fe6184347d0>,
#  <__main__.node at 0x7fe618434990>,
#  <__main__.node at 0x7fe618434a50>,
#  <__main__.node at 0x7fe618434bd0>,
#  <__main__.node at 0x7fe618434d90>,
#  <__main__.node at 0x7fe618434e50>,
#  <__main__.node at 0x7fe618434fd0>,
#  <__main__.node at 0x7fe618435190>,
#  <__main__.node at 0x7fe618435250>,
#  <__main__.node at 0x7fe6184353d0>,
#  <__main__.node at 0x7fe618435590>,
#  <__main__.node at 0x7fe618435650>,
#  <__main__.node at 0x7fe6184357d0>,
#  <__main__.node at 0x7fe618435990>,
#  <__main__.node at 0x7fe618435a50>,
#  <__main__.node at 0x7fe618435bd0>,
#  <__main__.node at 0x7fe618435d90>,
#  <__main__.node at 0x7fe618435e50>,
#  <__main__.node at 0x7fe618435fd0>,
#  <__main__.node at 0x7fe618436190>,
#  <__main__.node at 0x7fe618436250>,
#  <__main__.node at 0x7fe6184363d0>,
#  <__main__.node at 0x7fe618436590>,
#  <__main__.node at 0x7fe618436650>,
#  <__main__.node at 0x7fe6184367d0>,
#  <__main__.node at 0x7fe618436990>,
#  <__main__.node at 0x7fe618436a50>,
#  <__main__.node at 0x7fe618436bd0>,
#  <__main__.node at 0x7fe618436d90>,
#  <__main__.node at 0x7fe618436e50>,
#  <__main__.node at 0x7fe618436fd0>,
#  <__main__.node at 0x7fe618437190>,
#  <__main__.node at 0x7fe618437250>,
#  <__main__.node at 0x7fe6184373d0>,
#  <__main__.node at 0x7fe618437590>,
#  <__main__.node at 0x7fe618437650>,
#  <__main__.node at 0x7fe6184377d0>,
#  <__main__.node at 0x7fe618437990>,
#  <__main__.node at 0x7fe618437a50>,
#  <__main__.node at 0x7fe618437bd0>,
#  <__main__.node at 0x7fe618437d90>,
#  <__main__.node at 0x7fe618437e50>,
#  <__main__.node at 0x7fe618437fd0>,
#  <__main__.node at 0x7fe61843c1d0>,
#  <__main__.node at 0x7fe61843c290>,
#  <__main__.node at 0x7fe61843c410>,
#  <__main__.node at 0x7fe61843c5d0>,
#  <__main__.node at 0x7fe61843c690>,
#  <__main__.node at 0x7fe61843c810>,
#  <__main__.node at 0x7fe61843c9d0>,
#  <__main__.node at 0x7fe61843ca90>,
#  <__main__.node at 0x7fe61843cc10>,
#  <__main__.node at 0x7fe61843cdd0>,
#  <__main__.node at 0x7fe61843ce90>,
#  <__main__.node at 0x7fe61843d010>,
#  <__main__.node at 0x7fe61843d1d0>,
#  <__main__.node at 0x7fe61843d290>,
#  <__main__.node at 0x7fe61843d410>,
#  <__main__.node at 0x7fe61843d5d0>,
#  <__main__.node at 0x7fe61843d690>,
#  <__main__.node at 0x7fe61843d810>,
#  <__main__.node at 0x7fe61843d9d0>,
#  <__main__.node at 0x7fe61843da90>,
#  <__main__.node at 0x7fe61843dc10>,
#  <__main__.node at 0x7fe61843ddd0>,
#  <__main__.node at 0x7fe61843de90>,
#  <__main__.node at 0x7fe61843e010>,
#  <__main__.node at 0x7fe61843e1d0>,
#  <__main__.node at 0x7fe61843e290>,
#  <__main__.node at 0x7fe61843e410>,
#  <__main__.node at 0x7fe61843e5d0>,
#  <__main__.node at 0x7fe61843e690>,
#  <__main__.node at 0x7fe61843e810>,
#  <__main__.node at 0x7fe61843e9d0>,
#  <__main__.node at 0x7fe61843ea90>,
#  <__main__.node at 0x7fe61843ec10>,
#  <__main__.node at 0x7fe61843edd0>,
#  <__main__.node at 0x7fe61843ee90>,
#  <__main__.node at 0x7fe61843f010>,
#  <__main__.node at 0x7fe61843f1d0>,
#  <__main__.node at 0x7fe61843f290>,
#  <__main__.node at 0x7fe61843f410>,
#  <__main__.node at 0x7fe61843f5d0>,
#  <__main__.node at 0x7fe61843f690>,
#  <__main__.node at 0x7fe61843f810>,
#  <__main__.node at 0x7fe61843f9d0>,
#  <__main__.node at 0x7fe61843fa90>,
#  <__main__.node at 0x7fe61843fc10>,
#  <__main__.node at 0x7fe61843fdd0>,
#  <__main__.node at 0x7fe61843fe90>,
#  <__main__.node at 0x7fe618440050>,
#  <__main__.node at 0x7fe618440210>,
#  <__main__.node at 0x7fe6184402d0>,
#  <__main__.node at 0x7fe618440450>,
#  <__main__.node at 0x7fe618440610>,
#  <__main__.node at 0x7fe6184406d0>,
#  <__main__.node at 0x7fe618440850>,
#  <__main__.node at 0x7fe618440a10>,
#  <__main__.node at 0x7fe618440ad0>,
#  <__main__.node at 0x7fe618440c50>,
#  <__main__.node at 0x7fe618440e10>,
#  <__main__.node at 0x7fe618440ed0>,
#  <__main__.node at 0x7fe618441050>,
#  <__main__.node at 0x7fe618441210>,
#  <__main__.node at 0x7fe6184412d0>,
#  <__main__.node at 0x7fe618441450>,
#  <__main__.node at 0x7fe618441610>,
#  <__main__.node at 0x7fe6184416d0>,
#  <__main__.node at 0x7fe618441850>,
#  <__main__.node at 0x7fe618441a10>,
#  <__main__.node at 0x7fe618441ad0>,
#  <__main__.node at 0x7fe618441c50>,
#  <__main__.node at 0x7fe618441e10>,
#  <__main__.node at 0x7fe618441ed0>,
#  <__main__.node at 0x7fe618442050>,
#  <__main__.node at 0x7fe618442210>,
#  <__main__.node at 0x7fe6184422d0>,
#  <__main__.node at 0x7fe618442450>,
#  <__main__.node at 0x7fe618442610>,
#  <__main__.node at 0x7fe6184426d0>,
#  <__main__.node at 0x7fe618442850>,
#  <__main__.node at 0x7fe618442a10>,
#  <__main__.node at 0x7fe618442ad0>,
#  <__main__.node at 0x7fe618442c50>,
#  <__main__.node at 0x7fe618442e10>,
#  <__main__.node at 0x7fe618442ed0>,
#  <__main__.node at 0x7fe618443050>,
#  <__main__.node at 0x7fe618443210>,
#  <__main__.node at 0x7fe6184432d0>,
#  <__main__.node at 0x7fe618443450>,
#  <__main__.node at 0x7fe618443610>,
#  <__main__.node at 0x7fe6184436d0>,
#  <__main__.node at 0x7fe618443850>,
#  <__main__.node at 0x7fe618443a10>,
#  <__main__.node at 0x7fe618443ad0>,
#  <__main__.node at 0x7fe618443c50>,
#  <__main__.node at 0x7fe618443e10>,
#  <__main__.node at 0x7fe618443ed0>,
#  <__main__.node at 0x7fe618448090>,
#  <__main__.node at 0x7fe618448250>,
#  <__main__.node at 0x7fe618448310>,
#  <__main__.node at 0x7fe618448490>,
#  <__main__.node at 0x7fe618448650>,
#  <__main__.node at 0x7fe618448710>,
#  <__main__.node at 0x7fe618448890>,
#  <__main__.node at 0x7fe618448a50>,
#  <__main__.node at 0x7fe618448b10>,
#  <__main__.node at 0x7fe618448c90>,
#  <__main__.node at 0x7fe618448e50>,
#  <__main__.node at 0x7fe618448f10>,
#  <__main__.node at 0x7fe618449090>,
#  <__main__.node at 0x7fe618449250>,
#  <__main__.node at 0x7fe618449310>,
#  <__main__.node at 0x7fe618449490>,
#  <__main__.node at 0x7fe618449650>,
#  <__main__.node at 0x7fe618449710>,
#  <__main__.node at 0x7fe618449890>,
#  <__main__.node at 0x7fe618449a50>,
#  <__main__.node at 0x7fe618449b10>,
#  <__main__.node at 0x7fe618449c90>,
#  <__main__.node at 0x7fe618449e50>,
#  <__main__.node at 0x7fe618449f10>,
#  <__main__.node at 0x7fe61844a090>,
#  <__main__.node at 0x7fe61844a250>,
#  <__main__.node at 0x7fe61844a310>,
#  <__main__.node at 0x7fe61844a490>,
#  <__main__.node at 0x7fe61844a650>,
#  <__main__.node at 0x7fe61844a710>,
#  <__main__.node at 0x7fe61844a890>,
#  <__main__.node at 0x7fe61844aa50>,
#  <__main__.node at 0x7fe61844ab10>,
#  <__main__.node at 0x7fe61844ac90>,
#  <__main__.node at 0x7fe61844ae50>,
#  <__main__.node at 0x7fe61844af10>,
#  <__main__.node at 0x7fe61844b090>,
#  <__main__.node at 0x7fe61844b250>,
#  <__main__.node at 0x7fe61844b310>,
#  <__main__.node at 0x7fe61844b490>,
#  <__main__.node at 0x7fe61844b650>,
#  <__main__.node at 0x7fe61844b710>,
#  <__main__.node at 0x7fe61844b890>,
#  <__main__.node at 0x7fe61844ba50>,
#  <__main__.node at 0x7fe61844bb10>,
#  <__main__.node at 0x7fe61844bc90>,
#  <__main__.node at 0x7fe61844be50>,
#  <__main__.node at 0x7fe61844bf10>,
#  <__main__.node at 0x7fe6184500d0>,
#  <__main__.node at 0x7fe618450290>,
#  <__main__.node at 0x7fe618450350>,
#  <__main__.node at 0x7fe6184504d0>,
#  <__main__.node at 0x7fe618450690>,
#  <__main__.node at 0x7fe618450750>,
#  <__main__.node at 0x7fe6184508d0>,
#  <__main__.node at 0x7fe618450a90>,
#  <__main__.node at 0x7fe618450b50>,
#  <__main__.node at 0x7fe618450cd0>,
#  <__main__.node at 0x7fe618450e90>,
#  <__main__.node at 0x7fe618450f50>,
#  <__main__.node at 0x7fe6184510d0>,
#  <__main__.node at 0x7fe618451290>,
#  <__main__.node at 0x7fe618451350>,
#  <__main__.node at 0x7fe6184514d0>,
#  <__main__.node at 0x7fe618451690>,
#  <__main__.node at 0x7fe618451750>,
#  <__main__.node at 0x7fe6184518d0>,
#  <__main__.node at 0x7fe618451a90>,
#  <__main__.node at 0x7fe618451b50>,
#  <__main__.node at 0x7fe618451cd0>,
#  <__main__.node at 0x7fe618451e90>,
#  <__main__.node at 0x7fe618451f50>,
#  <__main__.node at 0x7fe6184520d0>,
#  <__main__.node at 0x7fe618452290>,
#  <__main__.node at 0x7fe618452350>,
#  <__main__.node at 0x7fe6184524d0>,
#  <__main__.node at 0x7fe618452690>,
#  <__main__.node at 0x7fe618452750>,
#  <__main__.node at 0x7fe6184528d0>,
#  <__main__.node at 0x7fe618452a90>,
#  <__main__.node at 0x7fe618452b50>,
#  <__main__.node at 0x7fe618452cd0>,
#  <__main__.node at 0x7fe618452e90>,
#  <__main__.node at 0x7fe618452f50>,
#  <__main__.node at 0x7fe6184530d0>,
#  <__main__.node at 0x7fe618453290>,
#  <__main__.node at 0x7fe618453350>,
#  <__main__.node at 0x7fe6184534d0>,
#  <__main__.node at 0x7fe618453690>,
#  <__main__.node at 0x7fe618453750>,
#  <__main__.node at 0x7fe6184538d0>,
#  <__main__.node at 0x7fe618453a90>,
#  <__main__.node at 0x7fe618453b50>,
#  <__main__.node at 0x7fe618453cd0>,
#  <__main__.node at 0x7fe618453e90>,
#  <__main__.node at 0x7fe618453f50>,
#  <__main__.node at 0x7fe618458110>,
#  <__main__.node at 0x7fe6184582d0>,
#  <__main__.node at 0x7fe618458390>,
#  <__main__.node at 0x7fe618458510>,
#  <__main__.node at 0x7fe6184586d0>,
#  <__main__.node at 0x7fe618458790>,
#  <__main__.node at 0x7fe618458910>,
#  <__main__.node at 0x7fe618458ad0>,
#  <__main__.node at 0x7fe618458b90>,
#  <__main__.node at 0x7fe618458d10>,
#  <__main__.node at 0x7fe618458ed0>,
#  <__main__.node at 0x7fe618458f90>,
#  <__main__.node at 0x7fe618459110>,
#  <__main__.node at 0x7fe6184592d0>,
#  <__main__.node at 0x7fe618459390>,
#  <__main__.node at 0x7fe618459510>,
#  <__main__.node at 0x7fe6184596d0>,
#  <__main__.node at 0x7fe618459790>,
#  <__main__.node at 0x7fe618459910>,
#  <__main__.node at 0x7fe618459ad0>,
#  <__main__.node at 0x7fe618459b90>,
#  <__main__.node at 0x7fe618459d10>,
#  <__main__.node at 0x7fe618459ed0>,
#  <__main__.node at 0x7fe618459f90>,
#  <__main__.node at 0x7fe61845a110>,
#  <__main__.node at 0x7fe61845a2d0>,
#  <__main__.node at 0x7fe61845a390>,
#  <__main__.node at 0x7fe61845a510>,
#  <__main__.node at 0x7fe61845a6d0>,
#  <__main__.node at 0x7fe61845a790>,
#  <__main__.node at 0x7fe61845a910>,
#  <__main__.node at 0x7fe61845aad0>,
#  <__main__.node at 0x7fe61845ab90>,
#  <__main__.node at 0x7fe61845ad10>,
#  <__main__.node at 0x7fe61845aed0>,
#  <__main__.node at 0x7fe61845af90>,
#  <__main__.node at 0x7fe61845b110>,
#  <__main__.node at 0x7fe61845b2d0>,
#  <__main__.node at 0x7fe61845b390>,
#  <__main__.node at 0x7fe61845b510>,
#  <__main__.node at 0x7fe61845b6d0>,
#  <__main__.node at 0x7fe61845b790>,
#  <__main__.node at 0x7fe61845b910>,
#  <__main__.node at 0x7fe61845bad0>,
#  <__main__.node at 0x7fe61845bb90>,
#  <__main__.node at 0x7fe61845bd10>,
#  <__main__.node at 0x7fe61845bed0>,
#  <__main__.node at 0x7fe61845bf90>,
#  <__main__.node at 0x7fe61845c150>,
#  <__main__.node at 0x7fe61845c310>,
#  <__main__.node at 0x7fe61845c3d0>,
#  <__main__.node at 0x7fe61845c550>,
#  <__main__.node at 0x7fe61845c710>,
#  <__main__.node at 0x7fe61845c7d0>,
#  <__main__.node at 0x7fe61845c950>,
#  <__main__.node at 0x7fe61845cb10>,
#  <__main__.node at 0x7fe61845cbd0>,
#  <__main__.node at 0x7fe61845cd50>,
#  <__main__.node at 0x7fe61845cf10>,
#  <__main__.node at 0x7fe61845cfd0>,
#  <__main__.node at 0x7fe61845d150>,
#  <__main__.node at 0x7fe61845d310>,
#  <__main__.node at 0x7fe61845d3d0>,
#  <__main__.node at 0x7fe61845d550>,
#  <__main__.node at 0x7fe61845d710>,
#  <__main__.node at 0x7fe61845d7d0>,
#  <__main__.node at 0x7fe61845d950>,
#  <__main__.node at 0x7fe61845db10>,
#  <__main__.node at 0x7fe61845dbd0>,
#  <__main__.node at 0x7fe61845dd50>,
#  <__main__.node at 0x7fe61845df10>,
#  <__main__.node at 0x7fe61845dfd0>,
#  <__main__.node at 0x7fe61845e150>,
#  <__main__.node at 0x7fe61845e310>,
#  <__main__.node at 0x7fe61845e3d0>,
#  <__main__.node at 0x7fe61845e550>,
#  <__main__.node at 0x7fe61845e710>,
#  <__main__.node at 0x7fe61845e7d0>,
#  <__main__.node at 0x7fe61845e950>,
#  <__main__.node at 0x7fe61845eb10>,
#  <__main__.node at 0x7fe61845ebd0>,
#  <__main__.node at 0x7fe61845ed50>,
#  <__main__.node at 0x7fe61845ef10>,
#  <__main__.node at 0x7fe61845efd0>,
#  <__main__.node at 0x7fe61845f150>,
#  <__main__.node at 0x7fe61845f310>,
#  <__main__.node at 0x7fe61845f3d0>,
#  <__main__.node at 0x7fe61845f550>,
#  <__main__.node at 0x7fe61845f710>,
#  <__main__.node at 0x7fe61845f7d0>,
#  <__main__.node at 0x7fe61845f950>,
#  <__main__.node at 0x7fe61845fb10>,
#  <__main__.node at 0x7fe61845fbd0>,
#  <__main__.node at 0x7fe61845fd50>,
#  <__main__.node at 0x7fe61845ff10>,
#  <__main__.node at 0x7fe618464050>,
#  <__main__.node at 0x7fe618464190>,
#  <__main__.node at 0x7fe618464350>,
#  <__main__.node at 0x7fe618464410>,
#  <__main__.node at 0x7fe618464590>,
#  <__main__.node at 0x7fe618464750>,
#  <__main__.node at 0x7fe618464810>,
#  <__main__.node at 0x7fe618464990>,
#  <__main__.node at 0x7fe618464b50>,
#  <__main__.node at 0x7fe618464c10>,
#  <__main__.node at 0x7fe618464d90>,
#  <__main__.node at 0x7fe618464f50>,
#  <__main__.node at 0x7fe618465010>,
#  <__main__.node at 0x7fe618465190>,
#  <__main__.node at 0x7fe618465350>,
#  <__main__.node at 0x7fe618465410>,
#  <__main__.node at 0x7fe618465590>,
#  <__main__.node at 0x7fe618465750>,
#  <__main__.node at 0x7fe618465810>,
#  <__main__.node at 0x7fe618465990>,
#  <__main__.node at 0x7fe618465b50>,
#  <__main__.node at 0x7fe618465c10>,
#  <__main__.node at 0x7fe618465d90>,
#  <__main__.node at 0x7fe618465f50>,
#  <__main__.node at 0x7fe618466010>,
#  <__main__.node at 0x7fe618466190>,
#  <__main__.node at 0x7fe618466350>,
#  <__main__.node at 0x7fe618466410>,
#  <__main__.node at 0x7fe618466590>,
#  <__main__.node at 0x7fe618466750>,
#  <__main__.node at 0x7fe618466810>,
#  <__main__.node at 0x7fe618466990>,
#  <__main__.node at 0x7fe618466b50>,
#  <__main__.node at 0x7fe618466c10>,
#  <__main__.node at 0x7fe618466d90>,
#  <__main__.node at 0x7fe618466f50>,
#  <__main__.node at 0x7fe618467010>,
#  <__main__.node at 0x7fe618467190>,
#  <__main__.node at 0x7fe618467350>,
#  <__main__.node at 0x7fe618467410>,
#  <__main__.node at 0x7fe618467590>,
#  <__main__.node at 0x7fe618467750>,
#  <__main__.node at 0x7fe618467810>,
#  <__main__.node at 0x7fe618467990>,
#  <__main__.node at 0x7fe618467b50>,
#  <__main__.node at 0x7fe618467c10>,
#  <__main__.node at 0x7fe618467d90>,
#  <__main__.node at 0x7fe618467f50>,
#  <__main__.node at 0x7fe618470050>,
#  <__main__.node at 0x7fe6184701d0>,
#  <__main__.node at 0x7fe618470390>,
#  <__main__.node at 0x7fe618470450>,
#  <__main__.node at 0x7fe6184705d0>,
#  <__main__.node at 0x7fe618470790>,
#  <__main__.node at 0x7fe618470850>,
#  <__main__.node at 0x7fe6184709d0>,
#  <__main__.node at 0x7fe618470b90>,
#  <__main__.node at 0x7fe618470c50>,
#  <__main__.node at 0x7fe618470dd0>,
#  <__main__.node at 0x7fe618470f90>,
#  <__main__.node at 0x7fe618471050>,
#  <__main__.node at 0x7fe6184711d0>,
#  <__main__.node at 0x7fe618471390>,
#  <__main__.node at 0x7fe618471450>,
#  <__main__.node at 0x7fe6184715d0>,
#  <__main__.node at 0x7fe618471790>,
#  <__main__.node at 0x7fe618471850>,
#  <__main__.node at 0x7fe6184719d0>,
#  <__main__.node at 0x7fe618471b90>,
#  <__main__.node at 0x7fe618471c50>,
#  <__main__.node at 0x7fe618471dd0>,
#  <__main__.node at 0x7fe618471f90>,
#  <__main__.node at 0x7fe618472050>,
#  <__main__.node at 0x7fe6184721d0>,
#  <__main__.node at 0x7fe618472390>,
#  <__main__.node at 0x7fe618472450>,
#  <__main__.node at 0x7fe6184725d0>,
#  <__main__.node at 0x7fe618472790>,
#  <__main__.node at 0x7fe618472850>,
#  <__main__.node at 0x7fe6184729d0>,
#  <__main__.node at 0x7fe618472b90>,
#  <__main__.node at 0x7fe618472c50>,
#  <__main__.node at 0x7fe618472dd0>,
#  <__main__.node at 0x7fe618472f90>,
#  <__main__.node at 0x7fe618473050>,
#  <__main__.node at 0x7fe6184731d0>,
#  <__main__.node at 0x7fe618473390>,
#  <__main__.node at 0x7fe618473450>,
#  <__main__.node at 0x7fe6184735d0>,
#  <__main__.node at 0x7fe618473790>,
#  <__main__.node at 0x7fe618473850>,
#  <__main__.node at 0x7fe6184739d0>,
#  <__main__.node at 0x7fe618473b90>,
#  <__main__.node at 0x7fe618473c50>,
#  <__main__.node at 0x7fe618473dd0>,
#  <__main__.node at 0x7fe618473f90>,
#  <__main__.node at 0x7fe618474090>,
#  <__main__.node at 0x7fe618474210>,
#  <__main__.node at 0x7fe6184743d0>,
#  <__main__.node at 0x7fe618474490>,
#  <__main__.node at 0x7fe618474610>,
#  <__main__.node at 0x7fe6184747d0>,
#  <__main__.node at 0x7fe618474890>,
#  <__main__.node at 0x7fe618474a10>,
#  <__main__.node at 0x7fe618474bd0>,
#  <__main__.node at 0x7fe618474c90>,
#  <__main__.node at 0x7fe618474e10>,
#  <__main__.node at 0x7fe618474fd0>,
#  <__main__.node at 0x7fe618475090>,
#  <__main__.node at 0x7fe618475210>,
#  <__main__.node at 0x7fe6184753d0>,
#  <__main__.node at 0x7fe618475490>,
#  <__main__.node at 0x7fe618475610>,
#  <__main__.node at 0x7fe6184757d0>,
#  <__main__.node at 0x7fe618475890>,
#  <__main__.node at 0x7fe618475a10>,
#  <__main__.node at 0x7fe618475bd0>,
#  <__main__.node at 0x7fe618475c90>,
#  <__main__.node at 0x7fe618475e10>,
#  <__main__.node at 0x7fe618475fd0>,
#  <__main__.node at 0x7fe618476090>,
#  <__main__.node at 0x7fe618476210>,
#  <__main__.node at 0x7fe6184763d0>,
#  <__main__.node at 0x7fe618476490>,
#  <__main__.node at 0x7fe618476610>,
#  <__main__.node at 0x7fe6184767d0>,
#  <__main__.node at 0x7fe618476890>,
#  <__main__.node at 0x7fe618476a10>,
#  <__main__.node at 0x7fe618476bd0>,
#  <__main__.node at 0x7fe618476c90>,
#  <__main__.node at 0x7fe618476e10>,
#  <__main__.node at 0x7fe618476fd0>,
#  <__main__.node at 0x7fe618477090>,
#  <__main__.node at 0x7fe618477210>,
#  <__main__.node at 0x7fe6184773d0>,
#  <__main__.node at 0x7fe618477490>,
#  <__main__.node at 0x7fe618477610>,
#  <__main__.node at 0x7fe6184777d0>,
#  <__main__.node at 0x7fe618477890>,
#  <__main__.node at 0x7fe618477a10>,
#  <__main__.node at 0x7fe618477bd0>,
#  <__main__.node at 0x7fe618477c90>,
#  <__main__.node at 0x7fe618477e10>,
#  <__main__.node at 0x7fe618477fd0>,
#  <__main__.node at 0x7fe61847c0d0>,
#  <__main__.node at 0x7fe61847c250>,
#  <__main__.node at 0x7fe61847c410>,
#  <__main__.node at 0x7fe61847c4d0>,
#  <__main__.node at 0x7fe61847c650>,
#  <__main__.node at 0x7fe61847c810>,
#  <__main__.node at 0x7fe61847c8d0>,
#  <__main__.node at 0x7fe61847ca50>,
#  <__main__.node at 0x7fe61847cc10>,
#  <__main__.node at 0x7fe61847ccd0>,
#  <__main__.node at 0x7fe61847ce50>,
#  <__main__.node at 0x7fe61847d010>,
#  <__main__.node at 0x7fe61847d0d0>,
#  <__main__.node at 0x7fe61847d250>,
#  <__main__.node at 0x7fe61847d410>,
#  <__main__.node at 0x7fe61847d4d0>,
#  <__main__.node at 0x7fe61847d650>,
#  <__main__.node at 0x7fe61847d810>,
#  <__main__.node at 0x7fe61847d8d0>,
#  <__main__.node at 0x7fe61847da50>,
#  <__main__.node at 0x7fe61847dc10>,
#  <__main__.node at 0x7fe61847dcd0>,
#  <__main__.node at 0x7fe61847de50>,
#  <__main__.node at 0x7fe61847e010>,
#  <__main__.node at 0x7fe61847e0d0>,
#  <__main__.node at 0x7fe61847e250>,
#  <__main__.node at 0x7fe61847e410>,
#  <__main__.node at 0x7fe61847e4d0>,
#  <__main__.node at 0x7fe61847e650>,
#  <__main__.node at 0x7fe61847e810>,
#  <__main__.node at 0x7fe61847e8d0>,
#  <__main__.node at 0x7fe61847ea50>,
#  <__main__.node at 0x7fe61847ec10>,
#  <__main__.node at 0x7fe61847ecd0>,
#  <__main__.node at 0x7fe61847ee50>,
#  <__main__.node at 0x7fe61847f010>,
#  <__main__.node at 0x7fe61847f0d0>,
#  <__main__.node at 0x7fe61847f250>,
#  <__main__.node at 0x7fe61847f410>,
#  <__main__.node at 0x7fe61847f4d0>,
#  <__main__.node at 0x7fe61847f650>,
#  <__main__.node at 0x7fe61847f810>,
#  <__main__.node at 0x7fe61847f8d0>,
#  <__main__.node at 0x7fe61847fa50>,
#  <__main__.node at 0x7fe61847fc10>,
#  <__main__.node at 0x7fe61847fcd0>,
#  <__main__.node at 0x7fe61847fe50>,
#  <__main__.node at 0x7fe61847ffd0>,
#  <__main__.node at 0x7fe618480110>,
#  <__main__.node at 0x7fe618480290>,
#  <__main__.node at 0x7fe618480450>,
#  <__main__.node at 0x7fe618480510>,
#  <__main__.node at 0x7fe618480690>,
#  <__main__.node at 0x7fe618480850>,
#  <__main__.node at 0x7fe618480910>,
#  <__main__.node at 0x7fe618480a90>,
#  <__main__.node at 0x7fe618480c50>,
#  <__main__.node at 0x7fe618480d10>,
#  <__main__.node at 0x7fe618480e90>,
#  <__main__.node at 0x7fe618481050>,
#  <__main__.node at 0x7fe618481110>,
#  <__main__.node at 0x7fe618481290>,
#  <__main__.node at 0x7fe618481450>,
#  <__main__.node at 0x7fe618481510>,
#  <__main__.node at 0x7fe618481690>,
#  <__main__.node at 0x7fe618481850>,
#  <__main__.node at 0x7fe618481910>,
#  <__main__.node at 0x7fe618481a90>,
#  <__main__.node at 0x7fe618481c50>,
#  <__main__.node at 0x7fe618481d10>,
#  <__main__.node at 0x7fe618481e90>,
#  <__main__.node at 0x7fe618482050>,
#  <__main__.node at 0x7fe618482110>,
#  <__main__.node at 0x7fe618482290>,
#  <__main__.node at 0x7fe618482450>,
#  <__main__.node at 0x7fe618482510>,
#  <__main__.node at 0x7fe618482690>,
#  <__main__.node at 0x7fe618482850>,
#  <__main__.node at 0x7fe618482910>,
#  <__main__.node at 0x7fe618482a90>,
#  <__main__.node at 0x7fe618482c50>,
#  <__main__.node at 0x7fe618482d10>,
#  <__main__.node at 0x7fe618482e90>,
#  <__main__.node at 0x7fe618483050>,
#  <__main__.node at 0x7fe618483110>,
#  <__main__.node at 0x7fe618483290>,
#  <__main__.node at 0x7fe618483450>,
#  <__main__.node at 0x7fe618483510>,
#  <__main__.node at 0x7fe618483690>,
#  <__main__.node at 0x7fe618483850>,
#  <__main__.node at 0x7fe618483910>,
#  <__main__.node at 0x7fe618483a90>,
#  <__main__.node at 0x7fe618483c50>,
#  <__main__.node at 0x7fe618483d10>,
#  <__main__.node at 0x7fe618483e90>,
#  <__main__.node at 0x7fe61848c090>,
#  <__main__.node at 0x7fe61848c150>,
#  <__main__.node at 0x7fe61848c2d0>,
#  <__main__.node at 0x7fe61848c490>,
#  <__main__.node at 0x7fe61848c550>,
#  <__main__.node at 0x7fe61848c6d0>,
#  <__main__.node at 0x7fe61848c890>,
#  <__main__.node at 0x7fe61848c950>,
#  <__main__.node at 0x7fe61848cad0>,
#  <__main__.node at 0x7fe61848cc90>,
#  <__main__.node at 0x7fe61848cd50>,
#  <__main__.node at 0x7fe61848ced0>,
#  <__main__.node at 0x7fe61848d090>,
#  <__main__.node at 0x7fe61848d150>,
#  <__main__.node at 0x7fe61848d2d0>,
#  <__main__.node at 0x7fe61848d490>,
#  <__main__.node at 0x7fe61848d550>,
#  <__main__.node at 0x7fe61848d6d0>,
#  <__main__.node at 0x7fe61848d890>,
#  <__main__.node at 0x7fe61848d950>,
#  <__main__.node at 0x7fe61848dad0>,
#  <__main__.node at 0x7fe61848dc90>,
#  <__main__.node at 0x7fe61848dd50>,
#  <__main__.node at 0x7fe61848ded0>,
#  <__main__.node at 0x7fe61848e090>,
#  <__main__.node at 0x7fe61848e150>,
#  <__main__.node at 0x7fe61848e2d0>,
#  <__main__.node at 0x7fe61848e490>,
#  <__main__.node at 0x7fe61848e550>,
#  <__main__.node at 0x7fe61848e6d0>,
#  <__main__.node at 0x7fe61848e890>,
#  <__main__.node at 0x7fe61848e950>,
#  <__main__.node at 0x7fe61848ead0>,
#  <__main__.node at 0x7fe61848ec90>,
#  <__main__.node at 0x7fe61848ed50>,
#  <__main__.node at 0x7fe61848eed0>,
#  <__main__.node at 0x7fe61848f090>,
#  <__main__.node at 0x7fe61848f150>,
#  <__main__.node at 0x7fe61848f2d0>,
#  <__main__.node at 0x7fe61848f490>,
#  <__main__.node at 0x7fe61848f550>,
#  <__main__.node at 0x7fe61848f6d0>,
#  <__main__.node at 0x7fe61848f890>,
#  <__main__.node at 0x7fe61848f950>,
#  <__main__.node at 0x7fe61848fad0>,
#  <__main__.node at 0x7fe61848fc90>,
#  <__main__.node at 0x7fe61848fd50>,
#  <__main__.node at 0x7fe61848fed0>,
#  <__main__.node at 0x7fe6184900d0>,
#  <__main__.node at 0x7fe618490190>,
#  <__main__.node at 0x7fe618490310>,
#  <__main__.node at 0x7fe6184904d0>,
#  <__main__.node at 0x7fe618490590>,
#  <__main__.node at 0x7fe618490710>,
#  <__main__.node at 0x7fe6184908d0>,
#  <__main__.node at 0x7fe618490990>,
#  <__main__.node at 0x7fe618490b10>,
#  <__main__.node at 0x7fe618490cd0>,
#  <__main__.node at 0x7fe618490d90>,
#  <__main__.node at 0x7fe618490f10>,
#  <__main__.node at 0x7fe6184910d0>,
#  <__main__.node at 0x7fe618491190>,
#  <__main__.node at 0x7fe618491310>,
#  <__main__.node at 0x7fe6184914d0>,
#  <__main__.node at 0x7fe618491590>,
#  <__main__.node at 0x7fe618491710>,
#  <__main__.node at 0x7fe6184918d0>,
#  <__main__.node at 0x7fe618491990>,
#  <__main__.node at 0x7fe618491b10>,
#  <__main__.node at 0x7fe618491cd0>,
#  <__main__.node at 0x7fe618491d90>,
#  <__main__.node at 0x7fe618491f10>,
#  <__main__.node at 0x7fe6184920d0>,
#  <__main__.node at 0x7fe618492190>,
#  <__main__.node at 0x7fe618492310>,
#  <__main__.node at 0x7fe6184924d0>,
#  <__main__.node at 0x7fe618492590>,
#  <__main__.node at 0x7fe618492710>,
#  <__main__.node at 0x7fe6184928d0>,
#  <__main__.node at 0x7fe618492990>,
#  <__main__.node at 0x7fe618492b10>,
#  <__main__.node at 0x7fe618492cd0>,
#  <__main__.node at 0x7fe618492d90>,
#  <__main__.node at 0x7fe618492f10>,
#  <__main__.node at 0x7fe6184930d0>,
#  <__main__.node at 0x7fe618493190>,
#  <__main__.node at 0x7fe618493310>,
#  <__main__.node at 0x7fe6184934d0>,
#  <__main__.node at 0x7fe618493590>,
#  <__main__.node at 0x7fe618493710>,
#  <__main__.node at 0x7fe6184938d0>,
#  <__main__.node at 0x7fe618493990>,
#  <__main__.node at 0x7fe618493b10>,
#  <__main__.node at 0x7fe618493cd0>,
#  <__main__.node at 0x7fe618493d90>,
#  <__main__.node at 0x7fe618493f10>,
#  <__main__.node at 0x7fe618498110>,
#  <__main__.node at 0x7fe6184981d0>,
#  <__main__.node at 0x7fe618498350>,
#  <__main__.node at 0x7fe618498510>,
#  <__main__.node at 0x7fe6184985d0>,
#  <__main__.node at 0x7fe618498750>,
#  <__main__.node at 0x7fe618498910>,
#  <__main__.node at 0x7fe6184989d0>,
#  <__main__.node at 0x7fe618498b50>,
#  <__main__.node at 0x7fe618498d10>,
#  <__main__.node at 0x7fe618498dd0>,
#  <__main__.node at 0x7fe618498f50>,
#  <__main__.node at 0x7fe618499110>,
#  <__main__.node at 0x7fe6184991d0>,
#  <__main__.node at 0x7fe618499350>,
#  <__main__.node at 0x7fe618499510>,
#  <__main__.node at 0x7fe6184995d0>,
#  <__main__.node at 0x7fe618499750>,
#  <__main__.node at 0x7fe618499910>,
#  <__main__.node at 0x7fe6184999d0>,
#  <__main__.node at 0x7fe618499b50>,
#  <__main__.node at 0x7fe618499d10>,
#  <__main__.node at 0x7fe618499dd0>,
#  <__main__.node at 0x7fe618499f50>,
#  <__main__.node at 0x7fe61849a110>,
#  <__main__.node at 0x7fe61849a1d0>,
#  <__main__.node at 0x7fe61849a350>,
#  <__main__.node at 0x7fe61849a510>,
#  <__main__.node at 0x7fe61849a5d0>,
#  <__main__.node at 0x7fe61849a750>,
#  <__main__.node at 0x7fe61849a910>,
#  <__main__.node at 0x7fe61849a9d0>,
#  <__main__.node at 0x7fe61849ab50>,
#  <__main__.node at 0x7fe61849ad10>,
#  <__main__.node at 0x7fe61849add0>,
#  <__main__.node at 0x7fe61849af50>,
#  <__main__.node at 0x7fe61849b110>,
#  <__main__.node at 0x7fe61849b1d0>,
#  <__main__.node at 0x7fe61849b350>,
#  <__main__.node at 0x7fe61849b510>,
#  <__main__.node at 0x7fe61849b5d0>,
#  <__main__.node at 0x7fe61849b750>,
#  <__main__.node at 0x7fe61849b910>,
#  <__main__.node at 0x7fe61849b9d0>,
#  <__main__.node at 0x7fe61849bb50>,
#  <__main__.node at 0x7fe61849bd10>,
#  <__main__.node at 0x7fe61849bdd0>,
#  <__main__.node at 0x7fe61849bf50>,
#  <__main__.node at 0x7fe61849c150>,
#  <__main__.node at 0x7fe61849c210>,
#  <__main__.node at 0x7fe61849c390>,
#  <__main__.node at 0x7fe61849c550>,
#  <__main__.node at 0x7fe61849c610>,
#  <__main__.node at 0x7fe61849c790>,
#  <__main__.node at 0x7fe61849c950>,
#  <__main__.node at 0x7fe61849ca10>,
#  <__main__.node at 0x7fe61849cb90>,
#  <__main__.node at 0x7fe61849cd50>,
#  <__main__.node at 0x7fe61849ce10>,
#  <__main__.node at 0x7fe61849cf90>,
#  <__main__.node at 0x7fe61849d150>,
#  <__main__.node at 0x7fe61849d210>,
#  <__main__.node at 0x7fe61849d390>,
#  <__main__.node at 0x7fe61849d550>,
#  <__main__.node at 0x7fe61849d610>,
#  <__main__.node at 0x7fe61849d790>,
#  <__main__.node at 0x7fe61849d950>,
#  <__main__.node at 0x7fe61849da10>,
#  <__main__.node at 0x7fe61849db90>,
#  <__main__.node at 0x7fe61849dd50>,
#  <__main__.node at 0x7fe61849de10>,
#  <__main__.node at 0x7fe61849df90>,
#  <__main__.node at 0x7fe61849e150>,
#  <__main__.node at 0x7fe61849e210>,
#  <__main__.node at 0x7fe61849e390>,
#  <__main__.node at 0x7fe61849e550>,
#  <__main__.node at 0x7fe61849e610>,
#  <__main__.node at 0x7fe61849e790>,
#  <__main__.node at 0x7fe61849e950>,
#  <__main__.node at 0x7fe61849ea10>,
#  <__main__.node at 0x7fe61849eb90>,
#  <__main__.node at 0x7fe61849ed50>,
#  <__main__.node at 0x7fe61849ee10>,
#  <__main__.node at 0x7fe61849ef90>,
#  <__main__.node at 0x7fe61849f150>,
#  <__main__.node at 0x7fe61849f210>,
#  <__main__.node at 0x7fe61849f390>,
#  <__main__.node at 0x7fe61849f550>,
#  <__main__.node at 0x7fe61849f610>,
#  <__main__.node at 0x7fe61849f790>,
#  <__main__.node at 0x7fe61849f950>,
#  <__main__.node at 0x7fe61849fa10>,
#  <__main__.node at 0x7fe61849fb90>,
#  <__main__.node at 0x7fe61849fd50>,
#  <__main__.node at 0x7fe61849fe10>,
#  <__main__.node at 0x7fe61849ff90>,
#  <__main__.node at 0x7fe6184a8190>,
#  <__main__.node at 0x7fe6184a8250>,
#  <__main__.node at 0x7fe6184a83d0>,
#  ...]

# %%
edges[0].source

# %%
import ray
import json
import math
import numpy as np

# Node 클래스 직렬화 가능하도록 개선
class node():
    def __init__(self, id, coord):
        self.id = id
        self.coord = np.array(coord)
        self.incoming_edges = []
        self.outgoing_edges = []
        self.OHT = None

    def add_incoming_edge(self, edge):
        self.incoming_edges.append(edge)

    def add_outgoing_edge(self, edge):
        self.outgoing_edges.append(edge)

class edge():
    def __init__(self, source, dest, length, max_speed):
        self.source = source
        self.dest = dest
        self.length = length
        self.max_speed = max_speed
        self.OHTs = []
        self.update_edge_references()

    def update_edge_references(self):
        self.source.add_incoming_edge(self)
        self.dest.add_outgoing_edge(self)

# 테스트 함수
def test_ray_put_with_layout_data():
    # Layout Data 로드 (파일 경로는 실제 경로로 바꿔야 함)
    with open('./flask_backend/fab_oht_layout_2nd.json') as f:
        layout_data = json.load(f)

    # Node 객체 생성
    nodes = [node(n['id'], [n['x'], n['y']]) for n in layout_data['nodes']]
    print(f"Loaded {len(nodes)} nodes")

    # Edge 객체 생성
    edges = [
        edge(
            source=next(node for node in nodes if node.id == rail['from']),
            dest=next(node for node in nodes if node.id == rail['to']),
            length=math.sqrt(
                (next(node for node in nodes if node.id == rail['to']).coord[0] -
                 next(node for node in nodes if node.id == rail['from']).coord[0])**2 +
                (next(node for node in nodes if node.id == rail['to']).coord[1] -
                 next(node for node in nodes if node.id == rail['from']).coord[1])**2
            ),
            max_speed=1500
        )
        for rail in layout_data['rails']
    ]
    print(f"Loaded {len(edges)} edges")

    # Ray에 직렬화 가능한 형태로 데이터 전송
    ray.put(nodes)
    ray.put(edges)

    print("Nodes and edges data have been put into Ray!")

# Ray 클러스터 초기화
ray.init(ignore_reinit_error=True)

# Ray 테스트
test_ray_put_with_layout_data()

# Ray 클러스터 종료
ray.shutdown()
# Out:
# 2025-01-23 08:07:20,658	INFO worker.py:1821 -- Started a local Ray instance.
# Loaded 2858 nodes
# Loaded 3424 edges
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/ray/cloudpickle/cloudpickle.py:1245, in Pickler.dump(self, obj)
#    1244 try:
# -> 1245     return super().dump(obj)
#    1246 except RuntimeError as e:
#
# RecursionError: maximum recursion depth exceeded
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# Cell In[15], line 71
#      68 ray.init(ignore_reinit_error=True)
#      70 # Ray 테스트
# ---> 71 test_ray_put_with_layout_data()
#      73 # Ray 클러스터 종료
#      74 ray.shutdown()
#
# Cell In[15], line 62, in test_ray_put_with_layout_data()
#      59 print(f"Loaded {len(edges)} edges")
#      61 # Ray에 직렬화 가능한 형태로 데이터 전송
# ---> 62 ray.put(nodes)
#      63 ray.put(edges)
#      65 print("Nodes and edges data have been put into Ray!")
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py:2836, in put(value, _owner)
#    2834 with profiling.profile("ray.put"):
#    2835     try:
# -> 2836         object_ref = worker.put_object(value, owner_address=serialize_owner_address)
#    2837     except ObjectStoreFullError:
#    2838         logger.info(
#    2839             "Put failed since the value was either too large or the "
#    2840             "store was full of pinned objects."
#    2841         )
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py:794, in Worker.put_object(self, value, object_ref, owner_address, _is_experimental_channel)
#     789     assert (
#     790         object_ref is None
#     791     ), "Local Mode does not support inserting with an ObjectRef"
#     793 try:
# --> 794     serialized_value = self.get_serialization_context().serialize(value)
#     795 except TypeError as e:
#     796     sio = io.StringIO()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:556, in SerializationContext.serialize(self, value)
#     554     return RawSerializedObject(value)
#     555 else:
# --> 556     return self._serialize_to_msgpack(value)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:534, in SerializationContext._serialize_to_msgpack(self, value)
#     532 if python_objects:
#     533     metadata = ray_constants.OBJECT_METADATA_TYPE_PYTHON
# --> 534     pickle5_serialized_object = self._serialize_to_pickle5(
#     535         metadata, python_objects
#     536     )
#     537 else:
#     538     pickle5_serialized_object = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:481, in SerializationContext._serialize_to_pickle5(self, metadata, value)
#     479 except Exception as e:
#     480     self.get_and_clear_contained_object_refs()
# --> 481     raise e
#     482 finally:
#     483     self.set_out_of_band_serialization()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/serialization.py:476, in SerializationContext._serialize_to_pickle5(self, metadata, value)
#     474 try:
#     475     self.set_in_band_serialization()
# --> 476     inband = pickle.dumps(
#     477         value, protocol=5, buffer_callback=writer.buffer_callback
#     478     )
#     479 except Exception as e:
#     480     self.get_and_clear_contained_object_refs()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/cloudpickle/cloudpickle.py:1479, in dumps(obj, protocol, buffer_callback)
#    1477 with io.BytesIO() as file:
#    1478     cp = Pickler(file, protocol=protocol, buffer_callback=buffer_callback)
# -> 1479     cp.dump(obj)
#    1480     return file.getvalue()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/cloudpickle/cloudpickle.py:1249, in Pickler.dump(self, obj)
#    1247 if len(e.args) > 0 and "recursion" in e.args[0]:
#    1248     msg = "Could not pickle object as excessively deep recursion required."
# -> 1249     raise pickle.PicklingError(msg) from e
#    1250 else:
#    1251     raise
#
# PicklingError: Could not pickle object as excessively deep recursion required.

# %%
import numpy as np
import random
import networkit as nk
import threading
import gzip
import base64

def compress_data(data):
    json_data = json.dumps(data).encode('utf-8')
    compressed_data = gzip.compress(json_data)
    return base64.b64encode(compressed_data).decode('utf-8')


#node 클래스
class node():
    def __init__(self, id, coord):
        #node id
        self.id = id
        #node 좌표 (2차원)
        self.coord = np.array(coord)
        #노드로 들어오는 edge들 => intersection 쪽 충돌 감지 위해 필요
        self.incoming_edges = []
        self.outgoing_edges = []
        self.OHT = None
        
class edge():
    def __init__(self, source, dest, length, max_speed):
        #Edge source
        self.source = source
        #edge target(destination)
        self.dest = dest
        #edge length
        self.length = length
        #edge의 방향 벡터
        self.unit_vec = (self.dest.coord - self.source.coord) / self.length
        #max speed -> 전부 1500
        self.max_speed = max_speed
        #edge 위에 존재하는 OHT 리스트
        self.OHTs = []  # Use a set to track OHTs
        
        self.count = 0  # OHT가 이 Edge에 진입한 횟수
        # self.speeds = []  # 최근 time_window 동안의 속도 저장
        self.avg_speed = max_speed  # time_window 내 평균 속도
        self.entry_exit_records = {} 
            
    def calculate_avg_speed(self, time_window, current_time):
        all_relevant_records = []
        total_time_covered = 0  # 기록된 총 시간
        total_distance_covered = 0  # 기록된 총 거리

        for oht_id, records in self.entry_exit_records.items():
            # time_window 내의 유효한 기록 필터링
            relevant_records = [
                (entry, exit) for entry, exit in records
                if exit is not None and entry >= current_time - time_window
            ]
            all_relevant_records.extend(relevant_records)

        # 기록된 각 구간의 속도와 이동 거리 계산
        for entry, exit in all_relevant_records:
            travel_time = exit - entry
            if travel_time > 0.01:  # 최소 이동 시간
                speed = self.length / travel_time
                total_time_covered += travel_time
                total_distance_covered += speed * travel_time

        # time_window에서 기록되지 않은 시간 간격 계산
        uncovered_time = time_window - total_time_covered
        if uncovered_time > 0:
            total_distance_covered += self.max_speed * uncovered_time

        # 전체 평균 속도 계산
        avg_speed = total_distance_covered / time_window
        return min(avg_speed, self.max_speed)
    
class port():
    def __init__(self, name, from_node, to_node, from_dist):
        #port name
        self.name = name
        #포트 위치 설정을 위한 from_node
        self.from_node = from_node
        #포트 to_node
        self.to_node = to_node
        #from_node로부터의 거리
        self.from_dist = from_dist
        #포트가 존재하는 edge
        self.edge = None

        
class OHT():
    def __init__(self, id, from_node, from_dist, speed, acc, rect, path):
        self.id = id #oht id
        self.from_node = from_node #oht 위치를 계산하기 위한 from_node
        self.from_dist = from_dist #from_node로부터의 거리
        
        self.path = path #oht가 움직일 경로, (Edge들의 List)
        self.path_to_start = [] #start port로 갈 때 경로
        self.path_to_end = [] #end port로 갈 때 경로
        self.edge = path.pop(0) if path else None #OHT가 위치한 edge
        
        self.pos = (
            self.from_node.coord + self.edge.unit_vec * self.from_dist
            if self.edge else self.from_node.coord
        ) #OHT의 위치 계산
        self.speed = speed #속도
        self.acc = acc #가속도
        self.rect = rect #충돌 감지 범위
        
        self.edge.OHTs.append(self) if self.edge else None #OHT가 위치한 edge의 OHT list에 self 추가 
        
        
        self.start_port = None #출발 포트
        self.end_port = None #도착 포트
        self.wait_time = 0 #loading / unloading시 기다리는 시간
        
        self.status = "IDLE" #STATUS, IDLE / TO_START / TO_END
    
    #위치 계산 method
    def cal_pos(self, time_step):
        self.from_dist = self.from_dist + self.speed * time_step + 1/2 * self.acc * time_step**2
        self.pos = self.from_node.coord + self.edge.unit_vec * self.from_dist if self.edge != None else self.from_node.coord

    #move, 매 time step 마다 실행            
    def move(self, time_step, current_time):
        #node 위에만 있을 떄?? 이거 사실 잘 모르겠구 에러 나는거 해결하려고 이거저거하다가 넣었습니다
        
        if self.status == 'ON_REMOVED':
            self.speed = 0
            self.acc = 0
            return
        
        if not self.edge:
            # print('no edge', self.edge)
            self.speed = 0
            self.acc = 0
            if len(self.path) != 0:
                self.from_node.OHT = None
            return

        #end port 도착하면 wait time 동안 기다리기
        if self.wait_time > 0:
            self.wait_time -= time_step
            if self.wait_time <= 0:  # 대기 시간이 끝나면
                self.wait_time = 0
                if self.status == 'STOP_AT_START':
                    self.status = 'TO_END'
                elif self.status == 'STOP_AT_END':
                    self.status = 'IDLE'
            return  # 대기 중이므로 이동하지 않음
        
        #충돌 감지
        self.col_check(time_step)
        
        # ori_dist_1 = copy.copy(self.from_dist)
        
        #다음 스텝에 움직인 거리 계산
        # self.from_dist = self.from_dist + self.speed * time_step + 1/2 * self.acc * time_step**2
        
        #만약 도착했다면 멈추기 
        if self.is_arrived():
            self.arrive()
            return
            
        #From_dist가 edge의 length보다 길어지면 다음 엣지로 업데이트    
        while (self.from_dist > self.edge.length):
            
            self.from_node = self.edge.dest #from_node를 Edge dest로 업데이트

            self.from_dist = self.from_dist - self.edge.length #from_dist도 업데이트
            
            if self.edge:
                try:
                     #원래 엣지에서 현재 OHT 제거
                    if len(self.path) > 0:
                # before_edge = copy.copy(self.edge)
                
                        exit_record = self.edge.entry_exit_records.get(self.id, [])
                        if exit_record and exit_record[-1][1] is None:
                            exit_record[-1] = (exit_record[-1][0], current_time)
                        self.edge.entry_exit_records[self.id] = exit_record
                                            
                        self.edge.OHTs.remove(self)
                        
                        self.edge = self.path.pop(0) #다음 엣지로 업데이트
                        
                        if self not in self.edge.OHTs:
                            self.edge.OHTs.append(self) #다음 엣지 안에 OHT 추가
                            self.edge.count += 1
                            if self.id not in self.edge.entry_exit_records:
                                self.edge.entry_exit_records[self.id] = []
                                self.edge.entry_exit_records[self.id].append((current_time, None))
                            
                    else:
                        self.speed = 0
                        self.acc = 0
                        self.from_dist = self.edge.length
                        self.from_node = self.edge.source
                        return
                except:
                    print('update error : ', self.edge.source.id)

  
            if self.is_arrived():
                self.arrive()
                return
            

        if self.is_arrived():
            self.arrive()
            return
            
        #가속도 고려해서 스피드 계산
        self.speed = min(max(self.speed + self.acc * time_step, 0), self.edge.max_speed)
        
    def is_arrived(self):

        #start_port 혹은 end port에 도착했는지 확인, OHT와 port가 같은 엣지, 같은 from_node에 있는지, OHT의 from_dist가 port의 From_dist보다 커지는지
        if self.status == "TO_START":
            return (self.start_port 
                    and self.start_port.from_node == self.from_node and self.start_port.to_node == self.edge.dest
                    and self.from_dist >= self.start_port.from_dist)
        elif self.status == "TO_END":
            return (self.end_port 
                    and self.end_port.from_node == self.from_node and self.end_port.to_node == self.edge.dest
                    and self.from_dist >= self.end_port.from_dist)
        
    def arrive(self):
        # print('arrived at', self.pos, self.from_node.id)
        # self.from_dist = self.end_port.from_dist
        # self.pos = self.from_node.coord + self.edge.unit_vec * self.end_port.from_dist
        # self.speed = 0
        # self.acc = 0
        # self.wait_time = 500
        # self.end_port = None
        # print('arrived rail : ', self.edge.OHTs, self in self.edge.OHTs)
        
        #도착하면 port위치로 OHT를 고정하고, 속도, 가속도 0으로 정지, wait_time 5초 주기
        if self.status == "TO_START":
            # print(f"OHT {self.id} arrived at start port: {self.start_port.name}")
            self.from_dist = self.start_port.from_dist
            self.pos = self.from_node.coord + self.edge.unit_vec * self.start_port.from_dist
            self.speed = 0
            self.acc = 0
            self.wait_time = 5
            
            self.status = "STOP_AT_START"
            self.path = self.path_to_end  # 경로를 end_port로 변경
            self.path_to_start = []  # start_port 경로 초기화
            self.start_port = None

        elif self.status == "TO_END":
            
            self.from_dist = self.end_port.from_dist
            self.pos = self.from_node.coord + self.edge.unit_vec * self.end_port.from_dist
            self.speed = 0
            self.acc = 0
            self.wait_time = 5
            self.end_port = None
            # print(f"OHT {self.id} arrived at end port: {self.end_port.name}")
            self.status = "STOP_AT_END"
            self.path = []
            self.path_to_end = []  # end_port 경로 초기화

        else:
            print(f"OHT {self.id} is idle.")

    
    #충돌 감지
    def col_check(self, time_step):
        OHTs = self.edge.OHTs
        
        #같은 edge상에 있는 OHT들과 거리 비교
        for oht in OHTs:
            if oht is not self:  # 자신과의 비교를 피함
                dist_diff = oht.from_dist - self.from_dist
                if 0 < dist_diff < self.rect:  # rect 길이보다 가까워지면
                    # 가속도를 줄여 충돌 방지
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
                
        if self.edge.dest.OHT is not None:
            dist_diff = self.edge.length - self.from_dist
            if 0 < dist_diff < self.rect:  # rect 길이보다 가까워지면
                # 가속도를 줄여 충돌 방지
                self.acc = -self.speed/time_step # 속도 감소 또는 정지
                return
         
         #다음 엣지에 있는 OHT들 중 제일 마지막에 있는 친구와 거리 비교       
        if len(self.path) > 0:
            next_edge = self.path[0]
            try:
                last_oht = next_edge.OHTs[-1]
                rem_diff = self.edge.length - self.from_dist
                dist_diff = last_oht.from_dist + rem_diff
                if 0 < dist_diff < self.rect:
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
            except:
                pass
        
        #다음 노드에서 들어오는 엣지들 상에 있는 OHT들과 충돌 비교 (intersection이 무조건 최대 2개임)    
        incoming_edges = [
            edge for edge in self.edge.dest.incoming_edges
            if edge != self.edge # Edges leading to the same destination node
        ]
        
        if len(incoming_edges) == 1: #만약 intersection이 있따면 (다른 edge가 있다면)
            rem_diff = self.edge.length - self.from_dist #현재 자기 자신의 엣지 상에서 남은 거리 계산
            try:
                other_oht = incoming_edges[0].OHTs[0]
                other_diff= other_oht.edge.length - other_oht.from_dist #다른 엣지 위 제일 앞에 있는 OHT의 남은 거리 계산
                dist_diff = rem_diff + other_diff #두 OHT간의 거리 계산
                if 0 < dist_diff < 3 * self.rect and rem_diff > other_diff: #더 가까운 OHT가 먼저 움직이도록, 나머지는 정지. 3*rect로 잡은 이유는 그래야 좀 더 미리 멈춰서
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
                elif rem_diff == other_diff and self.id > other_oht.id: #혹시나 거리가 같다면 OHT id가 더 빠른 아이가 움직이도록
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
            except:
                pass
        if len(self.path) > 0:
            outgoing_edges = [
                edge for edge in self.edge.dest.outgoing_edges
                if edge != self.path[0] # Edges leading to the same destination node
            ]
        
            if len(outgoing_edges) == 1: #만약 intersection이 있따면 (다른 edge가 있다면)
                rem_diff = self.edge.length - self.from_dist #현재 자기 자신의 엣지 상에서 남은 거리 계산
                try:
                    other_oht = outgoing_edges[0].OHTs[0]
                    other_diff= other_oht.from_dist #다른 엣지 위 제일 앞에 있는 OHT의 남은 거리 계산
                    dist_diff = rem_diff + other_diff #두 OHT간의 거리 계산
                    if 0 < dist_diff <  self.rect: #더 가까운 OHT가 먼저 움직이도록, 나머지는 정지. 3*rect로 잡은 이유는 그래야 좀 더 미리 멈춰서
                        self.acc = -self.speed/time_step # 속도 감소 또는 정지
                        return
                except:
                    pass
        
        #충돌 위험이 없다면 다시 원래 max speed로 가속
        self.acc = (self.edge.max_speed - self.speed) / time_step
        
class AMHS:
    def __init__(self, nodes, edges, ports, num_OHTs, max_jobs, job_list = [], oht_list = []):
        """
        AMHS 초기화.
        - nodes: node 클래스 객체 리스트
        - edges: edge 클래스 객체 리스트
        - num_OHTs: 초기 OHT 수
        - max_jobs: 작업 큐의 최대 크기
        """
        # self.graph = nx.DiGraph()
        # self.original_graph=nx.DiGraph()
        
        self.graph = nk.Graph(directed=True, weighted=True)  # Directed weighted graph
        
        self.nodes = nodes  # node 객체 리스트
        for node in nodes:
            node.OHT = None
        self.edges = edges  # edge 객체 리스트
        for edge in edges:
            edge.OHTs = []
            edge.count = 0
            edge.avg_speed = edge.max_speed
        self.ports = ports #port list
        for p in ports:
            p.edge = self.get_edge(p.from_node, p.to_node)
        self.OHTs = []
        if job_list != []:
            self.job_queue = [[self.get_port(q[0]), self.get_port(q[1])] for q in job_list]
        else:
            self.job_queue = []
        self.max_jobs = max_jobs
        
        self.node_id_map = {}
        
        self.time_step=0.01
        
                
        self.simulation_running = False  # 시뮬레이션 상태 관리
        self.stop_simulation_event = threading.Event()  # 스레드 이벤트 처리

        # 그래프 생성
        self._create_graph()
        
        self.original_graph = nk.Graph(self.graph)

        # 초기 OHT 배치
        if oht_list != []:
            self.set_initial_OHTs(oht_list)
        else:
            self.initialize_OHTs(num_OHTs)
        
        self.apsp = nk.distance.APSP(self.graph)
        self.apsp.run()
        
        self.original_apsp = nk.distance.APSP(self.original_graph)
        self.original_apsp.run()
        


    def _create_graph(self):
        """NetworkX 그래프를 nodes와 edges로 생성."""
        for i, node in enumerate(self.nodes):
            self.graph.addNode()  # Add node to the graph
            self.node_id_map[node.id] = i
        
        for edge in self.edges:
            u = self.node_id_map[edge.source.id]  # Get index for source node
            v = self.node_id_map[edge.dest.id]    # Get index for destination node
            self.graph.addEdge(u, v, edge.length)
            edge.dest.incoming_edges.append(edge) #각 node마다 incoming edge 추가
            edge.source.outgoing_edges.append(edge)

    def initialize_OHTs(self, num_OHTs):
        available_nodes = self.nodes.copy()
        
        for i in range(num_OHTs):
            # 노드 중에서 랜덤 선택 (노드 소진 시 다시 전체에서 랜덤)
            if not available_nodes:
                available_nodes = self.nodes.copy()  # 노드 리스트 재생성
            
            start_node = random.choice(available_nodes)
            available_nodes.remove(start_node)  # 선택한 노드는 제거
            
            oht = OHT(
                id=i,
                from_node=start_node,
                from_dist=0,
                speed=0,
                acc=0,
                rect=1000,  # 충돌 판정 거리
                path=[],
            )
            start_node.OHT = oht
            self.OHTs.append(oht)
            
    def set_initial_OHTs(self, oht_list):
        i = 0
        for start_node in oht_list:  
            start_node = self.get_node(start_node)
            oht = OHT(
                id=i,
                from_node=start_node,
                from_dist=0,
                speed=0,
                acc=0,
                rect=1000,  # 충돌 판정 거리
                path=[],
            )
            start_node.OHT = oht
            self.OHTs.append(oht)
            i = i+1
    
    def set_oht(self, oht_origin, oht_new):
        oht_origin.from_node = self.get_node(oht_new['from_node'])
        oht_origin.from_dist = oht_new['from_dist']
        oht_origin.edge = self.get_edge(oht_new['source'], oht_new['dest'])
        if oht_origin.edge:
            if oht_origin not in oht_origin.edge.OHTs:
                oht_origin.edge.OHTs.append(oht_origin)
        try:
            if not self.graph.hasEdge(self.node_id_map[oht_new['source']], self.node_id_map[oht_new['dest']]):
                oht_origin.speed = 0
                oht_origin.acc = 0
                oht_origin.status = 'ON_REMOVED'
                oht_origin.cal_pos(self.time_step)
                return
        except:
            print('is here?', oht_new['source'])
  
            
        oht_origin.speed = oht_new['speed']
        oht_origin.status = oht_new['status']
        
        if oht_origin.status == 'ON_REMOVED':
            if oht_origin.start_port:
                oht_origin.status = "TO_START"
            elif oht_origin.end_port:
                oht_origin.status = "TO_END"
            else:
                oht_origin.status = "IDLE"
                
        oht_origin.cal_pos(self.time_step)
             
        
        oht_origin.start_port = self.get_port(oht_new['startPort']) if oht_new['startPort'] else None
        oht_origin.end_port = self.get_port(oht_new['endPort']) if oht_new['endPort'] else None
        oht_origin.wait_time = oht_new['wait_time']
                
        if oht_origin.start_port != None:
            if oht_origin.edge:
                path_edges_to_start = self.get_path_edges(oht_origin.edge.dest.id, oht_origin.start_port.to_node.id)
                path_edges_to_start = self._validate_path(path_edges_to_start)

            else:
                path_edges_to_start = self.get_path_edges(oht_origin.from_node.id, oht_origin.start_port.to_node.id)
                path_edges_to_start = self._validate_path(path_edges_to_start)
            oht_origin.path_to_start = path_edges_to_start[:]
        
        # elif oht_origin.status == "TO_END":
        if oht_origin.end_port != None:
            if oht_origin.status == "TO_END" or oht_origin.status == 'STOP_AT_START':
                if oht_origin.edge:
                    path_edges_to_end = self.get_path_edges(oht_origin.edge.dest.id, oht_origin.end_port.to_node.id)
                    path_edges_to_end = self._validate_path(path_edges_to_end)
                else:
                    path_edges_to_end = self.get_path_edges(oht_origin.from_node.id, oht_origin.end_port.to_node.id)
                    path_edges_to_end = self._validate_path(path_edges_to_end)
            else:
                path_edges_to_end = self.get_path_edges(oht_origin.start_port.to_node.id, oht_origin.end_port.to_node.id)

            oht_origin.path_to_end = path_edges_to_end
        
        if oht_origin.status == "TO_START":
            oht_origin.path = path_edges_to_start[:]
        elif oht_origin.status == "TO_END" or oht_origin.status == "STOP_AT_START":
            oht_origin.path = path_edges_to_end[:]
        else:
            oht_origin.path = []

    def modi_edge(self, source, dest, oht_positions, is_removed):
        if is_removed:
            removed_edge = self.get_edge(source, dest)
            try:       
                self.graph.removeEdge(self.node_id_map[source], self.node_id_map[dest])
                self.apsp = nk.distance.APSP(self.graph)
                self.apsp.run()
            except:
                print(source, dest)
        else:
            edge_to_restore = next((e for e in self.edges if e.source.id == source and e.dest.id == dest), None)
            if edge_to_restore:
                self.graph.addEdge(self.node_id_map[source], self.node_id_map[dest], edge_to_restore.length)
                self.apsp = nk.distance.APSP(self.graph)
                self.apsp.run()
            else:
                print(f"Rail {source} -> {dest} not found in original edges.")
        
    
    def reinitialize_simul(self, oht_positions, edge_data):
        for edge in self.edges:
            edge.OHTs.clear()
            edge.entry_exit_records.clear()
        
        for oht in oht_positions:
            oht_in_amhs = self.get_oht(oht['id'])
            self.set_oht(oht_in_amhs, oht)
            
        edge_map = {f"{edge.source.id}-{edge.dest.id}": edge for edge in self.edges}
    
        for edge_info in edge_data:
            edge_key = f"{edge_info['from']}-{edge_info['to']}"
            if edge_key in edge_map:
                edge = edge_map[edge_key]
                edge.count = edge_info.get('count', 0)
                edge.avg_speed = edge_info.get('avg_speed', 0)
            
        for edge in self.edges:
            edge.OHTs.sort(key = lambda oht : -oht.from_dist)
    
    def generate_job(self):
        """모든 OHT가 Job을 갖도록 작업 생성."""
        for _ in range(50):
            start_port = random.choice(self.ports)
            end_port = random.choice(self.ports)
            while start_port == end_port:  # 시작/목적 포트가 같지 않도록 보장
                end_port = random.choice(self.ports)
            self.job_queue.append((start_port, end_port))
            

    def assign_jobs(self):
        """모든 OHT가 Job을 갖도록 작업 할당."""
        closest_oht = None
        closest_dist = 1e100
        for oht in self.OHTs:
            if not oht.path and self.job_queue and oht.status == 'IDLE':  # OHT가 Idle 상태이고 Job Queue가 비어있지 않은 경우
                start_port, end_port = self.job_queue.pop(0)
                dist = self.get_path_distance(oht.from_node.id, start_port.from_node.id)
                if dist < closest_dist:
                    closest_dist = dist
                    closest_oht = oht
        
        if closest_oht:
            oht = closest_oht
            oht.start_port = start_port
            # oht.start_port = next((port for port in self.ports if port.name == 'DIE0137_Port3'), None)
            oht.end_port = end_port
            oht.status = "TO_START"

            # # Start로 이동하는 경로
            if oht.edge:
                path_edges_to_start = self.get_path_edges(oht.edge.dest.id, start_port.to_node.id)
            else:
                path_edges_to_start = self.get_path_edges(oht.from_node.id, start_port.to_node.id)
            oht.path_to_start = path_edges_to_start[:]
            
            # # End로 이동하는 경로
            # start_edge = [self.get_edge(start_port.from_node.id, start_port.to_node.id)]
            path_edges_to_end = self.get_path_edges(start_port.to_node.id, end_port.to_node.id)
            oht.path_to_end = path_edges_to_end

            # # 전체 경로를 OHT에 설정
            oht.path = path_edges_to_start[:]
            
            # print(oht.path)

            # Assign the first edge in the path to the OHT's edge
            if oht.path:
                if not oht.edge:
                    oht.edge = oht.path.pop(0)
                    oht.from_node.OHT = None
                    if oht not in oht.edge.OHTs:
                        oht.edge.OHTs.append(oht)
                        
    def update_edge_metrics(self, current_time, time_window):
        for edge in self.edges:
            edge.avg_speed = edge.calculate_avg_speed(time_window, current_time)


    def get_node(self, node_id):
        """node id로 node 객체 반환."""
        return next((node for node in self.nodes if node.id == node_id), None)

    def get_edge(self, source_id, dest_id):
        """source와 dest ID로 edge 객체 반환."""
        return next(
            (e for e in self.edges if e.source.id == source_id and e.dest.id == dest_id), 
            None
        )
        
    def get_path_distance(self, source_id, dest_id):
        try:
            source_idx = self.node_id_map[source_id]
            dest_idx = self.node_id_map[dest_id]
            
            # dijkstra = nk.distance.Dijkstra(self.graph, source_idx, storePaths=True, storeNodesSortedByDistance=False, target=dest_idx)
            # dijkstra.run()
            # dist = dijkstra.distance(dest_idx)
            
            dist = self.apsp.getDistance(source_idx, dest_idx)      
            return dist
        except:
            try:
                source_idx = self.node_id_map[source_id]
                dest_idx = self.node_id_map[dest_id]
                
                
                
                # dijkstra = nk.distance.Dijkstra(self.original_graph, source_idx, storePaths=True, storeNodesSortedByDistance=False, target=dest_idx)
                # dijkstra.run()

                # dist = dijkstra.distance(dest_idx)
            

                dist = self.original_apsp.getDistance(source_idx, dest_idx)                
                return dist
            except:
                print(f"No path found even in original_graph for {source_id} -> {dest_id}.")
                return float('inf')
        

    def get_path_edges(self, source_id, dest_id):
        """source와 dest ID로 최단 경로 에지 리스트 반환."""
        try:
            source_idx = self.node_id_map[source_id]
            dest_idx = self.node_id_map[dest_id]
            
            dijkstra = nk.distance.Dijkstra(self.graph, source_idx, storePaths=True, storeNodesSortedByDistance=False, target=dest_idx)
            dijkstra.run()

            path = dijkstra.getPath(dest_idx)
            
            return [
                self.get_edge(self.nodes[path[i]].id, self.nodes[path[i+1]].id)
                for i in range(len(path) - 1)
            ]
        except:
            try:
                source_idx = self.node_id_map[source_id]
                dest_idx = self.node_id_map[dest_id]
                
                dijkstra = nk.distance.Dijkstra(self.original_graph, source_idx, storePaths=True, storeNodesSortedByDistance=False, target=dest_idx)
                dijkstra.run()

                path = dijkstra.getPath(dest_idx)
                
                return [
                    self.get_edge(self.nodes[path[i]].id, self.nodes[path[i+1]].id)
                    for i in range(len(path) - 1)
                ]
            except:
                print(f"No path found even in original_graph for {source_id} -> {dest_id}.")
                return []
    
    def get_oht(self, oht_id):
        return next((oht for oht in self.OHTs if oht.id == oht_id), None)
    
    def get_port(self, port_name):
        return next((port for port in self.ports if port.name == port_name), None)

    def _validate_path(self, path):
        """
        현재 경로에 지워진 edge가 포함된 경우, 해당 edge 직전까지만 반환합니다.

        Parameters:
            path (list): 현재 경로 (edge 객체 리스트)

        Returns:
            list: 수정된 경로 (지워진 edge 직전까지만 포함)
        """
        valid_path = []
        for edge in path:
            if self.graph.hasEdge(self.node_id_map[edge.source.id], self.node_id_map[edge.dest.id]):  # edge가 그래프에 존재하는 경우
                valid_path.append(edge)
            else:
                break  # 지워진 edge를 발견하면 직전까지만 반환
        return valid_path
    
    
        
    def start_simulation(self, socketio, current_time, max_time = 4000, time_step = 0.01):
        """시뮬레이션 시작"""        
        if self.simulation_running:
            print("Simulation is already running. Stopping the current simulation...")
            self.stop_simulation_event.set()
            while self.simulation_running:
                socketio.sleep(0.01)  # Wait for the current simulation to stop
            return
        
        self.simulation_running = True
        self.stop_simulation_event.clear()
        
        count = 0
        edge_metrics_cache = {}  # Cache for edge metrics to track changes

        while current_time < max_time:
            if self.stop_simulation_event.is_set():
                break
            
            if count % 5 == 0:
                self.generate_job()
                self.assign_jobs()

            # Move all OHTs
            oht_positions = []
            for oht in self.OHTs:
                oht.move(time_step, current_time)

            self.update_edge_metrics(current_time, time_window=500)
            
            for oht in self.OHTs:
                oht.cal_pos(time_step)

            if count % 5 == 0:
                for oht in self.OHTs:
                    oht_positions.append({
                        'id': oht.id,
                        'x': oht.pos[0],
                        'y': oht.pos[1],
                        'source': oht.edge.source.id if oht.edge else None,
                        'dest': oht.edge.dest.id if oht.edge else None,
                        'speed': oht.speed,
                        'status': oht.status,
                        'startPort': oht.start_port.name if oht.start_port else None,
                        'endPort': oht.end_port.name if oht.end_port else None,
                        'from_node': oht.from_node.id if oht.from_node else None,
                        'from_dist': oht.from_dist,
                        'wait_time': oht.wait_time
                    })

                updated_edges = []
                for edge in self.edges:
                    key = f"{edge.source.id}-{edge.dest.id}"
                    new_metrics = {"count": edge.count, "avg_speed": edge.avg_speed}
                    if edge_metrics_cache.get(key) != new_metrics:
                        edge_metrics_cache[key] = new_metrics
                        updated_edges.append({
                            "from": edge.source.id,
                            "to": edge.dest.id,
                            **new_metrics
                        })

                payload = {
                    'time': current_time,
                    'oht_positions': oht_positions,
                    'edges': updated_edges
                }

                compressed_payload = compress_data(payload)
                socketio.emit('updateOHT', {'data': compressed_payload})

            # Increment time
            current_time += time_step
            count += 1
            socketio.sleep(0.00001)

        self.simulation_running = False
        print('Simulation ended')
        
        
    
    def accelerate_simul(self, socketio, current_time, max_time = 4000, time_step = 0.01):
        """시뮬레이션 시작"""        
        if self.simulation_running:
            print("Simulation is already running. Stopping the current simulation...")
            self.stop_simulation_event.set()
            while self.simulation_running:
                socketio.sleep(0.01)  # Wait for the current simulation to stop
            return
        
        self.simulation_running = True
        self.stop_simulation_event.clear()
        
        _current_time = 0
        
        count = 0

        while _current_time < current_time:
            if self.stop_simulation_event.is_set():
                break
            
            if count % 5 == 0:
                self.generate_job()
                self.assign_jobs()
            
            if count % 10 == 0:
                print(_current_time)

            # Move all OHTs
            
            for oht in self.OHTs:
                oht.move(time_step, _current_time)

            self.update_edge_metrics(_current_time, time_window=500)
            
            for oht in self.OHTs:
                oht.cal_pos(time_step)

            # Increment time
            _current_time += time_step
            count += 1
            
        
        edge_metrics_cache = {} 
            
        
        while _current_time < max_time:
            if self.stop_simulation_event.is_set():
                break
            
            if count % 5 == 0:
                self.generate_job()
                self.assign_jobs()

            # Move all OHTs
            oht_positions = []
            for oht in self.OHTs:
                oht.move(time_step, _current_time)

            self.update_edge_metrics(_current_time, time_window=500)
            
            for oht in self.OHTs:
                oht.cal_pos(time_step)

            if count % 5 == 0:
                for oht in self.OHTs:
                    oht_positions.append({
                        'id': oht.id,
                        'x': oht.pos[0],
                        'y': oht.pos[1],
                        'source': oht.edge.source.id if oht.edge else None,
                        'dest': oht.edge.dest.id if oht.edge else None,
                        'speed': oht.speed,
                        'status': oht.status,
                        'startPort': oht.start_port.name if oht.start_port else None,
                        'endPort': oht.end_port.name if oht.end_port else None,
                        'from_node': oht.from_node.id if oht.from_node else None,
                        'from_dist': oht.from_dist,
                        'wait_time': oht.wait_time
                    })

                updated_edges = []
                for edge in self.edges:
                    key = f"{edge.source.id}-{edge.dest.id}"
                    new_metrics = {"count": edge.count, "avg_speed": edge.avg_speed}
                    if edge_metrics_cache.get(key) != new_metrics:
                        edge_metrics_cache[key] = new_metrics
                        updated_edges.append({
                            "from": edge.source.id,
                            "to": edge.dest.id,
                            **new_metrics
                        })

                payload = {
                    'time': current_time,
                    'oht_positions': oht_positions,
                    'edges': updated_edges
                }

                compressed_payload = compress_data(payload)
                socketio.emit('updateOHT', {'data': compressed_payload})

            # Increment time
            current_time += time_step
            count += 1
            socketio.sleep(0.00001)

        self.simulation_running = False
        print('Simulation ended')
# Out:
# 2025-01-23 08:22:07,294	INFO worker.py:1821 -- Started a local Ray instance.

# %%
#import libraries
import numpy as np
import random
import networkit as nk
import json
import threading
import gzip
import base64

def compress_data(data):
    json_data = json.dumps(data).encode('utf-8')
    compressed_data = gzip.compress(json_data)
    return base64.b64encode(compressed_data).decode('utf-8')


#node 클래스
class node():
    def __init__(self, id, coord):
        #node id
        self.id = id
        #node 좌표 (2차원)
        self.coord = np.array(coord)
        #노드로 들어오는 edge들 => intersection 쪽 충돌 감지 위해 필요
        self.incoming_edges = []
        self.outgoing_edges = []
        self.OHT = None
        
class edge():
    def __init__(self, source, dest, length, max_speed):
        #Edge source
        self.source = source
        #edge target(destination)
        self.dest = dest
        #edge length
        self.length = length
        #edge의 방향 벡터
        self.unit_vec = (self.dest.coord - self.source.coord) / self.length
        #max speed -> 전부 1500
        self.max_speed = max_speed
        #edge 위에 존재하는 OHT 리스트
        self.OHTs = []  # Use a set to track OHTs
        
        self.count = 0  # OHT가 이 Edge에 진입한 횟수
        # self.speeds = []  # 최근 time_window 동안의 속도 저장
        self.avg_speed = max_speed  # time_window 내 평균 속도
        self.entry_exit_records = {} 
            
    def calculate_avg_speed(self, time_window, current_time):
        all_relevant_records = []
        total_time_covered = 0  # 기록된 총 시간
        total_distance_covered = 0  # 기록된 총 거리

        for oht_id, records in self.entry_exit_records.items():
            # time_window 내의 유효한 기록 필터링
            relevant_records = [
                (entry, exit) for entry, exit in records
                if exit is not None and entry >= current_time - time_window
            ]
            all_relevant_records.extend(relevant_records)

        # 기록된 각 구간의 속도와 이동 거리 계산
        for entry, exit in all_relevant_records:
            travel_time = exit - entry
            if travel_time > 0.01:  # 최소 이동 시간
                speed = self.length / travel_time
                total_time_covered += travel_time
                total_distance_covered += speed * travel_time

        # time_window에서 기록되지 않은 시간 간격 계산
        uncovered_time = time_window - total_time_covered
        if uncovered_time > 0:
            total_distance_covered += self.max_speed * uncovered_time

        # 전체 평균 속도 계산
        avg_speed = total_distance_covered / time_window
        return min(avg_speed, self.max_speed)
    
class port():
    def __init__(self, name, from_node, to_node, from_dist):
        #port name
        self.name = name
        #포트 위치 설정을 위한 from_node
        self.from_node = from_node
        #포트 to_node
        self.to_node = to_node
        #from_node로부터의 거리
        self.from_dist = from_dist
        #포트가 존재하는 edge
        self.edge = None

        
class OHT():
    def __init__(self, id, from_node, from_dist, speed, acc, rect, path):
        self.id = id #oht id
        self.from_node = from_node #oht 위치를 계산하기 위한 from_node
        self.from_dist = from_dist #from_node로부터의 거리
        
        self.path = path #oht가 움직일 경로, (Edge들의 List)
        self.path_to_start = [] #start port로 갈 때 경로
        self.path_to_end = [] #end port로 갈 때 경로
        self.edge = path.pop(0) if path else None #OHT가 위치한 edge
        
        self.pos = (
            self.from_node.coord + self.edge.unit_vec * self.from_dist
            if self.edge else self.from_node.coord
        ) #OHT의 위치 계산
        self.speed = speed #속도
        self.acc = acc #가속도
        self.rect = rect #충돌 감지 범위
        
        self.edge.OHTs.append(self) if self.edge else None #OHT가 위치한 edge의 OHT list에 self 추가 
        
        
        self.start_port = None #출발 포트
        self.end_port = None #도착 포트
        self.wait_time = 0 #loading / unloading시 기다리는 시간
        
        self.status = "IDLE" #STATUS, IDLE / TO_START / TO_END
    
    #위치 계산 method
    def cal_pos(self, time_step):
        self.from_dist = self.from_dist + self.speed * time_step + 1/2 * self.acc * time_step**2
        self.pos = self.from_node.coord + self.edge.unit_vec * self.from_dist if self.edge != None else self.from_node.coord

    #move, 매 time step 마다 실행            
    def move(self, time_step, current_time):
        #node 위에만 있을 떄?? 이거 사실 잘 모르겠구 에러 나는거 해결하려고 이거저거하다가 넣었습니다
        
        if self.status == 'ON_REMOVED':
            self.speed = 0
            self.acc = 0
            return
        
        if not self.edge:
            # print('no edge', self.edge)
            self.speed = 0
            self.acc = 0
            if len(self.path) != 0:
                self.from_node.OHT = None
            return

        #end port 도착하면 wait time 동안 기다리기
        if self.wait_time > 0:
            self.wait_time -= time_step
            if self.wait_time <= 0:  # 대기 시간이 끝나면
                self.wait_time = 0
                if self.status == 'STOP_AT_START':
                    self.status = 'TO_END'
                elif self.status == 'STOP_AT_END':
                    self.status = 'IDLE'
            return  # 대기 중이므로 이동하지 않음
        
        #충돌 감지
        self.col_check(time_step)
        
        # ori_dist_1 = copy.copy(self.from_dist)
        
        #다음 스텝에 움직인 거리 계산
        # self.from_dist = self.from_dist + self.speed * time_step + 1/2 * self.acc * time_step**2
        
        #만약 도착했다면 멈추기 
        if self.is_arrived():
            self.arrive()
            return
            
        #From_dist가 edge의 length보다 길어지면 다음 엣지로 업데이트    
        while (self.from_dist > self.edge.length):
            
            self.from_node = self.edge.dest #from_node를 Edge dest로 업데이트

            self.from_dist = self.from_dist - self.edge.length #from_dist도 업데이트
            
            if self.edge:
                try:
                     #원래 엣지에서 현재 OHT 제거
                    if len(self.path) > 0:
                # before_edge = copy.copy(self.edge)
                
                        exit_record = self.edge.entry_exit_records.get(self.id, [])
                        if exit_record and exit_record[-1][1] is None:
                            exit_record[-1] = (exit_record[-1][0], current_time)
                        self.edge.entry_exit_records[self.id] = exit_record
                                            
                        self.edge.OHTs.remove(self)
                        
                        self.edge = self.path.pop(0) #다음 엣지로 업데이트
                        
                        if self not in self.edge.OHTs:
                            self.edge.OHTs.append(self) #다음 엣지 안에 OHT 추가
                            self.edge.count += 1
                            if self.id not in self.edge.entry_exit_records:
                                self.edge.entry_exit_records[self.id] = []
                                self.edge.entry_exit_records[self.id].append((current_time, None))
                            
                    else:
                        self.speed = 0
                        self.acc = 0
                        self.from_dist = self.edge.length
                        self.from_node = self.edge.source
                        return
                except:
                    print('update error : ', self.edge.source.id)

  
            if self.is_arrived():
                self.arrive()
                return
            

        if self.is_arrived():
            self.arrive()
            return
            
        #가속도 고려해서 스피드 계산
        self.speed = min(max(self.speed + self.acc * time_step, 0), self.edge.max_speed)
        
    def is_arrived(self):

        #start_port 혹은 end port에 도착했는지 확인, OHT와 port가 같은 엣지, 같은 from_node에 있는지, OHT의 from_dist가 port의 From_dist보다 커지는지
        if self.status == "TO_START":
            return (self.start_port 
                    and self.start_port.from_node == self.from_node and self.start_port.to_node == self.edge.dest
                    and self.from_dist >= self.start_port.from_dist)
        elif self.status == "TO_END":
            return (self.end_port 
                    and self.end_port.from_node == self.from_node and self.end_port.to_node == self.edge.dest
                    and self.from_dist >= self.end_port.from_dist)
        
    def arrive(self):
        # print('arrived at', self.pos, self.from_node.id)
        # self.from_dist = self.end_port.from_dist
        # self.pos = self.from_node.coord + self.edge.unit_vec * self.end_port.from_dist
        # self.speed = 0
        # self.acc = 0
        # self.wait_time = 500
        # self.end_port = None
        # print('arrived rail : ', self.edge.OHTs, self in self.edge.OHTs)
        
        #도착하면 port위치로 OHT를 고정하고, 속도, 가속도 0으로 정지, wait_time 5초 주기
        if self.status == "TO_START":
            # print(f"OHT {self.id} arrived at start port: {self.start_port.name}")
            self.from_dist = self.start_port.from_dist
            self.pos = self.from_node.coord + self.edge.unit_vec * self.start_port.from_dist
            self.speed = 0
            self.acc = 0
            self.wait_time = 5
            
            self.status = "STOP_AT_START"
            self.path = self.path_to_end  # 경로를 end_port로 변경
            self.path_to_start = []  # start_port 경로 초기화
            self.start_port = None

        elif self.status == "TO_END":
            
            self.from_dist = self.end_port.from_dist
            self.pos = self.from_node.coord + self.edge.unit_vec * self.end_port.from_dist
            self.speed = 0
            self.acc = 0
            self.wait_time = 5
            self.end_port = None
            # print(f"OHT {self.id} arrived at end port: {self.end_port.name}")
            self.status = "STOP_AT_END"
            self.path = []
            self.path_to_end = []  # end_port 경로 초기화

        else:
            print(f"OHT {self.id} is idle.")

    
    #충돌 감지
    def col_check(self, time_step):
        OHTs = self.edge.OHTs
        
        #같은 edge상에 있는 OHT들과 거리 비교
        for oht in OHTs:
            if oht is not self:  # 자신과의 비교를 피함
                dist_diff = oht.from_dist - self.from_dist
                if 0 < dist_diff < self.rect:  # rect 길이보다 가까워지면
                    # 가속도를 줄여 충돌 방지
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
                
        if self.edge.dest.OHT is not None:
            dist_diff = self.edge.length - self.from_dist
            if 0 < dist_diff < self.rect:  # rect 길이보다 가까워지면
                # 가속도를 줄여 충돌 방지
                self.acc = -self.speed/time_step # 속도 감소 또는 정지
                return
         
         #다음 엣지에 있는 OHT들 중 제일 마지막에 있는 친구와 거리 비교       
        if len(self.path) > 0:
            next_edge = self.path[0]
            try:
                last_oht = next_edge.OHTs[-1]
                rem_diff = self.edge.length - self.from_dist
                dist_diff = last_oht.from_dist + rem_diff
                if 0 < dist_diff < self.rect:
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
            except:
                pass
        
        #다음 노드에서 들어오는 엣지들 상에 있는 OHT들과 충돌 비교 (intersection이 무조건 최대 2개임)    
        incoming_edges = [
            edge for edge in self.edge.dest.incoming_edges
            if edge != self.edge # Edges leading to the same destination node
        ]
        
        if len(incoming_edges) == 1: #만약 intersection이 있따면 (다른 edge가 있다면)
            rem_diff = self.edge.length - self.from_dist #현재 자기 자신의 엣지 상에서 남은 거리 계산
            try:
                other_oht = incoming_edges[0].OHTs[0]
                other_diff= other_oht.edge.length - other_oht.from_dist #다른 엣지 위 제일 앞에 있는 OHT의 남은 거리 계산
                dist_diff = rem_diff + other_diff #두 OHT간의 거리 계산
                if 0 < dist_diff < 3 * self.rect and rem_diff > other_diff: #더 가까운 OHT가 먼저 움직이도록, 나머지는 정지. 3*rect로 잡은 이유는 그래야 좀 더 미리 멈춰서
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
                elif rem_diff == other_diff and self.id > other_oht.id: #혹시나 거리가 같다면 OHT id가 더 빠른 아이가 움직이도록
                    self.acc = -self.speed/time_step # 속도 감소 또는 정지
                    return
            except:
                pass
        if len(self.path) > 0:
            outgoing_edges = [
                edge for edge in self.edge.dest.outgoing_edges
                if edge != self.path[0] # Edges leading to the same destination node
            ]
        
            if len(outgoing_edges) == 1: #만약 intersection이 있따면 (다른 edge가 있다면)
                rem_diff = self.edge.length - self.from_dist #현재 자기 자신의 엣지 상에서 남은 거리 계산
                try:
                    other_oht = outgoing_edges[0].OHTs[0]
                    other_diff= other_oht.from_dist #다른 엣지 위 제일 앞에 있는 OHT의 남은 거리 계산
                    dist_diff = rem_diff + other_diff #두 OHT간의 거리 계산
                    if 0 < dist_diff <  self.rect: #더 가까운 OHT가 먼저 움직이도록, 나머지는 정지. 3*rect로 잡은 이유는 그래야 좀 더 미리 멈춰서
                        self.acc = -self.speed/time_step # 속도 감소 또는 정지
                        return
                except:
                    pass
        
        #충돌 위험이 없다면 다시 원래 max speed로 가속
        self.acc = (self.edge.max_speed - self.speed) / time_step
        
class AMHS:
    def __init__(self, nodes, edges, ports, num_OHTs, max_jobs, job_list = [], oht_list = []):
        """
        AMHS 초기화.
        - nodes: node 클래스 객체 리스트
        - edges: edge 클래스 객체 리스트
        - num_OHTs: 초기 OHT 수
        - max_jobs: 작업 큐의 최대 크기
        """
        # self.graph = nx.DiGraph()
        # self.original_graph=nx.DiGraph()
        
        self.graph = nk.Graph(directed=True, weighted=True)  # Directed weighted graph
        
        self.nodes = nodes  # node 객체 리스트
        for node in nodes:
            node.OHT = None
        self.edges = edges  # edge 객체 리스트
        for edge in edges:
            edge.OHTs = []
            edge.count = 0
            edge.avg_speed = edge.max_speed
        self.ports = ports #port list
        for p in ports:
            p.edge = self.get_edge(p.from_node, p.to_node)
        self.OHTs = []
        if job_list != []:
            self.job_queue = [[self.get_port(q[0]), self.get_port(q[1])] for q in job_list]
        else:
            self.job_queue = []
        self.max_jobs = max_jobs
        
        self.node_id_map = {}
        
        self.time_step=0.01
        
                
        self.simulation_running = False  # 시뮬레이션 상태 관리
        self.stop_simulation_event = threading.Event()  # 스레드 이벤트 처리

        # 그래프 생성
        self._create_graph()
        
        self.original_graph = nk.Graph(self.graph)

        # 초기 OHT 배치
        if oht_list != []:
            self.set_initial_OHTs(oht_list)
        else:
            self.initialize_OHTs(num_OHTs)
        
        self.apsp = nk.distance.APSP(self.graph)
        self.apsp.run()
        
        self.original_apsp = nk.distance.APSP(self.original_graph)
        self.original_apsp.run()
        


    def _create_graph(self):
        """NetworkX 그래프를 nodes와 edges로 생성."""
        for i, node in enumerate(self.nodes):
            self.graph.addNode()  # Add node to the graph
            self.node_id_map[node.id] = i
        
        for edge in self.edges:
            u = self.node_id_map[edge.source.id]  # Get index for source node
            v = self.node_id_map[edge.dest.id]    # Get index for destination node
            self.graph.addEdge(u, v, edge.length)
            edge.dest.incoming_edges.append(edge) #각 node마다 incoming edge 추가
            edge.source.outgoing_edges.append(edge)

    def initialize_OHTs(self, num_OHTs):
        available_nodes = self.nodes.copy()
        
        for i in range(num_OHTs):
            # 노드 중에서 랜덤 선택 (노드 소진 시 다시 전체에서 랜덤)
            if not available_nodes:
                available_nodes = self.nodes.copy()  # 노드 리스트 재생성
            
            start_node = random.choice(available_nodes)
            available_nodes.remove(start_node)  # 선택한 노드는 제거
            
            oht = OHT(
                id=i,
                from_node=start_node,
                from_dist=0,
                speed=0,
                acc=0,
                rect=1000,  # 충돌 판정 거리
                path=[],
            )
            start_node.OHT = oht
            self.OHTs.append(oht)
            
    def set_initial_OHTs(self, oht_list):
        i = 0
        for start_node in oht_list:  
            start_node = self.get_node(start_node)
            oht = OHT(
                id=i,
                from_node=start_node,
                from_dist=0,
                speed=0,
                acc=0,
                rect=1000,  # 충돌 판정 거리
                path=[],
            )
            start_node.OHT = oht
            self.OHTs.append(oht)
            i = i+1
    
    def set_oht(self, oht_origin, oht_new):
        oht_origin.from_node = self.get_node(oht_new['from_node'])
        oht_origin.from_dist = oht_new['from_dist']
        oht_origin.edge = self.get_edge(oht_new['source'], oht_new['dest'])
        if oht_origin.edge:
            if oht_origin not in oht_origin.edge.OHTs:
                oht_origin.edge.OHTs.append(oht_origin)
        try:
            if not self.graph.hasEdge(self.node_id_map[oht_new['source']], self.node_id_map[oht_new['dest']]):
                oht_origin.speed = 0
                oht_origin.acc = 0
                oht_origin.status = 'ON_REMOVED'
                oht_origin.cal_pos(self.time_step)
                return
        except:
            print('is here?', oht_new['source'])
  
            
        oht_origin.speed = oht_new['speed']
        oht_origin.status = oht_new['status']
        
        if oht_origin.status == 'ON_REMOVED':
            if oht_origin.start_port:
                oht_origin.status = "TO_START"
            elif oht_origin.end_port:
                oht_origin.status = "TO_END"
            else:
                oht_origin.status = "IDLE"
                
        oht_origin.cal_pos(self.time_step)
             
        
        oht_origin.start_port = self.get_port(oht_new['startPort']) if oht_new['startPort'] else None
        oht_origin.end_port = self.get_port(oht_new['endPort']) if oht_new['endPort'] else None
        oht_origin.wait_time = oht_new['wait_time']
                
        if oht_origin.start_port != None:
            if oht_origin.edge:
                path_edges_to_start = self.get_path_edges(oht_origin.edge.dest.id, oht_origin.start_port.to_node.id)
                path_edges_to_start = self._validate_path(path_edges_to_start)

            else:
                path_edges_to_start = self.get_path_edges(oht_origin.from_node.id, oht_origin.start_port.to_node.id)
                path_edges_to_start = self._validate_path(path_edges_to_start)
            oht_origin.path_to_start = path_edges_to_start[:]
        
        # elif oht_origin.status == "TO_END":
        if oht_origin.end_port != None:
            if oht_origin.status == "TO_END" or oht_origin.status == 'STOP_AT_START':
                if oht_origin.edge:
                    path_edges_to_end = self.get_path_edges(oht_origin.edge.dest.id, oht_origin.end_port.to_node.id)
                    path_edges_to_end = self._validate_path(path_edges_to_end)
                else:
                    path_edges_to_end = self.get_path_edges(oht_origin.from_node.id, oht_origin.end_port.to_node.id)
                    path_edges_to_end = self._validate_path(path_edges_to_end)
            else:
                path_edges_to_end = self.get_path_edges(oht_origin.start_port.to_node.id, oht_origin.end_port.to_node.id)

            oht_origin.path_to_end = path_edges_to_end
        
        if oht_origin.status == "TO_START":
            oht_origin.path = path_edges_to_start[:]
        elif oht_origin.status == "TO_END" or oht_origin.status == "STOP_AT_START":
            oht_origin.path = path_edges_to_end[:]
        else:
            oht_origin.path = []

    def modi_edge(self, source, dest, oht_positions, is_removed):
        if is_removed:
            removed_edge = self.get_edge(source, dest)
            try:       
                self.graph.removeEdge(self.node_id_map[source], self.node_id_map[dest])
                self.apsp = nk.distance.APSP(self.graph)
                self.apsp.run()
            except:
                print(source, dest)
        else:
            edge_to_restore = next((e for e in self.edges if e.source.id == source and e.dest.id == dest), None)
            if edge_to_restore:
                self.graph.addEdge(self.node_id_map[source], self.node_id_map[dest], edge_to_restore.length)
                self.apsp = nk.distance.APSP(self.graph)
                self.apsp.run()
            else:
                print(f"Rail {source} -> {dest} not found in original edges.")
        
    
    def reinitialize_simul(self, oht_positions, edge_data):
        for edge in self.edges:
            edge.OHTs.clear()
            edge.entry_exit_records.clear()
        
        for oht in oht_positions:
            oht_in_amhs = self.get_oht(oht['id'])
            self.set_oht(oht_in_amhs, oht)
            
        edge_map = {f"{edge.source.id}-{edge.dest.id}": edge for edge in self.edges}
    
        for edge_info in edge_data:
            edge_key = f"{edge_info['from']}-{edge_info['to']}"
            if edge_key in edge_map:
                edge = edge_map[edge_key]
                edge.count = edge_info.get('count', 0)
                edge.avg_speed = edge_info.get('avg_speed', 0)
            
        for edge in self.edges:
            edge.OHTs.sort(key = lambda oht : -oht.from_dist)
    
    def generate_job(self):
        """모든 OHT가 Job을 갖도록 작업 생성."""
        for _ in range(50):
            start_port = random.choice(self.ports)
            end_port = random.choice(self.ports)
            while start_port == end_port:  # 시작/목적 포트가 같지 않도록 보장
                end_port = random.choice(self.ports)
            self.job_queue.append((start_port, end_port))
            

    def assign_jobs(self):
        """모든 OHT가 Job을 갖도록 작업 할당."""
        closest_oht = None
        closest_dist = 1e100
        for oht in self.OHTs:
            if not oht.path and self.job_queue and oht.status == 'IDLE':  # OHT가 Idle 상태이고 Job Queue가 비어있지 않은 경우
                start_port, end_port = self.job_queue.pop(0)
                dist = self.get_path_distance(oht.from_node.id, start_port.from_node.id)
                if dist < closest_dist:
                    closest_dist = dist
                    closest_oht = oht
        
        if closest_oht:
            oht = closest_oht
            oht.start_port = start_port
            # oht.start_port = next((port for port in self.ports if port.name == 'DIE0137_Port3'), None)
            oht.end_port = end_port
            oht.status = "TO_START"

            # # Start로 이동하는 경로
            if oht.edge:
                path_edges_to_start = self.get_path_edges(oht.edge.dest.id, start_port.to_node.id)
            else:
                path_edges_to_start = self.get_path_edges(oht.from_node.id, start_port.to_node.id)
            oht.path_to_start = path_edges_to_start[:]
            
            # # End로 이동하는 경로
            # start_edge = [self.get_edge(start_port.from_node.id, start_port.to_node.id)]
            path_edges_to_end = self.get_path_edges(start_port.to_node.id, end_port.to_node.id)
            oht.path_to_end = path_edges_to_end

            # # 전체 경로를 OHT에 설정
            oht.path = path_edges_to_start[:]
            
            # print(oht.path)

            # Assign the first edge in the path to the OHT's edge
            if oht.path:
                if not oht.edge:
                    oht.edge = oht.path.pop(0)
                    oht.from_node.OHT = None
                    if oht not in oht.edge.OHTs:
                        oht.edge.OHTs.append(oht)
                        
    def update_edge_metrics(self, current_time, time_window):
        for edge in self.edges:
            edge.avg_speed = edge.calculate_avg_speed(time_window, current_time)


    def get_node(self, node_id):
        """node id로 node 객체 반환."""
        return next((node for node in self.nodes if node.id == node_id), None)

    def get_edge(self, source_id, dest_id):
        """source와 dest ID로 edge 객체 반환."""
        return next(
            (e for e in self.edges if e.source.id == source_id and e.dest.id == dest_id), 
            None
        )
        
    def get_path_distance(self, source_id, dest_id):
        try:
            source_idx = self.node_id_map[source_id]
            dest_idx = self.node_id_map[dest_id]

            dist = self.apsp.getDistance(source_idx, dest_idx)      
            return dist
        except:
            try:
                source_idx = self.node_id_map[source_id]
                dest_idx = self.node_id_map[dest_id]            

                dist = self.original_apsp.getDistance(source_idx, dest_idx)                
                return dist
            except:
                print(f"No path found even in original_graph for {source_id} -> {dest_id}.")
                return float('inf')
        

    def get_path_edges(self, source_id, dest_id):
        """source와 dest ID로 최단 경로 에지 리스트 반환."""
        try:
            source_idx = self.node_id_map[source_id]
            dest_idx = self.node_id_map[dest_id]
            
            dijkstra = nk.distance.Dijkstra(self.graph, source_idx, storePaths=True, storeNodesSortedByDistance=False, target=dest_idx)
            dijkstra.run()

            path = dijkstra.getPath(dest_idx)
            
            return [
                self.get_edge(self.nodes[path[i]].id, self.nodes[path[i+1]].id)
                for i in range(len(path) - 1)
            ]
        except:
            try:
                source_idx = self.node_id_map[source_id]
                dest_idx = self.node_id_map[dest_id]
                
                dijkstra = nk.distance.Dijkstra(self.original_graph, source_idx, storePaths=True, storeNodesSortedByDistance=False, target=dest_idx)
                dijkstra.run()

                path = dijkstra.getPath(dest_idx)
                
                return [
                    self.get_edge(self.nodes[path[i]].id, self.nodes[path[i+1]].id)
                    for i in range(len(path) - 1)
                ]
            except:
                print(f"No path found even in original_graph for {source_id} -> {dest_id}.")
                return []
    
    def get_oht(self, oht_id):
        return next((oht for oht in self.OHTs if oht.id == oht_id), None)
    
    def get_port(self, port_name):
        return next((port for port in self.ports if port.name == port_name), None)

    def _validate_path(self, path):
        """
        현재 경로에 지워진 edge가 포함된 경우, 해당 edge 직전까지만 반환합니다.

        Parameters:
            path (list): 현재 경로 (edge 객체 리스트)

        Returns:
            list: 수정된 경로 (지워진 edge 직전까지만 포함)
        """
        valid_path = []
        for edge in path:
            if self.graph.hasEdge(self.node_id_map[edge.source.id], self.node_id_map[edge.dest.id]):  # edge가 그래프에 존재하는 경우
                valid_path.append(edge)
            else:
                break  # 지워진 edge를 발견하면 직전까지만 반환
        return valid_path
    
    
        
    def start_simulation(self, socketio, current_time, max_time = 4000, time_step = 0.1):
        """시뮬레이션 시작"""        
        if self.simulation_running:
            print("Simulation is already running. Stopping the current simulation...")
            self.stop_simulation_event.set()
            while self.simulation_running:
                socketio.sleep(0.01)  # Wait for the current simulation to stop
            return
        
        self.simulation_running = True
        self.stop_simulation_event.clear()
        
        count = 0
        edge_metrics_cache = {}  # Cache for edge metrics to track changes

        while current_time < max_time:
            if self.stop_simulation_event.is_set():
                break
            
            if count % 5 == 0:
                self.generate_job()
                self.assign_jobs()

            # Move all OHTs
            oht_positions = []
            for oht in self.OHTs:
                oht.move(time_step, current_time)

            self.update_edge_metrics(current_time, time_window=500)
            
            for oht in self.OHTs:
                oht.cal_pos(time_step)

            if count % 1 == 0:
                for oht in self.OHTs:
                    oht_positions.append({
                        'id': oht.id,
                        'x': oht.pos[0],
                        'y': oht.pos[1],
                        'source': oht.edge.source.id if oht.edge else None,
                        'dest': oht.edge.dest.id if oht.edge else None,
                        'speed': oht.speed,
                        'status': oht.status,
                        'startPort': oht.start_port.name if oht.start_port else None,
                        'endPort': oht.end_port.name if oht.end_port else None,
                        'from_node': oht.from_node.id if oht.from_node else None,
                        'from_dist': oht.from_dist,
                        'wait_time': oht.wait_time
                    })

                updated_edges = []
                for edge in self.edges:
                    key = f"{edge.source.id}-{edge.dest.id}"
                    new_metrics = {"count": edge.count, "avg_speed": edge.avg_speed}
                    if edge_metrics_cache.get(key) != new_metrics:
                        edge_metrics_cache[key] = new_metrics
                        updated_edges.append({
                            "from": edge.source.id,
                            "to": edge.dest.id,
                            **new_metrics
                        })

                payload = {
                    'time': current_time,
                    'oht_positions': oht_positions,
                    'edges': updated_edges
                }

                compressed_payload = compress_data(payload)
                socketio.emit('updateOHT', {'data': compressed_payload})

            # Increment time
            current_time += time_step
            count += 1
            socketio.sleep(0.00001)

        self.simulation_running = False
        print('Simulation ended')
        
        
    
    def accelerate_simul(self, socketio, current_time, max_time = 4000, time_step = 0.01):
        """시뮬레이션 시작"""        
        if self.simulation_running:
            print("Simulation is already running. Stopping the current simulation...")
            self.stop_simulation_event.set()
            while self.simulation_running:
                socketio.sleep(0.01)  # Wait for the current simulation to stop
            return
        
        self.simulation_running = True
        self.stop_simulation_event.clear()
        
        _current_time = 0
        
        count = 0

        while _current_time < current_time:
            if self.stop_simulation_event.is_set():
                break
            
            if count % 5 == 0:
                self.generate_job()
                self.assign_jobs()

            for oht in self.OHTs:
                oht.move(time_step, _current_time)

            self.update_edge_metrics(_current_time, time_window=500)
            
            for oht in self.OHTs:
                oht.cal_pos(time_step)

            # Increment time
            _current_time += time_step
            count += 1
            
        
        edge_metrics_cache = {} 
            
        
        while _current_time < max_time:
            if self.stop_simulation_event.is_set():
                break
            
            if count % 5 == 0:
                self.generate_job()
                self.assign_jobs()

            # Move all OHTs
            oht_positions = []
            for oht in self.OHTs:
                oht.move(time_step, _current_time)

            self.update_edge_metrics(_current_time, time_window=500)
            
            for oht in self.OHTs:
                oht.cal_pos(time_step)

            if count % 1 == 0:
                for oht in self.OHTs:
                    oht_positions.append({
                        'id': oht.id,
                        'x': oht.pos[0],
                        'y': oht.pos[1],
                        'source': oht.edge.source.id if oht.edge else None,
                        'dest': oht.edge.dest.id if oht.edge else None,
                        'speed': oht.speed,
                        'status': oht.status,
                        'startPort': oht.start_port.name if oht.start_port else None,
                        'endPort': oht.end_port.name if oht.end_port else None,
                        'from_node': oht.from_node.id if oht.from_node else None,
                        'from_dist': oht.from_dist,
                        'wait_time': oht.wait_time
                    })

                updated_edges = []
                for edge in self.edges:
                    key = f"{edge.source.id}-{edge.dest.id}"
                    new_metrics = {"count": edge.count, "avg_speed": edge.avg_speed}
                    if edge_metrics_cache.get(key) != new_metrics:
                        edge_metrics_cache[key] = new_metrics
                        updated_edges.append({
                            "from": edge.source.id,
                            "to": edge.dest.id,
                            **new_metrics
                        })

                payload = {
                    'time': current_time,
                    'oht_positions': oht_positions,
                    'edges': updated_edges
                }

                compressed_payload = compress_data(payload)
                socketio.emit('updateOHT', {'data': compressed_payload})

            # Increment time
            current_time += time_step
            count += 1
            socketio.sleep(0.00001)

        self.simulation_running = False
        print('Simulation ended')
